# %%
# exp04 — GoogLeNet/InceptionV1 · Tiny ImageNet
# Acumula exp_001 (filtros 5a/5b reduzidos) + exp_002 (dropout 0.55)
# Hipótese: corrigir colapso do exp_003 (label_smoothing só na main, 0.05)
# + aumentar peso da saída auxiliar (0.4) + LR warmup 5 épocas
# para estabilizar o treinamento e empurrar Top-1 acima de 46%.

import datetime

EXPERIMENTO = {
    "id": "exp_004",
    "hipotese": (
        "Corrigir label_smoothing (0.05 só na main_output) + aumentar peso auxiliar (0.4) "
        "+ LR warmup 5 épocas devem estabilizar o treinamento e empurrar Top-1 acima de 46%."
    ),
    "mudancas": [
        "[exp_001] inception_5a: (256,160,320,32,128,128) → (192,128,256,32,96,96)",
        "[exp_001] inception_5b: (384,192,384,48,128,128) → (256,160,320,32,96,96)",
        "[exp_002] main_dropout: 0.4 → 0.55",
        "[exp_004] label_smoothing: 0.1 (ambas) → 0.05 só na main_output",
        "[exp_004] loss_weight auxiliar: 0.3 → 0.4",
        "[exp_004] ReduceLROnPlateau patience: 5 → 8",
        "[exp_004] EarlyStopping patience: 15 → 20",
        "[exp_004] LR warmup: 5 épocas (0.001 → 0.01)",
        "[exp_004] augmentation: revertido ao nível exp_002 (sem RandomBrightness, rotação 0.15→0.1)",
    ],
    "resultado_top1": None,
    "resultado_top5": None,
    "epocas": None,
}

print(f"[{datetime.datetime.now():%Y-%m-%d %H:%M}] {EXPERIMENTO['id']}")
print(f"Hipótese: {EXPERIMENTO['hipotese']}")
print("\nMudanças acumuladas:")
for m in EXPERIMENTO["mudancas"]:
    print(f"  • {m}")
# Out:
# [2026-05-04 11:53] exp_004
# Hipótese: Corrigir label_smoothing (0.05 só na main_output) + aumentar peso auxiliar (0.4) + LR warmup 5 épocas devem estabilizar o treinamento e empurrar Top-1 acima de 46%.
#
# Mudanças acumuladas:
#   • [exp_001] inception_5a: (256,160,320,32,128,128) → (192,128,256,32,96,96)
#   • [exp_001] inception_5b: (384,192,384,48,128,128) → (256,160,320,32,96,96)
#   • [exp_002] main_dropout: 0.4 → 0.55
#   • [exp_004] label_smoothing: 0.1 (ambas) → 0.05 só na main_output
#   • [exp_004] loss_weight auxiliar: 0.3 → 0.4
#   • [exp_004] ReduceLROnPlateau patience: 5 → 8
#   • [exp_004] EarlyStopping patience: 15 → 20
#   • [exp_004] LR warmup: 5 épocas (0.001 → 0.01)
#   • [exp_004] augmentation: revertido ao nível exp_002 (sem RandomBrightness, rotação 0.15→0.1)

# %% [markdown]
# ## Histórico de Experimentos
#
# | ID | Mudanças-chave | Top-1 val | Top-5 val | Δ Top-1 |
# |---|---|---|---|---|
# | baseline | Modelo original | 39.88% | — | — |
# | exp_001 | inception_5a/5b: canais reduzidos ~30% | 40.08% | — | +0.20pp |
# | exp_002 | main_dropout: 0.4 → 0.55 | 39.29%* | 71.79% | +1.08pp (principal) |
# | exp_003 | label_smoothing 0.1 (ambas) + ReduceLR patience=5 + aug+ | 0.50% ❌ | 2.50% ❌ | colapso (16 épocas) |
# | **exp_004** | label_smoothing 0.05 (só main) + peso aux 0.4 + warmup | *(pendente)* | *(pendente)* | — |
#
# > *O Top-1 do exp_002 reportado pelo `evaluate()` usa a saída principal (39.29%).
# > A saída auxiliar atingiu 46.58% — gap de ~7pp que exp_004 visa eliminar.
#
# > **exp_003 — post-mortem:** label_smoothing=0.1 aplicado nas duas saídas + ReduceLROnPlateau
# > com patience=5 causou colapso de gradiente desde a época 1. O modelo nunca saiu do
# > baseline aleatório (0.5% = 1/200 classes) e o LR foi reduzido 3x antes do early stopping
# > encerrar na época 16.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import itertools, math, csv, os, shutil, zipfile, warnings, datetime
import requests
from PIL import Image
from io import BytesIO
from pathlib import Path
from sklearn.metrics import confusion_matrix

warnings.filterwarnings('ignore')
print(f"TensorFlow: {tf.__version__}")
print(f"GPUs: {tf.config.list_physical_devices('GPU')}")
# Out:
# 2026-05-04 11:53:26.349966: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777895606.539898      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777895606.595844      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777895607.032778      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777895607.032824      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777895607.032826      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777895607.032829      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow: 2.19.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ── Hiperparâmetros ──────────────────────────────────────────────────────────
EPOCHS         = 100
BATCH_SIZE     = 128
NUM_CLASSES    = 200
IMG_SIZE       = 64
INITIAL_LR     = 0.01
WARMUP_EPOCHS  = 5      # exp_004 — warmup de LR
WARMUP_LR      = 0.001  # exp_004 — LR inicial do warmup
DROPOUT_MAIN   = 0.55   # exp_002
LABEL_SMOOTH   = 0.05   # exp_004 — reduzido de 0.1, aplicado só na main_output
AUX_WEIGHT     = 0.4    # exp_004 — aumentado de 0.3

tf.random.set_seed(42)
np.random.seed(42)
print(f"{EPOCHS} épocas | batch {BATCH_SIZE} | {IMG_SIZE}×{IMG_SIZE} | {NUM_CLASSES} classes")
print(f"dropout={DROPOUT_MAIN} | label_smoothing={LABEL_SMOOTH} (só main) | aux_weight={AUX_WEIGHT}")
print(f"LR warmup: {WARMUP_EPOCHS} épocas ({WARMUP_LR} → {INITIAL_LR})")
# Out:
# 100 épocas | batch 128 | 64×64 | 200 classes
# dropout=0.55 | label_smoothing=0.05 (só main) | aux_weight=0.4
# LR warmup: 5 épocas (0.001 → 0.01)

# %%
TINY_URL = 'http://cs231n.stanford.edu/tiny-imagenet-200.zip'
DATA_DIR = Path('/kaggle/working/tiny-imagenet-200')
ZIP_PATH = Path('/kaggle/working/tiny-imagenet-200.zip')

if not ZIP_PATH.exists():
    print('Baixando Tiny ImageNet (~236 MB)...')
    r = requests.get(TINY_URL, stream=True)
    total = int(r.headers.get('content-length', 0))
    downloaded = 0
    with open(ZIP_PATH, 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024*1024):
            f.write(chunk)
            downloaded += len(chunk)
            print(f'\r  {downloaded/1e6:.1f}/{total/1e6:.1f} MB', end='')
    print('\nDownload completo!')
else:
    print('ZIP já existe.')

if not DATA_DIR.exists():
    print('Extraindo...')
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall('/kaggle/working')
    print('Extração concluída.')
else:
    print('Dataset já extraído.')

# Reorganiza val/ → val_organized/class_id/img.JPEG
val_organized = DATA_DIR / 'val_organized'
if not val_organized.exists():
    print('Reorganizando val/...')
    val_organized.mkdir(parents=True)
    with open(DATA_DIR / 'val' / 'val_annotations.txt') as f:
        for line in f:
            fname, class_id = line.strip().split('\t')[:2]
            d = val_organized / class_id
            d.mkdir(exist_ok=True)
            shutil.copy(DATA_DIR / 'val' / 'images' / fname, d / fname)
    print(f'Val reorganizado: {len(list(val_organized.iterdir()))} classes')
else:
    print('val_organized já existe.')

TRAIN_DIR = DATA_DIR / 'train'
VAL_DIR   = val_organized
print(f'Treino: {TRAIN_DIR} | Val: {VAL_DIR}')
# Out:
# Baixando Tiny ImageNet (~236 MB)...
#   248.1/248.1 MB
# Download completo!
# Extraindo...
# Extração concluída.
# Reorganizando val/...
# Val reorganizado: 200 classes
# Treino: /kaggle/working/tiny-imagenet-200/train | Val: /kaggle/working/tiny-imagenet-200/val_organized

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR, image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE, label_mode='categorical', shuffle=True, seed=42
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR, image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE, label_mode='categorical', shuffle=False
)
CLASS_NAMES = train_ds.class_names
print(f'Classes: {len(CLASS_NAMES)}')

def normalize(img, lbl):
    return tf.cast(img, tf.float32) / 255.0, lbl

# exp_004: augmentation revertido ao nível do exp_002
# (removido RandomBrightness, rotação 0.15 → 0.1)
augment = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomTranslation(0.1, 0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1),
], name='augmentation')

train_ds = (
    train_ds
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .map(lambda img, lbl: (augment(img, training=True), lbl), num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)
val_ds = (
    val_ds
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)
print('Pipelines prontos.')
# Out:
# Found 100000 files belonging to 200 classes.
# I0000 00:00:1777895654.290600      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 10000 files belonging to 200 classes.
# Classes: 200
# Pipelines prontos.

# %%
def inception_module(x, f1, f3r, f3, f5r, f5, fp, name):
    """Módulo Inception: 4 ramos paralelos (Szegedy et al., 2014)."""
    ki = 'glorot_uniform'
    bi = tf.keras.initializers.Constant(0.2)
    kw = dict(padding='same', activation='relu', kernel_initializer=ki, bias_initializer=bi)

    b1 = tf.keras.layers.Conv2D(f1,  (1,1), **kw, name=f'{name}_1x1')(x)

    b2 = tf.keras.layers.Conv2D(f3r, (1,1), **kw, name=f'{name}_3x3_reduce')(x)
    b2 = tf.keras.layers.Conv2D(f3,  (3,3), **kw, name=f'{name}_3x3')(b2)

    b3 = tf.keras.layers.Conv2D(f5r, (1,1), **kw, name=f'{name}_5x5_reduce')(x)
    b3 = tf.keras.layers.Conv2D(f5,  (5,5), **kw, name=f'{name}_5x5')(b3)

    b4 = tf.keras.layers.MaxPooling2D((3,3), strides=(1,1), padding='same', name=f'{name}_pool')(x)
    b4 = tf.keras.layers.Conv2D(fp,  (1,1), **kw, name=f'{name}_pool_proj')(b4)

    return tf.keras.layers.Concatenate(axis=-1, name=name)([b1, b2, b3, b4])

# %%
def build_googlenet(num_classes=200, img_size=64, dropout=0.55):
    """GoogLeNet adaptado para 64×64. Acumula mudanças de exp_001 e exp_002."""
    bi = tf.keras.initializers.Constant(0.2)
    conv_kw = dict(padding='same', activation='relu',
                   kernel_initializer='glorot_uniform', bias_initializer=bi)

    inp = tf.keras.layers.Input(shape=(img_size, img_size, 3), name='input')

    # Stem: 3×3 × 3 + 1 MaxPool (preserva 32×32 para imagens 64×64)
    x = tf.keras.layers.Conv2D(64,  (3,3), **conv_kw, name='stem_c1')(inp)
    x = tf.keras.layers.Conv2D(64,  (3,3), **conv_kw, name='stem_c2')(x)
    x = tf.keras.layers.Conv2D(192, (3,3), **conv_kw, name='stem_c3')(x)
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same', name='stem_pool')(x)

    # Bloco 3
    x = inception_module(x,  64,  96, 128, 16,  32,  32, 'inception_3a')
    x = inception_module(x, 128, 128, 192, 32,  96,  64, 'inception_3b')
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same', name='pool_3')(x)

    # Bloco 4
    x = inception_module(x, 192,  96, 208, 16,  48,  64, 'inception_4a')

    # Classificador Auxiliar (peso 0.3 na loss)
    aux = tf.keras.layers.AveragePooling2D((5,5), strides=3, padding='same', name='aux_pool')(x)
    aux = tf.keras.layers.Conv2D(128, (1,1), **conv_kw, name='aux_conv')(aux)
    aux = tf.keras.layers.Flatten(name='aux_flat')(aux)
    aux = tf.keras.layers.Dense(1024, activation='relu', name='aux_dense')(aux)
    aux = tf.keras.layers.Dropout(0.3, name='aux_drop')(aux)
    aux_out = tf.keras.layers.Dense(num_classes, activation='softmax', name='auxiliary_output')(aux)

    x = inception_module(x, 160, 112, 224, 24,  64,  64, 'inception_4b')
    x = inception_module(x, 128, 128, 256, 24,  64,  64, 'inception_4c')
    x = inception_module(x, 112, 144, 288, 32,  64,  64, 'inception_4d')
    x = inception_module(x, 256, 160, 320, 32, 128, 128, 'inception_4e')
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same', name='pool_4')(x)

    # Bloco 5 — canais reduzidos (exp_001)
    x = inception_module(x, 192, 128, 256, 32, 96, 96, 'inception_5a')  # 640ch
    x = inception_module(x, 256, 160, 320, 32, 96, 96, 'inception_5b')  # 768ch

    # Cabeça principal — dropout 0.55 (exp_002)
    x = tf.keras.layers.GlobalAveragePooling2D(name='gap')(x)
    x = tf.keras.layers.Dropout(dropout, name='main_dropout')(x)
    main_out = tf.keras.layers.Dense(num_classes, activation='softmax', name='main_output')(x)

    return tf.keras.Model(inputs=inp, outputs=[main_out, aux_out], name='GoogLeNet_exp004')


model = build_googlenet(NUM_CLASSES, IMG_SIZE, DROPOUT_MAIN)
model.summary()
# Out:
# Model: "GoogLeNet_exp004"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 64, 64, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_c1 (Conv2D)    │ (None, 64, 64,    │      1,792 │ input[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_c2 (Conv2D)    │ (None, 64, 64,    │     36,928 │ stem_c1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_c3 (Conv2D)    │ (None, 64, 64,    │    110,784 │ stem_c2[0][0]     │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_pool           │ (None, 32, 32,    │          0 │ stem_c3[0][0]     │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3_r… │ (None, 32, 32,    │     18,528 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5_r… │ (None, 32, 32,    │      3,088 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool   │ (None, 32, 32,    │          0 │ stem_pool[0][0]   │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_1x1    │ (None, 32, 32,    │     12,352 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3    │ (None, 32, 32,    │    110,720 │ inception_3a_3x3… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5    │ (None, 32, 32,    │     12,832 │ inception_3a_5x5… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool_… │ (None, 32, 32,    │      6,176 │ inception_3a_poo… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a        │ (None, 32, 32,    │          0 │ inception_3a_1x1… │
# │ (Concatenate)       │ 256)              │            │ inception_3a_3x3… │
# │                     │                   │            │ inception_3a_5x5… │
# │                     │                   │            │ inception_3a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3_r… │ (None, 32, 32,    │     32,896 │ inception_3a[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5_r… │ (None, 32, 32,    │      8,224 │ inception_3a[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool   │ (None, 32, 32,    │          0 │ inception_3a[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_1x1    │ (None, 32, 32,    │     32,896 │ inception_3a[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3    │ (None, 32, 32,    │    221,376 │ inception_3b_3x3… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5    │ (None, 32, 32,    │     76,896 │ inception_3b_5x5… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool_… │ (None, 32, 32,    │     16,448 │ inception_3b_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b        │ (None, 32, 32,    │          0 │ inception_3b_1x1… │
# │ (Concatenate)       │ 480)              │            │ inception_3b_3x3… │
# │                     │                   │            │ inception_3b_5x5… │
# │                     │                   │            │ inception_3b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_3              │ (None, 16, 16,    │          0 │ inception_3b[0][… │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3_r… │ (None, 16, 16,    │     46,176 │ pool_3[0][0]      │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5_r… │ (None, 16, 16,    │      7,696 │ pool_3[0][0]      │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool   │ (None, 16, 16,    │          0 │ pool_3[0][0]      │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_1x1    │ (None, 16, 16,    │     92,352 │ pool_3[0][0]      │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3    │ (None, 16, 16,    │    179,920 │ inception_4a_3x3… │
# │ (Conv2D)            │ 208)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5    │ (None, 16, 16,    │     19,248 │ inception_4a_5x5… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool_… │ (None, 16, 16,    │     30,784 │ inception_4a_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a        │ (None, 16, 16,    │          0 │ inception_4a_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4a_3x3… │
# │                     │                   │            │ inception_4a_5x5… │
# │                     │                   │            │ inception_4a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_3x3_r… │ (None, 16, 16,    │     57,456 │ inception_4a[0][… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_5x5_r… │ (None, 16, 16,    │     12,312 │ inception_4a[0][… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_pool   │ (None, 16, 16,    │          0 │ inception_4a[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_1x1    │ (None, 16, 16,    │     82,080 │ inception_4a[0][… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_3x3    │ (None, 16, 16,    │    226,016 │ inception_4b_3x3… │
# │ (Conv2D)            │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_5x5    │ (None, 16, 16,    │     38,464 │ inception_4b_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_pool_… │ (None, 16, 16,    │     32,832 │ inception_4b_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b        │ (None, 16, 16,    │          0 │ inception_4b_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4b_3x3… │
# │                     │                   │            │ inception_4b_5x5… │
# │                     │                   │            │ inception_4b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_3x3_r… │ (None, 16, 16,    │     65,664 │ inception_4b[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_5x5_r… │ (None, 16, 16,    │     12,312 │ inception_4b[0][… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_pool   │ (None, 16, 16,    │          0 │ inception_4b[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_1x1    │ (None, 16, 16,    │     65,664 │ inception_4b[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_3x3    │ (None, 16, 16,    │    295,168 │ inception_4c_3x3… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_5x5    │ (None, 16, 16,    │     38,464 │ inception_4c_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_pool_… │ (None, 16, 16,    │     32,832 │ inception_4c_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c        │ (None, 16, 16,    │          0 │ inception_4c_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4c_3x3… │
# │                     │                   │            │ inception_4c_5x5… │
# │                     │                   │            │ inception_4c_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_3x3_r… │ (None, 16, 16,    │     73,872 │ inception_4c[0][… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_5x5_r… │ (None, 16, 16,    │     16,416 │ inception_4c[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_pool   │ (None, 16, 16,    │          0 │ inception_4c[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_1x1    │ (None, 16, 16,    │     57,456 │ inception_4c[0][… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_3x3    │ (None, 16, 16,    │    373,536 │ inception_4d_3x3… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_5x5    │ (None, 16, 16,    │     51,264 │ inception_4d_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_pool_… │ (None, 16, 16,    │     32,832 │ inception_4d_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d        │ (None, 16, 16,    │          0 │ inception_4d_1x1… │
# │ (Concatenate)       │ 528)              │            │ inception_4d_3x3… │
# │                     │                   │            │ inception_4d_5x5… │
# │                     │                   │            │ inception_4d_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3_r… │ (None, 16, 16,    │     84,640 │ inception_4d[0][… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5_r… │ (None, 16, 16,    │     16,928 │ inception_4d[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_pool   │ (None, 16, 16,    │          0 │ inception_4d[0][… │
# │ (MaxPooling2D)      │ 528)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_1x1    │ (None, 16, 16,    │    135,424 │ inception_4d[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3    │ (None, 16, 16,    │    461,120 │ inception_4e_3x3… │
# │ (Conv2D)            │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5    │ (None, 16, 16,    │    102,528 │ inception_4e_5x5… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_pool_… │ (None, 16, 16,    │     67,712 │ inception_4e_poo… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e        │ (None, 16, 16,    │          0 │ inception_4e_1x1… │
# │ (Concatenate)       │ 832)              │            │ inception_4e_3x3… │
# │                     │                   │            │ inception_4e_5x5… │
# │                     │                   │            │ inception_4e_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_4              │ (None, 8, 8, 832) │          0 │ inception_4e[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3_r… │ (None, 8, 8, 128) │    106,624 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_5x5_r… │ (None, 8, 8, 32)  │     26,656 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool   │ (None, 8, 8, 832) │          0 │ pool_4[0][0]      │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_1x1    │ (None, 8, 8, 192) │    159,936 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3    │ (None, 8, 8, 256) │    295,168 │ inception_5a_3x3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_5x5    │ (None, 8, 8, 96)  │     76,896 │ inception_5a_5x5… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool_… │ (None, 8, 8, 96)  │     79,968 │ inception_5a_poo… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a        │ (None, 8, 8, 640) │          0 │ inception_5a_1x1… │
# │ (Concatenate)       │                   │            │ inception_5a_3x3… │
# │                     │                   │            │ inception_5a_5x5… │
# │                     │                   │            │ inception_5a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3_r… │ (None, 8, 8, 160) │    102,560 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_5x5_r… │ (None, 8, 8, 32)  │     20,512 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool   │ (None, 8, 8, 640) │          0 │ inception_5a[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_pool            │ (None, 6, 6, 512) │          0 │ inception_4a[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_1x1    │ (None, 8, 8, 256) │    164,096 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3    │ (None, 8, 8, 320) │    461,120 │ inception_5b_3x3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_5x5    │ (None, 8, 8, 96)  │     76,896 │ inception_5b_5x5… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool_… │ (None, 8, 8, 96)  │     61,536 │ inception_5b_poo… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_conv (Conv2D)   │ (None, 6, 6, 128) │     65,664 │ aux_pool[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b        │ (None, 8, 8, 768) │          0 │ inception_5b_1x1… │
# │ (Concatenate)       │                   │            │ inception_5b_3x3… │
# │                     │                   │            │ inception_5b_5x5… │
# │                     │                   │            │ inception_5b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_flat (Flatten)  │ (None, 4608)      │          0 │ aux_conv[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 768)       │          0 │ inception_5b[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_dense (Dense)   │ (None, 1024)      │  4,719,616 │ aux_flat[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_dropout        │ (None, 768)       │          0 │ gap[0][0]         │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_drop (Dropout)  │ (None, 1024)      │          0 │ aux_dense[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_output (Dense) │ (None, 200)       │    153,800 │ main_dropout[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ auxiliary_output    │ (None, 200)       │    205,000 │ aux_drop[0][0]    │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,287,152 (39.24 MB)
#  Trainable params: 10,287,152 (39.24 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# exp_004: label_smoothing=0.05 APENAS na main_output; saída auxiliar sem smoothing
# loss_weight auxiliar aumentado de 0.3 → 0.4 para forçar gradientes mais fortes
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=WARMUP_LR, momentum=0.9, nesterov=True),
    loss={
        'main_output':      tf.keras.losses.CategoricalCrossentropy(label_smoothing=LABEL_SMOOTH),
        'auxiliary_output': tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.0),
    },
    loss_weights={'main_output': 1.0, 'auxiliary_output': AUX_WEIGHT},
    metrics={'main_output': ['accuracy'], 'auxiliary_output': ['accuracy']},
)
print('Compilado com sucesso.')
print(f'  LR inicial (warmup): {WARMUP_LR} | LR alvo: {INITIAL_LR}')
print(f'  label_smoothing main={LABEL_SMOOTH} | auxiliary=0.0')
print(f'  loss_weights: main=1.0 | auxiliary={AUX_WEIGHT}')
# Out:
# Compilado com sucesso.
#   LR inicial (warmup): 0.001 | LR alvo: 0.01
#   label_smoothing main=0.05 | auxiliary=0.0
#   loss_weights: main=1.0 | auxiliary=0.4

# %%
# exp_004: LR warmup manual (5 épocas) + ReduceLROnPlateau patience=8
# EarlyStopping patience=20 para dar mais margem após o warmup

class LRWarmupCallback(tf.keras.callbacks.Callback):
    """Sobe o LR linearmente de warmup_lr até target_lr ao longo de warmup_epochs."""
    def __init__(self, warmup_epochs, warmup_lr, target_lr):
        super().__init__()
        self.warmup_epochs = warmup_epochs
        self.warmup_lr     = warmup_lr
        self.target_lr     = target_lr

    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.warmup_epochs:
            lr = self.warmup_lr + (self.target_lr - self.warmup_lr) * (epoch / self.warmup_epochs)
            self.model.optimizer.learning_rate.assign(lr)  # Keras 3 — set_value foi removido
            print(f'  [warmup] época {epoch+1}/{self.warmup_epochs} — LR = {lr:.5f}')
        elif epoch == self.warmup_epochs:
            self.model.optimizer.learning_rate.assign(self.target_lr)
            print(f'  [warmup] concluído — LR fixado em {self.target_lr}')

callbacks = [
    LRWarmupCallback(
        warmup_epochs=WARMUP_EPOCHS,
        warmup_lr=WARMUP_LR,
        target_lr=INITIAL_LR,
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_main_output_accuracy', factor=0.5,
        patience=8, min_lr=1e-5, verbose=1, mode='max'
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_main_output_accuracy', patience=20,
        restore_best_weights=True, verbose=1, mode='max'
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'googlenet_exp004_best.keras', monitor='val_main_output_accuracy',
        save_best_only=True, verbose=1, mode='max'
    ),
    tf.keras.callbacks.CSVLogger('training_log_exp004.csv'),
]

# %%
# Duplica labels para as 2 saídas do modelo
def dual_labels(img, lbl):
    return img, (lbl, lbl)

train_ds_dual = train_ds.map(dual_labels)
val_ds_dual   = val_ds.map(dual_labels)

print(f'Iniciando exp_004 — {EPOCHS} épocas máx.')
history = model.fit(
    train_ds_dual,
    validation_data=val_ds_dual,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Iniciando exp_004 — 100 épocas máx.
#   [warmup] época 1/5 — LR = 0.00100
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777895666.398979      75 service.cc:152] XLA service 0x7896ec003d10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777895666.399023      75 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1777895668.292432      75 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1777895702.940847      75 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - auxiliary_output_accuracy: 0.0056 - auxiliary_output_loss: 5.3364 - loss: 7.4966 - main_output_accuracy: 0.0050 - main_output_loss: 5.3620
# Epoch 1: val_main_output_accuracy improved from -inf to 0.00500, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 291s 315ms/step - auxiliary_output_accuracy: 0.0056 - auxiliary_output_loss: 5.3363 - loss: 7.4965 - main_output_accuracy: 0.0050 - main_output_loss: 5.3620 - val_auxiliary_output_accuracy: 0.0071 - val_auxiliary_output_loss: 5.2931 - val_loss: 7.4164 - val_main_output_accuracy: 0.0050 - val_main_output_loss: 5.2988 - learning_rate: 0.0010
#   [warmup] época 2/5 — LR = 0.00280
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - auxiliary_output_accuracy: 0.0070 - auxiliary_output_loss: 5.2864 - loss: 7.4161 - main_output_accuracy: 0.0051 - main_output_loss: 5.3016
# Epoch 2: val_main_output_accuracy improved from 0.00500 to 0.00870, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 212s 270ms/step - auxiliary_output_accuracy: 0.0070 - auxiliary_output_loss: 5.2864 - loss: 7.4161 - main_output_accuracy: 0.0051 - main_output_loss: 5.3016 - val_auxiliary_output_accuracy: 0.0130 - val_auxiliary_output_loss: 5.1334 - val_loss: 7.3397 - val_main_output_accuracy: 0.0087 - val_main_output_loss: 5.2853 - learning_rate: 0.0028
#   [warmup] época 3/5 — LR = 0.00460
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.0179 - auxiliary_output_loss: 5.1235 - loss: 7.2946 - main_output_accuracy: 0.0089 - main_output_loss: 5.2452
# Epoch 3: val_main_output_accuracy improved from 0.00870 to 0.01820, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.0179 - auxiliary_output_loss: 5.1234 - loss: 7.2945 - main_output_accuracy: 0.0089 - main_output_loss: 5.2452 - val_auxiliary_output_accuracy: 0.0404 - val_auxiliary_output_loss: 4.8897 - val_loss: 7.0435 - val_main_output_accuracy: 0.0182 - val_main_output_loss: 5.0895 - learning_rate: 0.0046
#   [warmup] época 4/5 — LR = 0.00640
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.0349 - auxiliary_output_loss: 4.9332 - loss: 7.0888 - main_output_accuracy: 0.0170 - main_output_loss: 5.1155
# Epoch 4: val_main_output_accuracy improved from 0.01820 to 0.02900, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.0349 - auxiliary_output_loss: 4.9331 - loss: 7.0887 - main_output_accuracy: 0.0170 - main_output_loss: 5.1155 - val_auxiliary_output_accuracy: 0.0614 - val_auxiliary_output_loss: 4.6906 - val_loss: 6.8522 - val_main_output_accuracy: 0.0290 - val_main_output_loss: 4.9762 - learning_rate: 0.0064
#   [warmup] época 5/5 — LR = 0.00820
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.0572 - auxiliary_output_loss: 4.7096 - loss: 6.8384 - main_output_accuracy: 0.0310 - main_output_loss: 4.9546
# Epoch 5: val_main_output_accuracy improved from 0.02900 to 0.04740, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.0572 - auxiliary_output_loss: 4.7095 - loss: 6.8383 - main_output_accuracy: 0.0310 - main_output_loss: 4.9545 - val_auxiliary_output_accuracy: 0.0934 - val_auxiliary_output_loss: 4.4380 - val_loss: 6.5617 - val_main_output_accuracy: 0.0474 - val_main_output_loss: 4.7866 - learning_rate: 0.0082
#   [warmup] concluído — LR fixado em 0.01
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.0865 - auxiliary_output_loss: 4.4633 - loss: 6.5504 - main_output_accuracy: 0.0506 - main_output_loss: 4.7651
# Epoch 6: val_main_output_accuracy improved from 0.04740 to 0.06850, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.0866 - auxiliary_output_loss: 4.4632 - loss: 6.5503 - main_output_accuracy: 0.0506 - main_output_loss: 4.7651 - val_auxiliary_output_accuracy: 0.1178 - val_auxiliary_output_loss: 4.2034 - val_loss: 6.2652 - val_main_output_accuracy: 0.0685 - val_main_output_loss: 4.5860 - learning_rate: 0.0100
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.1156 - auxiliary_output_loss: 4.2370 - loss: 6.2823 - main_output_accuracy: 0.0736 - main_output_loss: 4.5876
# Epoch 7: val_main_output_accuracy improved from 0.06850 to 0.09800, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.1156 - auxiliary_output_loss: 4.2369 - loss: 6.2823 - main_output_accuracy: 0.0736 - main_output_loss: 4.5875 - val_auxiliary_output_accuracy: 0.1435 - val_auxiliary_output_loss: 3.9925 - val_loss: 5.9584 - val_main_output_accuracy: 0.0980 - val_main_output_loss: 4.3681 - learning_rate: 0.0100
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.1443 - auxiliary_output_loss: 4.0178 - loss: 6.0072 - main_output_accuracy: 0.0979 - main_output_loss: 4.4001
# Epoch 8: val_main_output_accuracy improved from 0.09800 to 0.10450, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.1443 - auxiliary_output_loss: 4.0177 - loss: 6.0071 - main_output_accuracy: 0.0979 - main_output_loss: 4.4000 - val_auxiliary_output_accuracy: 0.1406 - val_auxiliary_output_loss: 4.0559 - val_loss: 5.9472 - val_main_output_accuracy: 0.1045 - val_main_output_loss: 4.3259 - learning_rate: 0.0100
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.1709 - auxiliary_output_loss: 3.8368 - loss: 5.7531 - main_output_accuracy: 0.1283 - main_output_loss: 4.2184
# Epoch 9: val_main_output_accuracy improved from 0.10450 to 0.10570, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.1709 - auxiliary_output_loss: 3.8367 - loss: 5.7530 - main_output_accuracy: 0.1283 - main_output_loss: 4.2183 - val_auxiliary_output_accuracy: 0.1506 - val_auxiliary_output_loss: 4.0765 - val_loss: 6.0844 - val_main_output_accuracy: 0.1057 - val_main_output_loss: 4.4610 - learning_rate: 0.0100
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.1924 - auxiliary_output_loss: 3.6992 - loss: 5.5587 - main_output_accuracy: 0.1500 - main_output_loss: 4.0790
# Epoch 10: val_main_output_accuracy improved from 0.10570 to 0.10890, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.1925 - auxiliary_output_loss: 3.6992 - loss: 5.5586 - main_output_accuracy: 0.1500 - main_output_loss: 4.0790 - val_auxiliary_output_accuracy: 0.1415 - val_auxiliary_output_loss: 4.1575 - val_loss: 6.0175 - val_main_output_accuracy: 0.1089 - val_main_output_loss: 4.3785 - learning_rate: 0.0100
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.2114 - auxiliary_output_loss: 3.5691 - loss: 5.3774 - main_output_accuracy: 0.1707 - main_output_loss: 3.9497
# Epoch 11: val_main_output_accuracy improved from 0.10890 to 0.12600, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.2114 - auxiliary_output_loss: 3.5691 - loss: 5.3773 - main_output_accuracy: 0.1707 - main_output_loss: 3.9497 - val_auxiliary_output_accuracy: 0.1677 - val_auxiliary_output_loss: 3.9598 - val_loss: 5.8599 - val_main_output_accuracy: 0.1260 - val_main_output_loss: 4.2828 - learning_rate: 0.0100
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.2297 - auxiliary_output_loss: 3.4663 - loss: 5.2238 - main_output_accuracy: 0.1900 - main_output_loss: 3.8373
# Epoch 12: val_main_output_accuracy improved from 0.12600 to 0.18900, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.2297 - auxiliary_output_loss: 3.4663 - loss: 5.2238 - main_output_accuracy: 0.1901 - main_output_loss: 3.8373 - val_auxiliary_output_accuracy: 0.2116 - val_auxiliary_output_loss: 3.6100 - val_loss: 5.2173 - val_main_output_accuracy: 0.1890 - val_main_output_loss: 3.7889 - learning_rate: 0.0100
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - auxiliary_output_accuracy: 0.2439 - auxiliary_output_loss: 3.3683 - loss: 5.0819 - main_output_accuracy: 0.2075 - main_output_loss: 3.7345
# Epoch 13: val_main_output_accuracy improved from 0.18900 to 0.20970, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 212s 270ms/step - auxiliary_output_accuracy: 0.2439 - auxiliary_output_loss: 3.3683 - loss: 5.0818 - main_output_accuracy: 0.2075 - main_output_loss: 3.7345 - val_auxiliary_output_accuracy: 0.2241 - val_auxiliary_output_loss: 3.5407 - val_loss: 5.1032 - val_main_output_accuracy: 0.2097 - val_main_output_loss: 3.7023 - learning_rate: 0.0100
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.2574 - auxiliary_output_loss: 3.2932 - loss: 4.9647 - main_output_accuracy: 0.2254 - main_output_loss: 3.6474
# Epoch 14: val_main_output_accuracy improved from 0.20970 to 0.22840, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.2574 - auxiliary_output_loss: 3.2932 - loss: 4.9646 - main_output_accuracy: 0.2254 - main_output_loss: 3.6473 - val_auxiliary_output_accuracy: 0.2145 - val_auxiliary_output_loss: 3.6471 - val_loss: 5.0358 - val_main_output_accuracy: 0.2284 - val_main_output_loss: 3.5995 - learning_rate: 0.0100
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.2703 - auxiliary_output_loss: 3.2187 - loss: 4.8442 - main_output_accuracy: 0.2430 - main_output_loss: 3.5568
# Epoch 15: val_main_output_accuracy did not improve from 0.22840
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.2703 - auxiliary_output_loss: 3.2187 - loss: 4.8442 - main_output_accuracy: 0.2430 - main_output_loss: 3.5567 - val_auxiliary_output_accuracy: 0.2221 - val_auxiliary_output_loss: 3.6027 - val_loss: 5.3741 - val_main_output_accuracy: 0.1775 - val_main_output_loss: 3.9532 - learning_rate: 0.0100
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.2804 - auxiliary_output_loss: 3.1464 - loss: 4.7471 - main_output_accuracy: 0.2555 - main_output_loss: 3.4885
# Epoch 16: val_main_output_accuracy improved from 0.22840 to 0.23000, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.2805 - auxiliary_output_loss: 3.1463 - loss: 4.7470 - main_output_accuracy: 0.2555 - main_output_loss: 3.4885 - val_auxiliary_output_accuracy: 0.2384 - val_auxiliary_output_loss: 3.5504 - val_loss: 5.0773 - val_main_output_accuracy: 0.2300 - val_main_output_loss: 3.6700 - learning_rate: 0.0100
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.2922 - auxiliary_output_loss: 3.0849 - loss: 4.6540 - main_output_accuracy: 0.2694 - main_output_loss: 3.4200
# Epoch 17: val_main_output_accuracy improved from 0.23000 to 0.24900, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.2922 - auxiliary_output_loss: 3.0849 - loss: 4.6540 - main_output_accuracy: 0.2694 - main_output_loss: 3.4200 - val_auxiliary_output_accuracy: 0.2468 - val_auxiliary_output_loss: 3.4747 - val_loss: 4.9060 - val_main_output_accuracy: 0.2490 - val_main_output_loss: 3.5411 - learning_rate: 0.0100
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3021 - auxiliary_output_loss: 3.0196 - loss: 4.5568 - main_output_accuracy: 0.2856 - main_output_loss: 3.3490
# Epoch 18: val_main_output_accuracy improved from 0.24900 to 0.25680, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.3021 - auxiliary_output_loss: 3.0195 - loss: 4.5567 - main_output_accuracy: 0.2856 - main_output_loss: 3.3489 - val_auxiliary_output_accuracy: 0.2683 - val_auxiliary_output_loss: 3.2802 - val_loss: 4.8202 - val_main_output_accuracy: 0.2568 - val_main_output_loss: 3.5277 - learning_rate: 0.0100
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3098 - auxiliary_output_loss: 2.9698 - loss: 4.4822 - main_output_accuracy: 0.2957 - main_output_loss: 3.2943
# Epoch 19: val_main_output_accuracy did not improve from 0.25680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.3098 - auxiliary_output_loss: 2.9698 - loss: 4.4822 - main_output_accuracy: 0.2958 - main_output_loss: 3.2943 - val_auxiliary_output_accuracy: 0.2642 - val_auxiliary_output_loss: 3.3325 - val_loss: 4.8637 - val_main_output_accuracy: 0.2531 - val_main_output_loss: 3.5461 - learning_rate: 0.0100
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3214 - auxiliary_output_loss: 2.9095 - loss: 4.3988 - main_output_accuracy: 0.3080 - main_output_loss: 3.2350
# Epoch 20: val_main_output_accuracy improved from 0.25680 to 0.25970, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.3214 - auxiliary_output_loss: 2.9094 - loss: 4.3988 - main_output_accuracy: 0.3080 - main_output_loss: 3.2350 - val_auxiliary_output_accuracy: 0.2763 - val_auxiliary_output_loss: 3.2893 - val_loss: 4.8477 - val_main_output_accuracy: 0.2597 - val_main_output_loss: 3.5559 - learning_rate: 0.0100
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3259 - auxiliary_output_loss: 2.8725 - loss: 4.3348 - main_output_accuracy: 0.3190 - main_output_loss: 3.1859
# Epoch 21: val_main_output_accuracy did not improve from 0.25970
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.3259 - auxiliary_output_loss: 2.8724 - loss: 4.3348 - main_output_accuracy: 0.3190 - main_output_loss: 3.1858 - val_auxiliary_output_accuracy: 0.2503 - val_auxiliary_output_loss: 3.4669 - val_loss: 4.9847 - val_main_output_accuracy: 0.2505 - val_main_output_loss: 3.6114 - learning_rate: 0.0100
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3361 - auxiliary_output_loss: 2.8214 - loss: 4.2649 - main_output_accuracy: 0.3282 - main_output_loss: 3.1363
# Epoch 22: val_main_output_accuracy improved from 0.25970 to 0.30050, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.3361 - auxiliary_output_loss: 2.8214 - loss: 4.2649 - main_output_accuracy: 0.3282 - main_output_loss: 3.1363 - val_auxiliary_output_accuracy: 0.2640 - val_auxiliary_output_loss: 3.3905 - val_loss: 4.6552 - val_main_output_accuracy: 0.3005 - val_main_output_loss: 3.3193 - learning_rate: 0.0100
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3480 - auxiliary_output_loss: 2.7676 - loss: 4.1917 - main_output_accuracy: 0.3399 - main_output_loss: 3.0847
# Epoch 23: val_main_output_accuracy did not improve from 0.30050
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.3480 - auxiliary_output_loss: 2.7676 - loss: 4.1917 - main_output_accuracy: 0.3399 - main_output_loss: 3.0846 - val_auxiliary_output_accuracy: 0.2820 - val_auxiliary_output_loss: 3.2763 - val_loss: 4.6578 - val_main_output_accuracy: 0.2925 - val_main_output_loss: 3.3672 - learning_rate: 0.0100
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3555 - auxiliary_output_loss: 2.7230 - loss: 4.1321 - main_output_accuracy: 0.3489 - main_output_loss: 3.0428
# Epoch 24: val_main_output_accuracy did not improve from 0.30050
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.3555 - auxiliary_output_loss: 2.7230 - loss: 4.1320 - main_output_accuracy: 0.3489 - main_output_loss: 3.0428 - val_auxiliary_output_accuracy: 0.2336 - val_auxiliary_output_loss: 3.7570 - val_loss: 5.0971 - val_main_output_accuracy: 0.2628 - val_main_output_loss: 3.6166 - learning_rate: 0.0100
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3641 - auxiliary_output_loss: 2.6862 - loss: 4.0748 - main_output_accuracy: 0.3598 - main_output_loss: 3.0003
# Epoch 25: val_main_output_accuracy improved from 0.30050 to 0.32150, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.3641 - auxiliary_output_loss: 2.6862 - loss: 4.0747 - main_output_accuracy: 0.3598 - main_output_loss: 3.0002 - val_auxiliary_output_accuracy: 0.2917 - val_auxiliary_output_loss: 3.2530 - val_loss: 4.5267 - val_main_output_accuracy: 0.3215 - val_main_output_loss: 3.2389 - learning_rate: 0.0100
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3710 - auxiliary_output_loss: 2.6374 - loss: 4.0068 - main_output_accuracy: 0.3681 - main_output_loss: 2.9518
# Epoch 26: val_main_output_accuracy did not improve from 0.32150
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.3710 - auxiliary_output_loss: 2.6374 - loss: 4.0068 - main_output_accuracy: 0.3681 - main_output_loss: 2.9518 - val_auxiliary_output_accuracy: 0.2820 - val_auxiliary_output_loss: 3.2988 - val_loss: 4.6489 - val_main_output_accuracy: 0.2985 - val_main_output_loss: 3.3399 - learning_rate: 0.0100
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3779 - auxiliary_output_loss: 2.6078 - loss: 3.9545 - main_output_accuracy: 0.3783 - main_output_loss: 2.9114
# Epoch 27: val_main_output_accuracy improved from 0.32150 to 0.34350, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.3779 - auxiliary_output_loss: 2.6078 - loss: 3.9545 - main_output_accuracy: 0.3783 - main_output_loss: 2.9113 - val_auxiliary_output_accuracy: 0.3201 - val_auxiliary_output_loss: 3.0431 - val_loss: 4.2978 - val_main_output_accuracy: 0.3435 - val_main_output_loss: 3.0939 - learning_rate: 0.0100
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3847 - auxiliary_output_loss: 2.5632 - loss: 3.9023 - main_output_accuracy: 0.3842 - main_output_loss: 2.8770
# Epoch 28: val_main_output_accuracy did not improve from 0.34350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.3847 - auxiliary_output_loss: 2.5632 - loss: 3.9023 - main_output_accuracy: 0.3842 - main_output_loss: 2.8770 - val_auxiliary_output_accuracy: 0.2885 - val_auxiliary_output_loss: 3.3357 - val_loss: 4.7597 - val_main_output_accuracy: 0.3007 - val_main_output_loss: 3.4429 - learning_rate: 0.0100
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3926 - auxiliary_output_loss: 2.5200 - loss: 3.8323 - main_output_accuracy: 0.3976 - main_output_loss: 2.8243
# Epoch 29: val_main_output_accuracy did not improve from 0.34350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.3926 - auxiliary_output_loss: 2.5199 - loss: 3.8323 - main_output_accuracy: 0.3976 - main_output_loss: 2.8243 - val_auxiliary_output_accuracy: 0.3124 - val_auxiliary_output_loss: 3.1595 - val_loss: 4.4918 - val_main_output_accuracy: 0.3249 - val_main_output_loss: 3.2424 - learning_rate: 0.0100
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.3995 - auxiliary_output_loss: 2.4956 - loss: 3.7981 - main_output_accuracy: 0.4024 - main_output_loss: 2.7999
# Epoch 30: val_main_output_accuracy did not improve from 0.34350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.3995 - auxiliary_output_loss: 2.4955 - loss: 3.7981 - main_output_accuracy: 0.4024 - main_output_loss: 2.7999 - val_auxiliary_output_accuracy: 0.2990 - val_auxiliary_output_loss: 3.3134 - val_loss: 4.4446 - val_main_output_accuracy: 0.3412 - val_main_output_loss: 3.1410 - learning_rate: 0.0100
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4060 - auxiliary_output_loss: 2.4554 - loss: 3.7470 - main_output_accuracy: 0.4121 - main_output_loss: 2.7648
# Epoch 31: val_main_output_accuracy did not improve from 0.34350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.4060 - auxiliary_output_loss: 2.4553 - loss: 3.7469 - main_output_accuracy: 0.4121 - main_output_loss: 2.7648 - val_auxiliary_output_accuracy: 0.2819 - val_auxiliary_output_loss: 3.4531 - val_loss: 4.7843 - val_main_output_accuracy: 0.3047 - val_main_output_loss: 3.4151 - learning_rate: 0.0100
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4107 - auxiliary_output_loss: 2.4200 - loss: 3.7024 - main_output_accuracy: 0.4175 - main_output_loss: 2.7344
# Epoch 32: val_main_output_accuracy improved from 0.34350 to 0.37310, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.4107 - auxiliary_output_loss: 2.4200 - loss: 3.7024 - main_output_accuracy: 0.4175 - main_output_loss: 2.7344 - val_auxiliary_output_accuracy: 0.3400 - val_auxiliary_output_loss: 2.9679 - val_loss: 4.1597 - val_main_output_accuracy: 0.3731 - val_main_output_loss: 2.9819 - learning_rate: 0.0100
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4164 - auxiliary_output_loss: 2.3920 - loss: 3.6492 - main_output_accuracy: 0.4272 - main_output_loss: 2.6924
# Epoch 33: val_main_output_accuracy did not improve from 0.37310
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.4164 - auxiliary_output_loss: 2.3920 - loss: 3.6491 - main_output_accuracy: 0.4272 - main_output_loss: 2.6924 - val_auxiliary_output_accuracy: 0.3071 - val_auxiliary_output_loss: 3.2830 - val_loss: 4.4609 - val_main_output_accuracy: 0.3346 - val_main_output_loss: 3.1743 - learning_rate: 0.0100
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4225 - auxiliary_output_loss: 2.3536 - loss: 3.5979 - main_output_accuracy: 0.4350 - main_output_loss: 2.6564
# Epoch 34: val_main_output_accuracy did not improve from 0.37310
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.4226 - auxiliary_output_loss: 2.3536 - loss: 3.5978 - main_output_accuracy: 0.4350 - main_output_loss: 2.6564 - val_auxiliary_output_accuracy: 0.3157 - val_auxiliary_output_loss: 3.2328 - val_loss: 4.4428 - val_main_output_accuracy: 0.3438 - val_main_output_loss: 3.1590 - learning_rate: 0.0100
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4288 - auxiliary_output_loss: 2.3355 - loss: 3.5685 - main_output_accuracy: 0.4426 - main_output_loss: 2.6343
# Epoch 35: val_main_output_accuracy did not improve from 0.37310
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.4288 - auxiliary_output_loss: 2.3354 - loss: 3.5684 - main_output_accuracy: 0.4426 - main_output_loss: 2.6343 - val_auxiliary_output_accuracy: 0.3375 - val_auxiliary_output_loss: 2.9960 - val_loss: 4.1814 - val_main_output_accuracy: 0.3697 - val_main_output_loss: 3.0067 - learning_rate: 0.0100
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4346 - auxiliary_output_loss: 2.2970 - loss: 3.5176 - main_output_accuracy: 0.4503 - main_output_loss: 2.5988
# Epoch 36: val_main_output_accuracy improved from 0.37310 to 0.37540, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.4346 - auxiliary_output_loss: 2.2970 - loss: 3.5176 - main_output_accuracy: 0.4503 - main_output_loss: 2.5988 - val_auxiliary_output_accuracy: 0.3331 - val_auxiliary_output_loss: 3.0498 - val_loss: 4.2026 - val_main_output_accuracy: 0.3754 - val_main_output_loss: 2.9962 - learning_rate: 0.0100
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4403 - auxiliary_output_loss: 2.2645 - loss: 3.4814 - main_output_accuracy: 0.4544 - main_output_loss: 2.5756
# Epoch 37: val_main_output_accuracy did not improve from 0.37540
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.4403 - auxiliary_output_loss: 2.2644 - loss: 3.4814 - main_output_accuracy: 0.4544 - main_output_loss: 2.5756 - val_auxiliary_output_accuracy: 0.3171 - val_auxiliary_output_loss: 3.2495 - val_loss: 4.5398 - val_main_output_accuracy: 0.3477 - val_main_output_loss: 3.2580 - learning_rate: 0.0100
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4475 - auxiliary_output_loss: 2.2425 - loss: 3.4447 - main_output_accuracy: 0.4637 - main_output_loss: 2.5477
# Epoch 38: val_main_output_accuracy did not improve from 0.37540
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.4475 - auxiliary_output_loss: 2.2425 - loss: 3.4447 - main_output_accuracy: 0.4637 - main_output_loss: 2.5477 - val_auxiliary_output_accuracy: 0.3245 - val_auxiliary_output_loss: 3.2077 - val_loss: 4.4364 - val_main_output_accuracy: 0.3497 - val_main_output_loss: 3.1771 - learning_rate: 0.0100
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4508 - auxiliary_output_loss: 2.2090 - loss: 3.4010 - main_output_accuracy: 0.4700 - main_output_loss: 2.5174
# Epoch 39: val_main_output_accuracy improved from 0.37540 to 0.39610, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 270ms/step - auxiliary_output_accuracy: 0.4509 - auxiliary_output_loss: 2.2090 - loss: 3.4010 - main_output_accuracy: 0.4700 - main_output_loss: 2.5174 - val_auxiliary_output_accuracy: 0.3583 - val_auxiliary_output_loss: 2.8557 - val_loss: 4.0184 - val_main_output_accuracy: 0.3961 - val_main_output_loss: 2.8892 - learning_rate: 0.0100
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4537 - auxiliary_output_loss: 2.1869 - loss: 3.3648 - main_output_accuracy: 0.4767 - main_output_loss: 2.4900
# Epoch 40: val_main_output_accuracy did not improve from 0.39610
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.4537 - auxiliary_output_loss: 2.1869 - loss: 3.3648 - main_output_accuracy: 0.4767 - main_output_loss: 2.4900 - val_auxiliary_output_accuracy: 0.3417 - val_auxiliary_output_loss: 3.0259 - val_loss: 4.1584 - val_main_output_accuracy: 0.3802 - val_main_output_loss: 2.9635 - learning_rate: 0.0100
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4597 - auxiliary_output_loss: 2.1636 - loss: 3.3292 - main_output_accuracy: 0.4823 - main_output_loss: 2.4638
# Epoch 41: val_main_output_accuracy improved from 0.39610 to 0.41170, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.4597 - auxiliary_output_loss: 2.1636 - loss: 3.3292 - main_output_accuracy: 0.4823 - main_output_loss: 2.4637 - val_auxiliary_output_accuracy: 0.3730 - val_auxiliary_output_loss: 2.8964 - val_loss: 4.0445 - val_main_output_accuracy: 0.4117 - val_main_output_loss: 2.8992 - learning_rate: 0.0100
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4691 - auxiliary_output_loss: 2.1347 - loss: 3.2938 - main_output_accuracy: 0.4882 - main_output_loss: 2.4399
# Epoch 42: val_main_output_accuracy did not improve from 0.41170
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 261s 269ms/step - auxiliary_output_accuracy: 0.4691 - auxiliary_output_loss: 2.1347 - loss: 3.2937 - main_output_accuracy: 0.4882 - main_output_loss: 2.4399 - val_auxiliary_output_accuracy: 0.3288 - val_auxiliary_output_loss: 3.1363 - val_loss: 4.3561 - val_main_output_accuracy: 0.3609 - val_main_output_loss: 3.1153 - learning_rate: 0.0100
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4692 - auxiliary_output_loss: 2.1085 - loss: 3.2522 - main_output_accuracy: 0.4946 - main_output_loss: 2.4088
# Epoch 43: val_main_output_accuracy did not improve from 0.41170
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.4692 - auxiliary_output_loss: 2.1085 - loss: 3.2521 - main_output_accuracy: 0.4946 - main_output_loss: 2.4087 - val_auxiliary_output_accuracy: 0.3256 - val_auxiliary_output_loss: 3.2802 - val_loss: 4.3408 - val_main_output_accuracy: 0.3807 - val_main_output_loss: 3.0481 - learning_rate: 0.0100
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4736 - auxiliary_output_loss: 2.0851 - loss: 3.2204 - main_output_accuracy: 0.5004 - main_output_loss: 2.3864
# Epoch 44: val_main_output_accuracy did not improve from 0.41170
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.4736 - auxiliary_output_loss: 2.0850 - loss: 3.2204 - main_output_accuracy: 0.5004 - main_output_loss: 2.3864 - val_auxiliary_output_accuracy: 0.3250 - val_auxiliary_output_loss: 3.2653 - val_loss: 4.3705 - val_main_output_accuracy: 0.3656 - val_main_output_loss: 3.0866 - learning_rate: 0.0100
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4783 - auxiliary_output_loss: 2.0718 - loss: 3.1919 - main_output_accuracy: 0.5068 - main_output_loss: 2.3631
# Epoch 45: val_main_output_accuracy did not improve from 0.41170
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.4783 - auxiliary_output_loss: 2.0718 - loss: 3.1918 - main_output_accuracy: 0.5068 - main_output_loss: 2.3631 - val_auxiliary_output_accuracy: 0.3480 - val_auxiliary_output_loss: 3.0999 - val_loss: 4.2341 - val_main_output_accuracy: 0.3886 - val_main_output_loss: 3.0089 - learning_rate: 0.0100
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4817 - auxiliary_output_loss: 2.0443 - loss: 3.1512 - main_output_accuracy: 0.5124 - main_output_loss: 2.3335
# Epoch 46: val_main_output_accuracy did not improve from 0.41170
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.4817 - auxiliary_output_loss: 2.0443 - loss: 3.1512 - main_output_accuracy: 0.5124 - main_output_loss: 2.3335 - val_auxiliary_output_accuracy: 0.3522 - val_auxiliary_output_loss: 3.0362 - val_loss: 4.1449 - val_main_output_accuracy: 0.3993 - val_main_output_loss: 2.9432 - learning_rate: 0.0100
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4884 - auxiliary_output_loss: 2.0167 - loss: 3.1240 - main_output_accuracy: 0.5147 - main_output_loss: 2.3173
# Epoch 47: val_main_output_accuracy improved from 0.41170 to 0.41770, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.4884 - auxiliary_output_loss: 2.0167 - loss: 3.1240 - main_output_accuracy: 0.5147 - main_output_loss: 2.3173 - val_auxiliary_output_accuracy: 0.3682 - val_auxiliary_output_loss: 2.8815 - val_loss: 3.9691 - val_main_output_accuracy: 0.4177 - val_main_output_loss: 2.8296 - learning_rate: 0.0100
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4927 - auxiliary_output_loss: 1.9944 - loss: 3.0911 - main_output_accuracy: 0.5237 - main_output_loss: 2.2934
# Epoch 48: val_main_output_accuracy did not improve from 0.41770
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.4927 - auxiliary_output_loss: 1.9944 - loss: 3.0911 - main_output_accuracy: 0.5237 - main_output_loss: 2.2934 - val_auxiliary_output_accuracy: 0.3426 - val_auxiliary_output_loss: 3.1149 - val_loss: 4.3789 - val_main_output_accuracy: 0.3638 - val_main_output_loss: 3.1438 - learning_rate: 0.0100
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.4962 - auxiliary_output_loss: 1.9786 - loss: 3.0738 - main_output_accuracy: 0.5283 - main_output_loss: 2.2823
# Epoch 49: val_main_output_accuracy did not improve from 0.41770
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.4962 - auxiliary_output_loss: 1.9785 - loss: 3.0737 - main_output_accuracy: 0.5283 - main_output_loss: 2.2823 - val_auxiliary_output_accuracy: 0.3306 - val_auxiliary_output_loss: 3.2607 - val_loss: 4.4270 - val_main_output_accuracy: 0.3655 - val_main_output_loss: 3.1463 - learning_rate: 0.0100
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5028 - auxiliary_output_loss: 1.9537 - loss: 3.0272 - main_output_accuracy: 0.5356 - main_output_loss: 2.2457
# Epoch 50: val_main_output_accuracy did not improve from 0.41770
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5028 - auxiliary_output_loss: 1.9537 - loss: 3.0272 - main_output_accuracy: 0.5356 - main_output_loss: 2.2457 - val_auxiliary_output_accuracy: 0.3628 - val_auxiliary_output_loss: 3.0709 - val_loss: 4.2242 - val_main_output_accuracy: 0.4015 - val_main_output_loss: 3.0122 - learning_rate: 0.0100
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5093 - auxiliary_output_loss: 1.9228 - loss: 2.9913 - main_output_accuracy: 0.5398 - main_output_loss: 2.2221
# Epoch 51: val_main_output_accuracy did not improve from 0.41770
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5093 - auxiliary_output_loss: 1.9228 - loss: 2.9912 - main_output_accuracy: 0.5398 - main_output_loss: 2.2221 - val_auxiliary_output_accuracy: 0.3459 - val_auxiliary_output_loss: 3.1717 - val_loss: 4.3066 - val_main_output_accuracy: 0.3804 - val_main_output_loss: 3.0565 - learning_rate: 0.0100
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5076 - auxiliary_output_loss: 1.9138 - loss: 2.9781 - main_output_accuracy: 0.5412 - main_output_loss: 2.2126
# Epoch 52: val_main_output_accuracy did not improve from 0.41770
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5076 - auxiliary_output_loss: 1.9137 - loss: 2.9781 - main_output_accuracy: 0.5412 - main_output_loss: 2.2126 - val_auxiliary_output_accuracy: 0.3341 - val_auxiliary_output_loss: 3.2553 - val_loss: 4.4908 - val_main_output_accuracy: 0.3536 - val_main_output_loss: 3.2044 - learning_rate: 0.0100
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5152 - auxiliary_output_loss: 1.8938 - loss: 2.9485 - main_output_accuracy: 0.5479 - main_output_loss: 2.1909
# Epoch 53: val_main_output_accuracy did not improve from 0.41770
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.5153 - auxiliary_output_loss: 1.8938 - loss: 2.9484 - main_output_accuracy: 0.5479 - main_output_loss: 2.1909 - val_auxiliary_output_accuracy: 0.3663 - val_auxiliary_output_loss: 2.9206 - val_loss: 4.0741 - val_main_output_accuracy: 0.4026 - val_main_output_loss: 2.9161 - learning_rate: 0.0100
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5154 - auxiliary_output_loss: 1.8719 - loss: 2.9169 - main_output_accuracy: 0.5543 - main_output_loss: 2.1681
# Epoch 54: val_main_output_accuracy did not improve from 0.41770
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5154 - auxiliary_output_loss: 1.8719 - loss: 2.9168 - main_output_accuracy: 0.5543 - main_output_loss: 2.1681 - val_auxiliary_output_accuracy: 0.3567 - val_auxiliary_output_loss: 3.0890 - val_loss: 4.1597 - val_main_output_accuracy: 0.4060 - val_main_output_loss: 2.9397 - learning_rate: 0.0100
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5201 - auxiliary_output_loss: 1.8666 - loss: 2.9059 - main_output_accuracy: 0.5562 - main_output_loss: 2.1592
# Epoch 55: val_main_output_accuracy improved from 0.41770 to 0.41790, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.5201 - auxiliary_output_loss: 1.8666 - loss: 2.9058 - main_output_accuracy: 0.5562 - main_output_loss: 2.1592 - val_auxiliary_output_accuracy: 0.3700 - val_auxiliary_output_loss: 3.0407 - val_loss: 4.0246 - val_main_output_accuracy: 0.4179 - val_main_output_loss: 2.8298 - learning_rate: 0.0100
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5223 - auxiliary_output_loss: 1.8403 - loss: 2.8715 - main_output_accuracy: 0.5650 - main_output_loss: 2.1354
# Epoch 56: val_main_output_accuracy did not improve from 0.41790
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5223 - auxiliary_output_loss: 1.8403 - loss: 2.8714 - main_output_accuracy: 0.5650 - main_output_loss: 2.1353 - val_auxiliary_output_accuracy: 0.3680 - val_auxiliary_output_loss: 3.0559 - val_loss: 4.2005 - val_main_output_accuracy: 0.4111 - val_main_output_loss: 3.0016 - learning_rate: 0.0100
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5284 - auxiliary_output_loss: 1.8191 - loss: 2.8498 - main_output_accuracy: 0.5657 - main_output_loss: 2.1222
# Epoch 57: val_main_output_accuracy did not improve from 0.41790
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.5284 - auxiliary_output_loss: 1.8191 - loss: 2.8498 - main_output_accuracy: 0.5657 - main_output_loss: 2.1222 - val_auxiliary_output_accuracy: 0.3541 - val_auxiliary_output_loss: 3.1139 - val_loss: 4.1437 - val_main_output_accuracy: 0.4088 - val_main_output_loss: 2.9106 - learning_rate: 0.0100
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5322 - auxiliary_output_loss: 1.8069 - loss: 2.8123 - main_output_accuracy: 0.5735 - main_output_loss: 2.0896
# Epoch 58: val_main_output_accuracy improved from 0.41790 to 0.44010, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.5322 - auxiliary_output_loss: 1.8068 - loss: 2.8123 - main_output_accuracy: 0.5735 - main_output_loss: 2.0895 - val_auxiliary_output_accuracy: 0.3882 - val_auxiliary_output_loss: 2.8719 - val_loss: 3.9596 - val_main_output_accuracy: 0.4401 - val_main_output_loss: 2.8343 - learning_rate: 0.0100
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5396 - auxiliary_output_loss: 1.7829 - loss: 2.7797 - main_output_accuracy: 0.5796 - main_output_loss: 2.0665
# Epoch 59: val_main_output_accuracy did not improve from 0.44010
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5397 - auxiliary_output_loss: 1.7829 - loss: 2.7797 - main_output_accuracy: 0.5796 - main_output_loss: 2.0665 - val_auxiliary_output_accuracy: 0.3728 - val_auxiliary_output_loss: 3.0575 - val_loss: 4.1383 - val_main_output_accuracy: 0.4178 - val_main_output_loss: 2.9418 - learning_rate: 0.0100
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5395 - auxiliary_output_loss: 1.7617 - loss: 2.7549 - main_output_accuracy: 0.5832 - main_output_loss: 2.0503
# Epoch 60: val_main_output_accuracy did not improve from 0.44010
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.5395 - auxiliary_output_loss: 1.7617 - loss: 2.7549 - main_output_accuracy: 0.5832 - main_output_loss: 2.0503 - val_auxiliary_output_accuracy: 0.3776 - val_auxiliary_output_loss: 2.9719 - val_loss: 3.9570 - val_main_output_accuracy: 0.4392 - val_main_output_loss: 2.7859 - learning_rate: 0.0100
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5425 - auxiliary_output_loss: 1.7491 - loss: 2.7358 - main_output_accuracy: 0.5865 - main_output_loss: 2.0361
# Epoch 61: val_main_output_accuracy did not improve from 0.44010
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.5425 - auxiliary_output_loss: 1.7491 - loss: 2.7358 - main_output_accuracy: 0.5865 - main_output_loss: 2.0361 - val_auxiliary_output_accuracy: 0.3807 - val_auxiliary_output_loss: 2.9842 - val_loss: 4.0939 - val_main_output_accuracy: 0.4229 - val_main_output_loss: 2.9187 - learning_rate: 0.0100
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5467 - auxiliary_output_loss: 1.7338 - loss: 2.7072 - main_output_accuracy: 0.5928 - main_output_loss: 2.0137
# Epoch 62: val_main_output_accuracy did not improve from 0.44010
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5467 - auxiliary_output_loss: 1.7338 - loss: 2.7072 - main_output_accuracy: 0.5928 - main_output_loss: 2.0137 - val_auxiliary_output_accuracy: 0.3826 - val_auxiliary_output_loss: 2.9161 - val_loss: 3.9406 - val_main_output_accuracy: 0.4380 - val_main_output_loss: 2.7934 - learning_rate: 0.0100
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5518 - auxiliary_output_loss: 1.7142 - loss: 2.6803 - main_output_accuracy: 0.5983 - main_output_loss: 1.9946
# Epoch 63: val_main_output_accuracy did not improve from 0.44010
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.5518 - auxiliary_output_loss: 1.7142 - loss: 2.6802 - main_output_accuracy: 0.5983 - main_output_loss: 1.9946 - val_auxiliary_output_accuracy: 0.3560 - val_auxiliary_output_loss: 3.1681 - val_loss: 4.3118 - val_main_output_accuracy: 0.3884 - val_main_output_loss: 3.0572 - learning_rate: 0.0100
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5562 - auxiliary_output_loss: 1.6845 - loss: 2.6532 - main_output_accuracy: 0.6020 - main_output_loss: 1.9794
# Epoch 64: val_main_output_accuracy improved from 0.44010 to 0.44360, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.5562 - auxiliary_output_loss: 1.6845 - loss: 2.6532 - main_output_accuracy: 0.6020 - main_output_loss: 1.9794 - val_auxiliary_output_accuracy: 0.3858 - val_auxiliary_output_loss: 2.9667 - val_loss: 3.9558 - val_main_output_accuracy: 0.4436 - val_main_output_loss: 2.7810 - learning_rate: 0.0100
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5585 - auxiliary_output_loss: 1.6802 - loss: 2.6409 - main_output_accuracy: 0.6071 - main_output_loss: 1.9688
# Epoch 65: val_main_output_accuracy did not improve from 0.44360
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.5585 - auxiliary_output_loss: 1.6802 - loss: 2.6409 - main_output_accuracy: 0.6071 - main_output_loss: 1.9688 - val_auxiliary_output_accuracy: 0.3784 - val_auxiliary_output_loss: 3.0178 - val_loss: 4.0792 - val_main_output_accuracy: 0.4237 - val_main_output_loss: 2.8901 - learning_rate: 0.0100
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5609 - auxiliary_output_loss: 1.6657 - loss: 2.6185 - main_output_accuracy: 0.6087 - main_output_loss: 1.9522
# Epoch 66: val_main_output_accuracy did not improve from 0.44360
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5609 - auxiliary_output_loss: 1.6657 - loss: 2.6185 - main_output_accuracy: 0.6087 - main_output_loss: 1.9522 - val_auxiliary_output_accuracy: 0.3850 - val_auxiliary_output_loss: 2.9746 - val_loss: 4.0409 - val_main_output_accuracy: 0.4322 - val_main_output_loss: 2.8688 - learning_rate: 0.0100
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5628 - auxiliary_output_loss: 1.6520 - loss: 2.5932 - main_output_accuracy: 0.6141 - main_output_loss: 1.9325
# Epoch 67: val_main_output_accuracy did not improve from 0.44360
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5628 - auxiliary_output_loss: 1.6520 - loss: 2.5932 - main_output_accuracy: 0.6141 - main_output_loss: 1.9324 - val_auxiliary_output_accuracy: 0.3791 - val_auxiliary_output_loss: 2.9958 - val_loss: 4.0184 - val_main_output_accuracy: 0.4336 - val_main_output_loss: 2.8445 - learning_rate: 0.0100
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5664 - auxiliary_output_loss: 1.6366 - loss: 2.5686 - main_output_accuracy: 0.6193 - main_output_loss: 1.9140
# Epoch 68: val_main_output_accuracy did not improve from 0.44360
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5664 - auxiliary_output_loss: 1.6366 - loss: 2.5686 - main_output_accuracy: 0.6193 - main_output_loss: 1.9140 - val_auxiliary_output_accuracy: 0.3942 - val_auxiliary_output_loss: 2.9182 - val_loss: 3.9573 - val_main_output_accuracy: 0.4421 - val_main_output_loss: 2.8117 - learning_rate: 0.0100
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5707 - auxiliary_output_loss: 1.6212 - loss: 2.5461 - main_output_accuracy: 0.6257 - main_output_loss: 1.8976
# Epoch 69: val_main_output_accuracy did not improve from 0.44360
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.5708 - auxiliary_output_loss: 1.6212 - loss: 2.5460 - main_output_accuracy: 0.6257 - main_output_loss: 1.8976 - val_auxiliary_output_accuracy: 0.3707 - val_auxiliary_output_loss: 3.1480 - val_loss: 4.3140 - val_main_output_accuracy: 0.4098 - val_main_output_loss: 3.0689 - learning_rate: 0.0100
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5736 - auxiliary_output_loss: 1.6013 - loss: 2.5301 - main_output_accuracy: 0.6259 - main_output_loss: 1.8895
# Epoch 70: val_main_output_accuracy did not improve from 0.44360
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5736 - auxiliary_output_loss: 1.6013 - loss: 2.5300 - main_output_accuracy: 0.6259 - main_output_loss: 1.8895 - val_auxiliary_output_accuracy: 0.3860 - val_auxiliary_output_loss: 3.0332 - val_loss: 4.1443 - val_main_output_accuracy: 0.4202 - val_main_output_loss: 2.9455 - learning_rate: 0.0100
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5770 - auxiliary_output_loss: 1.5952 - loss: 2.5122 - main_output_accuracy: 0.6315 - main_output_loss: 1.8741
# Epoch 71: val_main_output_accuracy did not improve from 0.44360
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.5770 - auxiliary_output_loss: 1.5952 - loss: 2.5122 - main_output_accuracy: 0.6315 - main_output_loss: 1.8741 - val_auxiliary_output_accuracy: 0.3718 - val_auxiliary_output_loss: 3.1420 - val_loss: 4.1827 - val_main_output_accuracy: 0.4195 - val_main_output_loss: 2.9471 - learning_rate: 0.0100
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.5766 - auxiliary_output_loss: 1.5844 - loss: 2.5022 - main_output_accuracy: 0.6312 - main_output_loss: 1.8685
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 72: val_main_output_accuracy did not improve from 0.44360
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.5766 - auxiliary_output_loss: 1.5843 - loss: 2.5022 - main_output_accuracy: 0.6312 - main_output_loss: 1.8684 - val_auxiliary_output_accuracy: 0.3900 - val_auxiliary_output_loss: 2.9522 - val_loss: 4.0086 - val_main_output_accuracy: 0.4375 - val_main_output_loss: 2.8489 - learning_rate: 0.0100
# Epoch 73/100
# ...
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.6294 - auxiliary_output_loss: 1.3777 - loss: 2.1568 - main_output_accuracy: 0.7073 - main_output_loss: 1.6058 - val_auxiliary_output_accuracy: 0.3933 - val_auxiliary_output_loss: 3.1102 - val_loss: 4.0856 - val_main_output_accuracy: 0.4463 - val_main_output_loss: 2.8611 - learning_rate: 0.0050
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6325 - auxiliary_output_loss: 1.3533 - loss: 2.1278 - main_output_accuracy: 0.7098 - main_output_loss: 1.5865
# Epoch 77: val_main_output_accuracy did not improve from 0.46300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.6325 - auxiliary_output_loss: 1.3533 - loss: 2.1277 - main_output_accuracy: 0.7098 - main_output_loss: 1.5864 - val_auxiliary_output_accuracy: 0.4013 - val_auxiliary_output_loss: 3.0462 - val_loss: 4.0290 - val_main_output_accuracy: 0.4565 - val_main_output_loss: 2.8265 - learning_rate: 0.0050
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6320 - auxiliary_output_loss: 1.3451 - loss: 2.1068 - main_output_accuracy: 0.7148 - main_output_loss: 1.5688
# Epoch 78: val_main_output_accuracy did not improve from 0.46300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6320 - auxiliary_output_loss: 1.3451 - loss: 2.1068 - main_output_accuracy: 0.7148 - main_output_loss: 1.5687 - val_auxiliary_output_accuracy: 0.4006 - val_auxiliary_output_loss: 3.0387 - val_loss: 4.0441 - val_main_output_accuracy: 0.4464 - val_main_output_loss: 2.8518 - learning_rate: 0.0050
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6394 - auxiliary_output_loss: 1.3237 - loss: 2.0872 - main_output_accuracy: 0.7185 - main_output_loss: 1.5577
# Epoch 79: val_main_output_accuracy did not improve from 0.46300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6394 - auxiliary_output_loss: 1.3237 - loss: 2.0871 - main_output_accuracy: 0.7185 - main_output_loss: 1.5577 - val_auxiliary_output_accuracy: 0.3898 - val_auxiliary_output_loss: 3.1281 - val_loss: 4.1115 - val_main_output_accuracy: 0.4471 - val_main_output_loss: 2.8874 - learning_rate: 0.0050
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6387 - auxiliary_output_loss: 1.3232 - loss: 2.0656 - main_output_accuracy: 0.7259 - main_output_loss: 1.5363
# Epoch 80: val_main_output_accuracy did not improve from 0.46300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6387 - auxiliary_output_loss: 1.3232 - loss: 2.0656 - main_output_accuracy: 0.7259 - main_output_loss: 1.5363 - val_auxiliary_output_accuracy: 0.4082 - val_auxiliary_output_loss: 3.0461 - val_loss: 4.0277 - val_main_output_accuracy: 0.4566 - val_main_output_loss: 2.8315 - learning_rate: 0.0050
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6419 - auxiliary_output_loss: 1.3056 - loss: 2.0510 - main_output_accuracy: 0.7272 - main_output_loss: 1.5288
# Epoch 81: val_main_output_accuracy did not improve from 0.46300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6419 - auxiliary_output_loss: 1.3056 - loss: 2.0510 - main_output_accuracy: 0.7272 - main_output_loss: 1.5288 - val_auxiliary_output_accuracy: 0.4031 - val_auxiliary_output_loss: 3.0316 - val_loss: 4.0378 - val_main_output_accuracy: 0.4564 - val_main_output_loss: 2.8498 - learning_rate: 0.0050
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6459 - auxiliary_output_loss: 1.2925 - loss: 2.0318 - main_output_accuracy: 0.7321 - main_output_loss: 1.5148
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 82: val_main_output_accuracy did not improve from 0.46300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6459 - auxiliary_output_loss: 1.2925 - loss: 2.0318 - main_output_accuracy: 0.7321 - main_output_loss: 1.5148 - val_auxiliary_output_accuracy: 0.4041 - val_auxiliary_output_loss: 3.0773 - val_loss: 4.0331 - val_main_output_accuracy: 0.4589 - val_main_output_loss: 2.8212 - learning_rate: 0.0050
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6531 - auxiliary_output_loss: 1.2580 - loss: 1.9606 - main_output_accuracy: 0.7496 - main_output_loss: 1.4574
# Epoch 83: val_main_output_accuracy improved from 0.46300 to 0.46330, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 269ms/step - auxiliary_output_accuracy: 0.6531 - auxiliary_output_loss: 1.2580 - loss: 1.9605 - main_output_accuracy: 0.7496 - main_output_loss: 1.4573 - val_auxiliary_output_accuracy: 0.4080 - val_auxiliary_output_loss: 3.0799 - val_loss: 4.0072 - val_main_output_accuracy: 0.4633 - val_main_output_loss: 2.7914 - learning_rate: 0.0025
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6633 - auxiliary_output_loss: 1.2185 - loss: 1.9002 - main_output_accuracy: 0.7632 - main_output_loss: 1.4128
# Epoch 84: val_main_output_accuracy improved from 0.46330 to 0.46830, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.6633 - auxiliary_output_loss: 1.2184 - loss: 1.9002 - main_output_accuracy: 0.7632 - main_output_loss: 1.4128 - val_auxiliary_output_accuracy: 0.4165 - val_auxiliary_output_loss: 3.0649 - val_loss: 3.9950 - val_main_output_accuracy: 0.4683 - val_main_output_loss: 2.7877 - learning_rate: 0.0025
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6697 - auxiliary_output_loss: 1.1923 - loss: 1.8696 - main_output_accuracy: 0.7687 - main_output_loss: 1.3927
# Epoch 85: val_main_output_accuracy did not improve from 0.46830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6697 - auxiliary_output_loss: 1.1923 - loss: 1.8696 - main_output_accuracy: 0.7687 - main_output_loss: 1.3927 - val_auxiliary_output_accuracy: 0.4109 - val_auxiliary_output_loss: 3.0712 - val_loss: 4.0171 - val_main_output_accuracy: 0.4661 - val_main_output_loss: 2.8113 - learning_rate: 0.0025
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6695 - auxiliary_output_loss: 1.1954 - loss: 1.8590 - main_output_accuracy: 0.7737 - main_output_loss: 1.3809
# Epoch 86: val_main_output_accuracy improved from 0.46830 to 0.47430, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.6696 - auxiliary_output_loss: 1.1953 - loss: 1.8590 - main_output_accuracy: 0.7737 - main_output_loss: 1.3808 - val_auxiliary_output_accuracy: 0.4194 - val_auxiliary_output_loss: 2.9868 - val_loss: 3.9175 - val_main_output_accuracy: 0.4743 - val_main_output_loss: 2.7453 - learning_rate: 0.0025
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6741 - auxiliary_output_loss: 1.1678 - loss: 1.8424 - main_output_accuracy: 0.7748 - main_output_loss: 1.3752
# Epoch 87: val_main_output_accuracy did not improve from 0.47430
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6741 - auxiliary_output_loss: 1.1678 - loss: 1.8423 - main_output_accuracy: 0.7748 - main_output_loss: 1.3752 - val_auxiliary_output_accuracy: 0.4159 - val_auxiliary_output_loss: 3.0498 - val_loss: 3.9820 - val_main_output_accuracy: 0.4678 - val_main_output_loss: 2.7873 - learning_rate: 0.0025
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6770 - auxiliary_output_loss: 1.1628 - loss: 1.8289 - main_output_accuracy: 0.7767 - main_output_loss: 1.3638
# Epoch 88: val_main_output_accuracy improved from 0.47430 to 0.47520, saving model to googlenet_exp004_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 211s 269ms/step - auxiliary_output_accuracy: 0.6770 - auxiliary_output_loss: 1.1628 - loss: 1.8289 - main_output_accuracy: 0.7767 - main_output_loss: 1.3637 - val_auxiliary_output_accuracy: 0.4188 - val_auxiliary_output_loss: 3.0482 - val_loss: 3.9650 - val_main_output_accuracy: 0.4752 - val_main_output_loss: 2.7686 - learning_rate: 0.0025
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6766 - auxiliary_output_loss: 1.1657 - loss: 1.8190 - main_output_accuracy: 0.7810 - main_output_loss: 1.3527
# Epoch 89: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6766 - auxiliary_output_loss: 1.1656 - loss: 1.8189 - main_output_accuracy: 0.7810 - main_output_loss: 1.3527 - val_auxiliary_output_accuracy: 0.4139 - val_auxiliary_output_loss: 3.0711 - val_loss: 4.0107 - val_main_output_accuracy: 0.4678 - val_main_output_loss: 2.8054 - learning_rate: 0.0025
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6782 - auxiliary_output_loss: 1.1562 - loss: 1.8035 - main_output_accuracy: 0.7828 - main_output_loss: 1.3410
# Epoch 90: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6782 - auxiliary_output_loss: 1.1562 - loss: 1.8034 - main_output_accuracy: 0.7828 - main_output_loss: 1.3410 - val_auxiliary_output_accuracy: 0.4133 - val_auxiliary_output_loss: 3.1110 - val_loss: 4.0720 - val_main_output_accuracy: 0.4636 - val_main_output_loss: 2.8505 - learning_rate: 0.0025
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6766 - auxiliary_output_loss: 1.1584 - loss: 1.7951 - main_output_accuracy: 0.7871 - main_output_loss: 1.3318
# Epoch 91: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6766 - auxiliary_output_loss: 1.1583 - loss: 1.7951 - main_output_accuracy: 0.7871 - main_output_loss: 1.3317 - val_auxiliary_output_accuracy: 0.4120 - val_auxiliary_output_loss: 3.1314 - val_loss: 4.0931 - val_main_output_accuracy: 0.4575 - val_main_output_loss: 2.8573 - learning_rate: 0.0025
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6797 - auxiliary_output_loss: 1.1466 - loss: 1.7810 - main_output_accuracy: 0.7921 - main_output_loss: 1.3224
# Epoch 92: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6797 - auxiliary_output_loss: 1.1466 - loss: 1.7810 - main_output_accuracy: 0.7921 - main_output_loss: 1.3224 - val_auxiliary_output_accuracy: 0.4132 - val_auxiliary_output_loss: 3.0687 - val_loss: 4.0501 - val_main_output_accuracy: 0.4630 - val_main_output_loss: 2.8422 - learning_rate: 0.0025
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6793 - auxiliary_output_loss: 1.1378 - loss: 1.7683 - main_output_accuracy: 0.7926 - main_output_loss: 1.3132
# Epoch 93: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6794 - auxiliary_output_loss: 1.1378 - loss: 1.7683 - main_output_accuracy: 0.7926 - main_output_loss: 1.3132 - val_auxiliary_output_accuracy: 0.4154 - val_auxiliary_output_loss: 3.1022 - val_loss: 4.0695 - val_main_output_accuracy: 0.4619 - val_main_output_loss: 2.8519 - learning_rate: 0.0025
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6828 - auxiliary_output_loss: 1.1338 - loss: 1.7609 - main_output_accuracy: 0.7940 - main_output_loss: 1.3074
# Epoch 94: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6828 - auxiliary_output_loss: 1.1338 - loss: 1.7609 - main_output_accuracy: 0.7940 - main_output_loss: 1.3074 - val_auxiliary_output_accuracy: 0.4097 - val_auxiliary_output_loss: 3.0656 - val_loss: 4.0411 - val_main_output_accuracy: 0.4647 - val_main_output_loss: 2.8291 - learning_rate: 0.0025
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6864 - auxiliary_output_loss: 1.1205 - loss: 1.7481 - main_output_accuracy: 0.7954 - main_output_loss: 1.2999
# Epoch 95: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6864 - auxiliary_output_loss: 1.1204 - loss: 1.7481 - main_output_accuracy: 0.7954 - main_output_loss: 1.2999 - val_auxiliary_output_accuracy: 0.4135 - val_auxiliary_output_loss: 3.1443 - val_loss: 4.0866 - val_main_output_accuracy: 0.4618 - val_main_output_loss: 2.8483 - learning_rate: 0.0025
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - auxiliary_output_accuracy: 0.6886 - auxiliary_output_loss: 1.1138 - loss: 1.7387 - main_output_accuracy: 0.7977 - main_output_loss: 1.2932
# Epoch 96: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 96: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6886 - auxiliary_output_loss: 1.1137 - loss: 1.7387 - main_output_accuracy: 0.7977 - main_output_loss: 1.2932 - val_auxiliary_output_accuracy: 0.4124 - val_auxiliary_output_loss: 3.1241 - val_loss: 4.0721 - val_main_output_accuracy: 0.4619 - val_main_output_loss: 2.8448 - learning_rate: 0.0025
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6932 - auxiliary_output_loss: 1.1013 - loss: 1.7120 - main_output_accuracy: 0.8069 - main_output_loss: 1.2715
# Epoch 97: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6932 - auxiliary_output_loss: 1.1013 - loss: 1.7120 - main_output_accuracy: 0.8069 - main_output_loss: 1.2715 - val_auxiliary_output_accuracy: 0.4149 - val_auxiliary_output_loss: 3.1073 - val_loss: 4.0616 - val_main_output_accuracy: 0.4650 - val_main_output_loss: 2.8329 - learning_rate: 0.0012
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6968 - auxiliary_output_loss: 1.0824 - loss: 1.6769 - main_output_accuracy: 0.8142 - main_output_loss: 1.2439
# Epoch 98: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6969 - auxiliary_output_loss: 1.0824 - loss: 1.6769 - main_output_accuracy: 0.8142 - main_output_loss: 1.2439 - val_auxiliary_output_accuracy: 0.4202 - val_auxiliary_output_loss: 3.1023 - val_loss: 4.0474 - val_main_output_accuracy: 0.4707 - val_main_output_loss: 2.8240 - learning_rate: 0.0012
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.6995 - auxiliary_output_loss: 1.0688 - loss: 1.6627 - main_output_accuracy: 0.8181 - main_output_loss: 1.2352
# Epoch 99: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.6995 - auxiliary_output_loss: 1.0688 - loss: 1.6627 - main_output_accuracy: 0.8181 - main_output_loss: 1.2352 - val_auxiliary_output_accuracy: 0.4186 - val_auxiliary_output_loss: 3.0831 - val_loss: 4.0356 - val_main_output_accuracy: 0.4659 - val_main_output_loss: 2.8176 - learning_rate: 0.0012
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - auxiliary_output_accuracy: 0.7020 - auxiliary_output_loss: 1.0605 - loss: 1.6521 - main_output_accuracy: 0.8201 - main_output_loss: 1.2279
# Epoch 100: val_main_output_accuracy did not improve from 0.47520
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - auxiliary_output_accuracy: 0.7020 - auxiliary_output_loss: 1.0604 - loss: 1.6521 - main_output_accuracy: 0.8201 - main_output_loss: 1.2279 - val_auxiliary_output_accuracy: 0.4243 - val_auxiliary_output_loss: 3.1036 - val_loss: 4.0199 - val_main_output_accuracy: 0.4706 - val_main_output_loss: 2.7965 - learning_rate: 0.0012
# Restoring model weights from the end of the best epoch: 88.

# %%
best_model = tf.keras.models.load_model('googlenet_exp004_best.keras')
results    = best_model.evaluate(val_ds_dual, verbose=0)
print(f'\nTop-1 — Saída Principal (val): {results[3]*100:.2f}%')
print(f'Top-1 — Saída Auxiliar  (val): {results[4]*100:.2f}%')
# Out:
# Top-1 — Saída Principal (val): 41.88%
# Top-1 — Saída Auxiliar  (val): 47.52%

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['loss'],     label='Train', color='steelblue')
axes[0].plot(history.history['val_loss'], label='Val',   color='tomato')
axes[0].set_title('Loss Total')
axes[0].set_xlabel('Épocas'); axes[0].legend(); axes[0].grid(alpha=0.4)

axes[1].plot(history.history['main_output_accuracy'],     label='Train', color='steelblue')
axes[1].plot(history.history['val_main_output_accuracy'], label='Val',   color='tomato')
axes[1].set_title('Acurácia — Saída Principal')
axes[1].set_xlabel('Épocas'); axes[1].legend(); axes[1].grid(alpha=0.4)

plt.tight_layout()
plt.savefig('training_curves_exp004.png', dpi=150)
plt.show()

# %%
# Carrega words.txt para nomes legíveis
id_to_name = {}
words_file = DATA_DIR / 'words.txt'
if words_file.exists():
    with open(words_file) as f:
        for line in f:
            parts = line.strip().split('\t', 1)
            if len(parts) == 2:
                id_to_name[parts[0]] = parts[1].split(',')[0]

idx_to_name = {i: id_to_name.get(cid, cid) for i, cid in enumerate(CLASS_NAMES)}
print('Mapeamento carregado. Exemplos:')
for i in range(5):
    print(f'  [{i}] {CLASS_NAMES[i]} → {idx_to_name[i]}')
# Out:
# Mapeamento carregado. Exemplos:
#   [0] n01443537 → goldfish
#   [1] n01629819 → European fire salamander
#   [2] n01641577 → bullfrog
#   [3] n01644900 → tailed frog
#   [4] n01698640 → American alligator

# %%
# Coleta predições completas sobre o val set
all_true, all_pred, all_probs = [], [], []
for imgs, (lbls, _) in val_ds_dual:
    lbl_idx = tf.argmax(lbls, axis=1).numpy()
    probs   = best_model(imgs, training=False)[0].numpy()
    all_true.extend(lbl_idx)
    all_pred.extend(np.argmax(probs, axis=1))
    all_probs.append(probs)

all_true  = np.array(all_true)
all_pred  = np.array(all_pred)
all_probs = np.concatenate(all_probs, axis=0)

# Top-5 (corrigido: SparseTopK com labels sparse, não one-hot)
top5_metric = tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5)
top5_metric.update_state(all_true, all_probs)
top5_acc = top5_metric.result().numpy()

per_class_acc = {
    c: (all_pred[all_true == c] == c).mean()
    for c in range(NUM_CLASSES) if (all_true == c).sum() > 0
}
sorted_acc = sorted(per_class_acc.items(), key=lambda x: x[1], reverse=True)

print(f"{'='*50}")
print(f"  Top-1 Accuracy  : {(all_true == all_pred).mean()*100:.2f}%")
print(f"  Top-5 Accuracy  : {top5_acc*100:.2f}%")
print(f"  Média per-class : {np.mean(list(per_class_acc.values()))*100:.2f}%")
print(f"  Melhor classe   : {idx_to_name.get(sorted_acc[0][0])} ({sorted_acc[0][1]*100:.1f}%)")
print(f"  Pior classe     : {idx_to_name.get(sorted_acc[-1][0])} ({sorted_acc[-1][1]*100:.1f}%)")
print(f"{'='*50}")
# Out:
# ==================================================
#   Top-1 Accuracy  : 47.52%
#   Top-5 Accuracy  : 71.91%
#   Média per-class : 47.52%
#   Melhor classe   : school bus (88.0%)
#   Pior classe     : umbrella (8.0%)
# ==================================================

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
for ax, data, title, color in [
    (axes[0], sorted_acc[:20],  'Top-20 (melhor acurácia)', '#2ecc71'),
    (axes[1], sorted_acc[-20:], 'Bottom-20 (pior acurácia)', '#e74c3c'),
]:
    lbls = [idx_to_name.get(c, str(c)) for c, _ in data]
    vals = [v * 100 for _, v in data]
    bars = ax.barh(lbls[::-1], vals[::-1], color=color, alpha=0.8)
    ax.axvline(np.mean(list(per_class_acc.values())) * 100,
               color='gray', linestyle='--', lw=1, label='Média')
    ax.set_xlabel('Acurácia (%)'); ax.set_title(title)
    ax.set_xlim(0, 100); ax.legend(fontsize=8); ax.grid(axis='x', alpha=0.3)
    for bar, val in zip(bars, vals[::-1]):
        ax.text(val + 0.5, bar.get_y() + bar.get_height()/2,
                f'{val:.1f}%', va='center', fontsize=7)

plt.tight_layout()
plt.savefig('per_class_exp004.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
top20_idx = [c for c, _ in sorted(
    ((c, (all_true == c).sum()) for c in range(NUM_CLASSES)), key=lambda x: -x[1]
)[:20]]

mask = np.isin(all_true, top20_idx)
cm   = confusion_matrix(all_true[mask], all_pred[mask], labels=top20_idx)
cm_n = cm.astype(float) / cm.sum(axis=1, keepdims=True)

fig, ax = plt.subplots(figsize=(14, 12))
im = ax.imshow(cm_n, cmap='Blues', vmin=0, vmax=1)
plt.colorbar(im, ax=ax, fraction=0.03)
tick_lbl = [idx_to_name.get(c, str(c))[:12] for c in top20_idx]
ax.set_xticks(range(20)); ax.set_xticklabels(tick_lbl, rotation=45, ha='right', fontsize=7)
ax.set_yticks(range(20)); ax.set_yticklabels(tick_lbl, fontsize=7)
ax.set_title('Confusion Matrix — 20 classes mais frequentes (normalizada)')
ax.set_ylabel('Real'); ax.set_xlabel('Predito')
for i, j in itertools.product(range(20), range(20)):
    if cm_n[i, j] > 0.15:
        ax.text(j, i, f'{cm_n[i,j]:.2f}', ha='center', va='center',
                color='white' if cm_n[i,j] > 0.5 else 'black', fontsize=6)
plt.tight_layout()
plt.savefig('confusion_matrix_exp004.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
N, COLS = 20, 5
ROWS = math.ceil(N / COLS)

sample_imgs, (sample_lbls, _) = next(iter(val_ds_dual))
sample_imgs = sample_imgs[:N]
true_idx    = tf.argmax(sample_lbls[:N], axis=1).numpy()
probs_main  = best_model(sample_imgs, training=False)[0].numpy()
pred_idx    = np.argmax(probs_main, axis=1)
confs       = np.max(probs_main, axis=1)

fig, axes = plt.subplots(ROWS, COLS, figsize=(COLS*3, ROWS*3.4))
for i, ax in enumerate(axes.flat[:N]):
    correct = true_idx[i] == pred_idx[i]
    cor = '#2ecc71' if correct else '#e74c3c'
    ax.imshow(sample_imgs[i].numpy())
    for s in ax.spines.values():
        s.set_edgecolor(cor); s.set_linewidth(4)
    ax.set_title(
        f"Real: {idx_to_name.get(true_idx[i], '')}\n"
        f"Pred: {idx_to_name.get(pred_idx[i], '')}\n{confs[i]*100:.1f}%",
        fontsize=7.5, color=cor, pad=3
    )
    ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
for ax in axes.flat[N:]:
    ax.axis('off')

n_ok = (true_idx == pred_idx).sum()
fig.legend(handles=[
    mpatches.Patch(color='#2ecc71', label='Acerto'),
    mpatches.Patch(color='#e74c3c', label='Erro')
], loc='lower center', ncol=2, fontsize=10, bbox_to_anchor=(0.5, 0), frameon=False)
fig.suptitle(f'Real vs. Predito — {n_ok}/{N} corretos ({n_ok/N*100:.0f}%)', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('real_vs_predito_exp004.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# URLs de imagens públicas cobrindo classes presentes no Tiny ImageNet
TEST_URLS = [
    # goldfish (n01443537)
    ('goldfish',      'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Goldfish3.jpg/320px-Goldfish3.jpg'),
    # tabby cat (n02123045)
    ('tabby cat',     'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Cat_November_2010-1a.jpg/320px-Cat_November_2010-1a.jpg'),
    # ant (n02165456)
    ('ant',           'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Camponotus_flavomarginatus_ant.jpg/320px-Camponotus_flavomarginatus_ant.jpg'),
    # school bus (n04376876)
    ('school bus',    'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Iconbus.jpg/320px-Iconbus.jpg'),
    # Egyptian cat (n02124075)
    ('Egyptian cat',  'https://upload.wikimedia.org/wikipedia/commons/thumb/9/94/Sobekhotep_IV_MET_44.4.21.jpg/320px-Sobekhotep_IV_MET_44.4.21.jpg'),
    # monarch butterfly (n02281406)
    ('monarch',       'https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Monarch_Butterfly_Danaus_plexippus_on_Echinacea_purpurea_1.jpg/320px-Monarch_Butterfly_Danaus_plexippus_on_Echinacea_purpurea_1.jpg'),
]

def predict_url(label, url, top_k=5):
    """Baixa imagem, redimensiona para IMG_SIZE e exibe top-k predições."""
    try:
        r   = requests.get(url, timeout=10, headers={'User-Agent': 'Mozilla/5.0'})
        img = Image.open(BytesIO(r.content)).convert('RGB')
        img_r = img.resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)
        arr   = np.array(img_r, dtype=np.float32)[None] / 255.0

        probs     = best_model(arr, training=False)[0][0].numpy()
        top_idx   = np.argsort(probs)[::-1][:top_k]

        fig, axes = plt.subplots(1, 2, figsize=(8, 3.5),
                                 gridspec_kw={'width_ratios': [1, 2]})
        axes[0].imshow(img_r); axes[0].axis('off')
        axes[0].set_title(f'[esperado: {label}]', fontsize=8, color='gray')

        names = [idx_to_name.get(i, str(i)) for i in top_idx]
        vals  = [probs[i]*100 for i in top_idx]
        colors = ['#2ecc71' if label.lower() in n.lower() else '#5b8dd9' for n in names]
        axes[1].barh(names[::-1], vals[::-1], color=colors[::-1])
        axes[1].set_xlabel('Confiança (%)')
        axes[1].set_title('Top-5 Predições')
        axes[1].set_xlim(0, 100)

        plt.suptitle(f'Predição externa — {label}', fontsize=10)
        plt.tight_layout()
        plt.show()

        print(f'  Top-1: {names[0]} ({vals[0]:.1f}%) | esperado: {label}')
    except Exception as e:
        print(f'  Erro ({label}): {e}')

for lbl, url in TEST_URLS:
    predict_url(lbl, url)
# Out:
#   Erro (goldfish): cannot identify image file <_io.BytesIO object at 0x7896ea56f9c0>
#   Erro (tabby cat): cannot identify image file <_io.BytesIO object at 0x7896ea5804a0>
#   Erro (ant): cannot identify image file <_io.BytesIO object at 0x789700f2e2f0>
#   Erro (school bus): cannot identify image file <_io.BytesIO object at 0x789700f2e2f0>
#   Erro (Egyptian cat): cannot identify image file <_io.BytesIO object at 0x7896eaba8040>
#   Erro (monarch): cannot identify image file <_io.BytesIO object at 0x7896eac47560>

# %%
EXPERIMENTO['resultado_top1'] = round(float(results[3]) * 100, 2)
EXPERIMENTO['resultado_top5'] = round(float(top5_acc) * 100, 2)
EXPERIMENTO['epocas']         = len(history.history['loss'])

log_path   = 'experimentos_log.csv'
fieldnames = ['id', 'hipotese', 'mudancas', 'resultado_top1', 'resultado_top5', 'epocas', 'timestamp']
row = {
    **EXPERIMENTO,
    'mudancas':  ' | '.join(EXPERIMENTO['mudancas']),
    'timestamp': datetime.datetime.now().isoformat(),
}
file_exists = os.path.isfile(log_path)
with open(log_path, 'a', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    if not file_exists:
        writer.writeheader()
    writer.writerow(row)

print(f'✓ {EXPERIMENTO["id"]} salvo em {log_path}')
print(f'  Top-1: {EXPERIMENTO["resultado_top1"]}% | Top-5: {EXPERIMENTO["resultado_top5"]}% | Épocas: {EXPERIMENTO["epocas"]}')
# Out:
# ✓ exp_004 salvo em experimentos_log.csv
#   Top-1: 41.88% | Top-5: 71.91% | Épocas: 100

# %% [markdown]
# ## Resumo — exp_004
#
# | Métrica | Baseline | EXP01 | EXP02 | EXP03 ❌ | **EXP04** |
# |---|---|---|---|---|---|
# | Top-1 val (principal) | 39.88% | 40.08% | 39.29% | 0.50% | *(preencher)* |
# | Top-1 val (auxiliar) | — | 44.76% | 46.58% | 2.50% | *(preencher)* |
# | Top-5 val | — | 71.05% | 71.79% | 2.50% | *(preencher)* |
# | Épocas | — | 66 | 94 | 16 | *(preencher)* |
#
# **Mudanças acumuladas vs baseline:**
# - `inception_5a/5b`: canais reduzidos ~30% (exp_001)
# - `main_dropout`: 0.4 → 0.55 (exp_002)
# - `label_smoothing`: 0.05 **só na main_output** (exp_004 — corrige colapso do exp_003)
# - `loss_weight` auxiliar: 0.3 → 0.4 (exp_004)
# - `scheduler`: ReduceLROnPlateau patience=8 (exp_004)
# - `early_stopping`: patience=20 (exp_004)
# - `LR warmup`: 5 épocas de 0.001 → 0.01 (exp_004)
# - `augmentation`: revertido ao nível do exp_002 (exp_004)
#
# **Post-mortem exp_003:**
# > Label smoothing=0.1 em ambas as saídas + ReduceLROnPlateau com patience=5 causaram
# > colapso de gradiente desde a época 1. O modelo ficou preso no baseline aleatório (0.5%)
# > e o LR foi cortado 3× antes do EarlyStopping encerrar na época 16.
