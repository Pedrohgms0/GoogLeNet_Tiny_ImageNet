# %% [markdown]
# # GoogLeNet (InceptionV1) — Tiny ImageNet
#
# **Dataset:** Tiny ImageNet (Stanford) — 200 classes, 64×64px, 100k imagens de treino + 10k de validação
# **Arquitetura:** GoogLeNet/InceptionV1 adaptado para imagens 64×64
# **Ambiente recomendado:** Kaggle (GPU T4/P100) ou Google Colab (GPU)
#
# ---
# ### Diferenças em relação à versão CIFAR-10
# | Aspecto | CIFAR-10 | Tiny ImageNet |
# |---|---|---|
# | Resolução | 32×32 | 64×64 |
# | Classes | 10 | 200 |
# | Treino | 50k | 100k |
# | Stem | kernel 7×7 (agressivo) | kernel 3×3 (preserva resolução) |
# | Módulos Inception | 4 | 7 |
# | Saída | softmax(10) | softmax(200) |

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import cv2
import os
import zipfile
import requests
from PIL import Image
from io import BytesIO
from pathlib import Path

print(f"TensorFlow: {tf.__version__}")
print(f"GPUs disponíveis: {tf.config.list_physical_devices('GPU')}")
# Out:
# 2026-04-27 22:20:22.973046: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777328423.179090      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777328423.233826      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777328423.698312      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777328423.698352      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777328423.698354      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777328423.698357      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow: 2.19.0
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Configurações Globais

# %%
# ── Hiperparâmetros ──────────────────────────────────────────────────────────
EPOCHS          = 100          # Tiny ImageNet converge bem em ~80-100 épocas
BATCH_SIZE      = 128          # Ajuste para 64 se der OOM na GPU
NUM_CLASSES     = 200          # Tiny ImageNet tem 200 classes
IMG_SIZE        = 64           # Resolução nativa do Tiny ImageNet
INITIAL_LR     = 0.01
LR_DROP_FACTOR = 0.96
LR_DROP_PERIOD = 5
USE_AUGMENTATION = True

# ── Reprodutibilidade ────────────────────────────────────────────────────────
tf.random.set_seed(42)
np.random.seed(42)

print(f"Configuração: {EPOCHS} épocas | batch {BATCH_SIZE} | {IMG_SIZE}×{IMG_SIZE} | {NUM_CLASSES} classes")
# Out:
# Configuração: 100 épocas | batch 128 | 64×64 | 200 classes

# %% [markdown]
# ## Download e Extração do Tiny ImageNet
#
# O Tiny ImageNet está hospedado na Stanford. Fazemos o download (~236 MB), extraímos e reorganizamos a pasta de validação (que vem em formato diferente do treino).

# %%
TINY_URL  = 'http://cs231n.stanford.edu/tiny-imagenet-200.zip'
DATA_DIR  = Path('/kaggle/working/tiny-imagenet-200')   # ajuste se necessário
ZIP_PATH  = Path('/kaggle/working/tiny-imagenet-200.zip')

# ── Download ─────────────────────────────────────────────────────────────────
if not ZIP_PATH.exists():
    print('Baixando Tiny ImageNet (~236 MB)...')
    r = requests.get(TINY_URL, stream=True)
    total = int(r.headers.get('content-length', 0))
    downloaded = 0
    with open(ZIP_PATH, 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024*1024):
            f.write(chunk)
            downloaded += len(chunk)
            print(f'\r  {downloaded/1e6:.1f}/{total/1e6:.1f} MB', end='')
    print('\nDownload completo!')
else:
    print('ZIP já existe, pulando download.')

# ── Extração ─────────────────────────────────────────────────────────────────
if not DATA_DIR.exists():
    print('Extraindo...')
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall('/kaggle/working')
    print('Extração concluída.')
else:
    print('Diretório já existe, pulando extração.')

print(f'Dataset em: {DATA_DIR}')
# Out:
# Baixando Tiny ImageNet (~236 MB)...
#   248.1/248.1 MB
# Download completo!
# Extraindo...
# Extração concluída.
# Dataset em: /kaggle/working/tiny-imagenet-200

# %%
# ── Reorganiza pasta de validação ─────────────────────────────────────────────
# A pasta val do Tiny ImageNet coloca todas as imagens numa pasta flat com um
# arquivo val_annotations.txt indicando a classe de cada imagem.
# Aqui reorganizamos para o formato class/image.JPEG que o Keras espera.

import shutil

val_dir        = DATA_DIR / 'val'
val_img_dir    = val_dir / 'images'
val_annot_file = val_dir / 'val_annotations.txt'
val_organized  = DATA_DIR / 'val_organized'

if not val_organized.exists():
    print('Reorganizando val/ para estrutura class/image...')
    val_organized.mkdir(parents=True)
    with open(val_annot_file, 'r') as f:
        for line in f:
            parts = line.strip().split('\t')
            fname, class_id = parts[0], parts[1]
            class_dir = val_organized / class_id
            class_dir.mkdir(exist_ok=True)
            shutil.copy(val_img_dir / fname, class_dir / fname)
    print(f'Validação reorganizada: {len(list(val_organized.iterdir()))} classes')
else:
    print('val_organized já existe.')

TRAIN_DIR = DATA_DIR / 'train'
VAL_DIR   = val_organized
print(f'Treino: {TRAIN_DIR}')
print(f'Val:    {VAL_DIR}')
# Out:
# Reorganizando val/ para estrutura class/image...
# Validação reorganizada: 200 classes
# Treino: /kaggle/working/tiny-imagenet-200/train
# Val:    /kaggle/working/tiny-imagenet-200/val_organized

# %% [markdown]
# ## Pipeline de Dados com `image_dataset_from_directory`
#
# Usamos a API do Keras para criar datasets eficientes (sem carregar tudo na RAM).

# %%
# ── Carregamento ──────────────────────────────────────────────────────────────
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    shuffle=True,
    seed=42
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    shuffle=False
)

CLASS_NAMES = train_ds.class_names
print(f'Classes encontradas: {len(CLASS_NAMES)}')
print(f'Primeiras 5: {CLASS_NAMES[:5]}')

# Guarda o mapeamento class_id → índice para uso na predição
class_to_idx = {name: i for i, name in enumerate(CLASS_NAMES)}
# Out:
# Found 100000 files belonging to 200 classes.
# I0000 00:00:1777328472.748056      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 10000 files belonging to 200 classes.
# Classes encontradas: 200
# Primeiras 5: ['n01443537', 'n01629819', 'n01641577', 'n01644900', 'n01698640']

# %%
# ── Normalização e Augmentation ───────────────────────────────────────────────
def normalize(image, label):
    """Normaliza pixel [0,255] → [0,1]."""
    return tf.cast(image, tf.float32) / 255.0, label

train_ds = train_ds.map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
val_ds   = val_ds.map(normalize,   num_parallel_calls=tf.data.AUTOTUNE)

if USE_AUGMENTATION:
    augment = tf.keras.Sequential([
        tf.keras.layers.RandomFlip('horizontal'),
        tf.keras.layers.RandomRotation(0.1),
        tf.keras.layers.RandomTranslation(0.1, 0.1),
        tf.keras.layers.RandomZoom(0.1),
        tf.keras.layers.RandomContrast(0.1),
    ], name='augmentation')

    def augment_fn(image, label):
        return augment(image, training=True), label

    train_ds = train_ds.map(augment_fn, num_parallel_calls=tf.data.AUTOTUNE)

# Prefetch para sobreposição CPU/GPU
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds   = val_ds.prefetch(tf.data.AUTOTUNE)

print('Pipelines de dados prontos.')
# Out:
# Pipelines de dados prontos.

# %% [markdown]
# ## Visualização de Amostras do Dataset

# %%
# Exibe 16 imagens de treino com seus rótulos
fig, axes = plt.subplots(4, 4, figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i].numpy())
        class_idx = np.argmax(labels[i].numpy())
        ax.set_title(CLASS_NAMES[class_idx], fontsize=8)
        ax.axis('off')
plt.suptitle('Amostras do Treino — Tiny ImageNet', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.10614884..1.0348514].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03697613..1.0043912].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0004005].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0092857].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0024749339..1.0240843].

# %% [markdown]
# ## Módulo Inception
#
# O módulo permanece idêntico ao original — 4 ramos paralelos (1×1, 3×3, 5×5, pool+proj) concatenados no eixo de canais.

# %%
def inception_module(x, filters_1x1, filters_3x3_reduce, filters_3x3,
                     filters_5x5_reduce, filters_5x5, filters_pool_proj, name=None):
    """Módulo Inception com 4 ramos paralelos (Szegedy et al., 2014)."""
    kw_init = 'glorot_uniform'
    b_init  = tf.keras.initializers.Constant(0.2)

    # Ramo 1 — convolução 1×1
    b1 = tf.keras.layers.Conv2D(
        filters_1x1, (1, 1), padding='same', activation='relu',
        kernel_initializer=kw_init, bias_initializer=b_init,
        name=f'{name}_1x1')(x)

    # Ramo 2 — redução 1×1 → convolução 3×3
    b2 = tf.keras.layers.Conv2D(
        filters_3x3_reduce, (1, 1), padding='same', activation='relu',
        kernel_initializer=kw_init, bias_initializer=b_init,
        name=f'{name}_3x3_reduce')(x)
    b2 = tf.keras.layers.Conv2D(
        filters_3x3, (3, 3), padding='same', activation='relu',
        kernel_initializer=kw_init, bias_initializer=b_init,
        name=f'{name}_3x3')(b2)

    # Ramo 3 — redução 1×1 → convolução 5×5
    b3 = tf.keras.layers.Conv2D(
        filters_5x5_reduce, (1, 1), padding='same', activation='relu',
        kernel_initializer=kw_init, bias_initializer=b_init,
        name=f'{name}_5x5_reduce')(x)
    b3 = tf.keras.layers.Conv2D(
        filters_5x5, (5, 5), padding='same', activation='relu',
        kernel_initializer=kw_init, bias_initializer=b_init,
        name=f'{name}_5x5')(b3)

    # Ramo 4 — MaxPool 3×3 → projeção 1×1
    b4 = tf.keras.layers.MaxPooling2D(
        (3, 3), strides=(1, 1), padding='same',
        name=f'{name}_pool')(x)
    b4 = tf.keras.layers.Conv2D(
        filters_pool_proj, (1, 1), padding='same', activation='relu',
        kernel_initializer=kw_init, bias_initializer=b_init,
        name=f'{name}_pool_proj')(b4)

    return tf.keras.layers.Concatenate(axis=-1, name=name)([b1, b2, b3, b4])

# %% [markdown]
# ## Construção do Modelo — GoogLeNet adaptado para 64×64
#
# ### Decisões de projeto
#
# **Stem:** O GoogLeNet original usa kernel 7×7 stride-2 → MaxPool stride-2 → MaxPool stride-2, o que reduz 224→28px. Aplicar isso a imagens 64×64 colapsaria o mapa para apenas ~4px antes do primeiro módulo Inception, destruindo informação espacial. Solução: substituímos o kernel 7×7 por dois blocos 3×3 consecutivos com stride-1 e mantemos apenas **um** MaxPool stride-2, preservando um mapa de 32×32 antes dos Inceptions.
#
# **Classificador Auxiliar:** Posicionado após o bloco Inception 4a, com peso 0.3 na loss, igual ao paper original.
#
# **Camadas Inception:** 7 módulos (3a, 3b, 4a, 4b, 4c, 4d, 4e) vs. 4 na versão CIFAR-10.

# %%
inputs = tf.keras.layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name='input_layer')

# ── Stem ─────────────────────────────────────────────────────────────────────
# Adaptado para 64×64: dois Conv 3×3 (sem stride agressivo) + 1 MaxPool
# 64 → 64 → 64 → 32px
x = tf.keras.layers.Conv2D(
    64, (3, 3), strides=(1, 1), padding='same', activation='relu',
    kernel_initializer='glorot_uniform',
    bias_initializer=tf.keras.initializers.Constant(0.2),
    name='stem_conv1')(inputs)
x = tf.keras.layers.Conv2D(
    64, (3, 3), padding='same', activation='relu',
    kernel_initializer='glorot_uniform',
    bias_initializer=tf.keras.initializers.Constant(0.2),
    name='stem_conv2')(x)
x = tf.keras.layers.Conv2D(
    192, (3, 3), padding='same', activation='relu',
    kernel_initializer='glorot_uniform',
    bias_initializer=tf.keras.initializers.Constant(0.2),
    name='stem_conv3')(x)
x = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='stem_pool')(x)
# Saída do stem: 32×32×192

# ── Bloco Inception 3 ────────────────────────────────────────────────────────
# Filtros iguais ao GoogLeNet original
x = inception_module(x, 64,  96, 128, 16,  32,  32,  name='inception_3a')
x = inception_module(x, 128, 128, 192, 32,  96,  64,  name='inception_3b')
x = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='pool_3')(x)
# 32×32 → 16×16

# ── Bloco Inception 4 ────────────────────────────────────────────────────────
x = inception_module(x, 192, 96,  208, 16, 48, 64,  name='inception_4a')

# Classificador Auxiliar — inserido após 4a (como no paper)
aux = tf.keras.layers.AveragePooling2D((5, 5), strides=3, padding='same', name='aux_avgpool')(x)
aux = tf.keras.layers.Conv2D(128, (1, 1), padding='same', activation='relu', name='aux_conv')(aux)
aux = tf.keras.layers.Flatten(name='aux_flatten')(aux)
aux = tf.keras.layers.Dense(1024, activation='relu', name='aux_dense1')(aux)
aux = tf.keras.layers.Dropout(0.3, name='aux_dropout')(aux)
aux_out = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax', name='auxiliary_output')(aux)

x = inception_module(x, 160, 112, 224, 24, 64, 64,  name='inception_4b')
x = inception_module(x, 128, 128, 256, 24, 64, 64,  name='inception_4c')
x = inception_module(x, 112, 144, 288, 32, 64, 64,  name='inception_4d')
x = inception_module(x, 256, 160, 320, 32, 128, 128, name='inception_4e')
x = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='pool_4')(x)
# 16×16 → 8×8

# ── Bloco Inception 5 ────────────────────────────────────────────────────────
x = inception_module(x, 256, 160, 320, 32, 128, 128, name='inception_5a')
x = inception_module(x, 384, 192, 384, 48, 128, 128, name='inception_5b')

# ── Cabeça de Classificação ───────────────────────────────────────────────────
x = tf.keras.layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
x = tf.keras.layers.Dropout(0.4, name='main_dropout')(x)
main_out = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax', name='main_output')(x)

# ── Modelo ────────────────────────────────────────────────────────────────────
model = tf.keras.Model(
    inputs=inputs,
    outputs=[main_out, aux_out],
    name='GoogLeNet_TinyImageNet'
)
model.summary()
# Out:
# Model: "GoogLeNet_TinyImageNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv1 (Conv2D) │ (None, 64, 64,    │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv2 (Conv2D) │ (None, 64, 64,    │     36,928 │ stem_conv1[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv3 (Conv2D) │ (None, 64, 64,    │    110,784 │ stem_conv2[0][0]  │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_pool           │ (None, 32, 32,    │          0 │ stem_conv3[0][0]  │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3_r… │ (None, 32, 32,    │     18,528 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5_r… │ (None, 32, 32,    │      3,088 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool   │ (None, 32, 32,    │          0 │ stem_pool[0][0]   │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_1x1    │ (None, 32, 32,    │     12,352 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3    │ (None, 32, 32,    │    110,720 │ inception_3a_3x3… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5    │ (None, 32, 32,    │     12,832 │ inception_3a_5x5… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool_… │ (None, 32, 32,    │      6,176 │ inception_3a_poo… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a        │ (None, 32, 32,    │          0 │ inception_3a_1x1… │
# │ (Concatenate)       │ 256)              │            │ inception_3a_3x3… │
# │                     │                   │            │ inception_3a_5x5… │
# │                     │                   │            │ inception_3a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3_r… │ (None, 32, 32,    │     32,896 │ inception_3a[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5_r… │ (None, 32, 32,    │      8,224 │ inception_3a[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool   │ (None, 32, 32,    │          0 │ inception_3a[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_1x1    │ (None, 32, 32,    │     32,896 │ inception_3a[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3    │ (None, 32, 32,    │    221,376 │ inception_3b_3x3… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5    │ (None, 32, 32,    │     76,896 │ inception_3b_5x5… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool_… │ (None, 32, 32,    │     16,448 │ inception_3b_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b        │ (None, 32, 32,    │          0 │ inception_3b_1x1… │
# │ (Concatenate)       │ 480)              │            │ inception_3b_3x3… │
# │                     │                   │            │ inception_3b_5x5… │
# │                     │                   │            │ inception_3b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_3              │ (None, 16, 16,    │          0 │ inception_3b[0][… │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3_r… │ (None, 16, 16,    │     46,176 │ pool_3[0][0]      │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5_r… │ (None, 16, 16,    │      7,696 │ pool_3[0][0]      │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool   │ (None, 16, 16,    │          0 │ pool_3[0][0]      │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_1x1    │ (None, 16, 16,    │     92,352 │ pool_3[0][0]      │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3    │ (None, 16, 16,    │    179,920 │ inception_4a_3x3… │
# │ (Conv2D)            │ 208)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5    │ (None, 16, 16,    │     19,248 │ inception_4a_5x5… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool_… │ (None, 16, 16,    │     30,784 │ inception_4a_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a        │ (None, 16, 16,    │          0 │ inception_4a_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4a_3x3… │
# │                     │                   │            │ inception_4a_5x5… │
# │                     │                   │            │ inception_4a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_3x3_r… │ (None, 16, 16,    │     57,456 │ inception_4a[0][… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_5x5_r… │ (None, 16, 16,    │     12,312 │ inception_4a[0][… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_pool   │ (None, 16, 16,    │          0 │ inception_4a[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_1x1    │ (None, 16, 16,    │     82,080 │ inception_4a[0][… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_3x3    │ (None, 16, 16,    │    226,016 │ inception_4b_3x3… │
# │ (Conv2D)            │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_5x5    │ (None, 16, 16,    │     38,464 │ inception_4b_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_pool_… │ (None, 16, 16,    │     32,832 │ inception_4b_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b        │ (None, 16, 16,    │          0 │ inception_4b_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4b_3x3… │
# │                     │                   │            │ inception_4b_5x5… │
# │                     │                   │            │ inception_4b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_3x3_r… │ (None, 16, 16,    │     65,664 │ inception_4b[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_5x5_r… │ (None, 16, 16,    │     12,312 │ inception_4b[0][… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_pool   │ (None, 16, 16,    │          0 │ inception_4b[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_1x1    │ (None, 16, 16,    │     65,664 │ inception_4b[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_3x3    │ (None, 16, 16,    │    295,168 │ inception_4c_3x3… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_5x5    │ (None, 16, 16,    │     38,464 │ inception_4c_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_pool_… │ (None, 16, 16,    │     32,832 │ inception_4c_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c        │ (None, 16, 16,    │          0 │ inception_4c_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4c_3x3… │
# │                     │                   │            │ inception_4c_5x5… │
# │                     │                   │            │ inception_4c_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_3x3_r… │ (None, 16, 16,    │     73,872 │ inception_4c[0][… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_5x5_r… │ (None, 16, 16,    │     16,416 │ inception_4c[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_pool   │ (None, 16, 16,    │          0 │ inception_4c[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_1x1    │ (None, 16, 16,    │     57,456 │ inception_4c[0][… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_3x3    │ (None, 16, 16,    │    373,536 │ inception_4d_3x3… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_5x5    │ (None, 16, 16,    │     51,264 │ inception_4d_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_pool_… │ (None, 16, 16,    │     32,832 │ inception_4d_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d        │ (None, 16, 16,    │          0 │ inception_4d_1x1… │
# │ (Concatenate)       │ 528)              │            │ inception_4d_3x3… │
# │                     │                   │            │ inception_4d_5x5… │
# │                     │                   │            │ inception_4d_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3_r… │ (None, 16, 16,    │     84,640 │ inception_4d[0][… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5_r… │ (None, 16, 16,    │     16,928 │ inception_4d[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_pool   │ (None, 16, 16,    │          0 │ inception_4d[0][… │
# │ (MaxPooling2D)      │ 528)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_1x1    │ (None, 16, 16,    │    135,424 │ inception_4d[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3    │ (None, 16, 16,    │    461,120 │ inception_4e_3x3… │
# │ (Conv2D)            │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5    │ (None, 16, 16,    │    102,528 │ inception_4e_5x5… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_pool_… │ (None, 16, 16,    │     67,712 │ inception_4e_poo… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e        │ (None, 16, 16,    │          0 │ inception_4e_1x1… │
# │ (Concatenate)       │ 832)              │            │ inception_4e_3x3… │
# │                     │                   │            │ inception_4e_5x5… │
# │                     │                   │            │ inception_4e_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_4              │ (None, 8, 8, 832) │          0 │ inception_4e[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3_r… │ (None, 8, 8, 160) │    133,280 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_5x5_r… │ (None, 8, 8, 32)  │     26,656 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool   │ (None, 8, 8, 832) │          0 │ pool_4[0][0]      │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_1x1    │ (None, 8, 8, 256) │    213,248 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3    │ (None, 8, 8, 320) │    461,120 │ inception_5a_3x3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_5x5    │ (None, 8, 8, 128) │    102,528 │ inception_5a_5x5… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool_… │ (None, 8, 8, 128) │    106,624 │ inception_5a_poo… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a        │ (None, 8, 8, 832) │          0 │ inception_5a_1x1… │
# │ (Concatenate)       │                   │            │ inception_5a_3x3… │
# │                     │                   │            │ inception_5a_5x5… │
# │                     │                   │            │ inception_5a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3_r… │ (None, 8, 8, 192) │    159,936 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_5x5_r… │ (None, 8, 8, 48)  │     39,984 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool   │ (None, 8, 8, 832) │          0 │ inception_5a[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_avgpool         │ (None, 6, 6, 512) │          0 │ inception_4a[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_1x1    │ (None, 8, 8, 384) │    319,872 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3    │ (None, 8, 8, 384) │    663,936 │ inception_5b_3x3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_5x5    │ (None, 8, 8, 128) │    153,728 │ inception_5b_5x5… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool_… │ (None, 8, 8, 128) │    106,624 │ inception_5b_poo… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_conv (Conv2D)   │ (None, 6, 6, 128) │     65,664 │ aux_avgpool[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b        │ (None, 8, 8,      │          0 │ inception_5b_1x1… │
# │ (Concatenate)       │ 1024)             │            │ inception_5b_3x3… │
# │                     │                   │            │ inception_5b_5x5… │
# │                     │                   │            │ inception_5b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_flatten         │ (None, 4608)      │          0 │ aux_conv[0][0]    │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_avg_pool     │ (None, 1024)      │          0 │ inception_5b[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_dense1 (Dense)  │ (None, 1024)      │  4,719,616 │ aux_flatten[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_dropout        │ (None, 1024)      │          0 │ global_avg_pool[… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_dropout         │ (None, 1024)      │          0 │ aux_dense1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_output (Dense) │ (None, 200)       │    205,000 │ main_dropout[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ auxiliary_output    │ (None, 200)       │    205,000 │ aux_dropout[0][0] │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,193,920 (42.70 MB)
#  Trainable params: 11,193,920 (42.70 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compilação e Callbacks

# %%
model.compile(
    optimizer=tf.keras.optimizers.SGD(
        learning_rate=INITIAL_LR, momentum=0.9, nesterov=True
    ),
    loss={
        'main_output': 'categorical_crossentropy',
        'auxiliary_output': 'categorical_crossentropy'
    },
    loss_weights={'main_output': 1.0, 'auxiliary_output': 0.3},
    metrics={
        'main_output': ['accuracy'],
        'auxiliary_output': ['accuracy']
    }
)
print("Modelo compilado com sucesso!")
# Out:
# Modelo compilado com sucesso!

# %%
# ── Learning Rate Scheduler ───────────────────────────────────────────────────
def lr_scheduler(epoch):
    return INITIAL_LR * (LR_DROP_FACTOR ** int((epoch + 1) / LR_DROP_PERIOD))

lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler, verbose=1)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_main_output_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1,
    mode='max'          # CORREÇÃO
)

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'googlenet_tinyimagenet_best.keras',
    monitor='val_main_output_accuracy',
    save_best_only=True,
    verbose=1,
    mode='max'          # CORREÇÃO
)

csv_logger = tf.keras.callbacks.CSVLogger('training_log.csv')

# %% [markdown]
# ## Treinamento
#
# > **Nota sobre o dataset com 2 saídas:** Como o modelo tem `[main_output, auxiliary_output]`, precisamos passar os labels duas vezes em cada batch. Fazemos isso com um dataset wrapper que duplica os labels.

# %%
# Duplica os labels para as 2 saídas do modelo
def duplicate_labels(image, label):
    return image, (label, label)

train_ds_dual = train_ds.map(duplicate_labels)
val_ds_dual   = val_ds.map(duplicate_labels)

print(f'Iniciando treinamento — {EPOCHS} épocas máx.')
history = model.fit(
    train_ds_dual,
    validation_data=val_ds_dual,
    epochs=EPOCHS,
    callbacks=[lr_callback, early_stop, checkpoint, csv_logger],
    verbose=1
)
# Out:
# Iniciando treinamento — 100 épocas máx.
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777328486.151691      73 service.cc:152] XLA service 0x7ca31c002de0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777328486.151738      73 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1777328488.027448      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1777328522.007165      73 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - auxiliary_output_accuracy: 0.0046 - auxiliary_output_loss: 5.3057 - loss: 6.9214 - main_output_accuracy: 0.0050 - main_output_loss: 5.3297
# Epoch 1: val_main_output_accuracy improved from -inf to 0.00500, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 291s 317ms/step - auxiliary_output_accuracy: 0.0046 - auxiliary_output_loss: 5.3057 - loss: 6.9214 - main_output_accuracy: 0.0050 - main_output_loss: 5.3297 - val_auxiliary_output_accuracy: 0.0051 - val_auxiliary_output_loss: 5.2983 - val_loss: 6.8878 - val_main_output_accuracy: 0.0050 - val_main_output_loss: 5.2981 - learning_rate: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.0048 - auxiliary_output_loss: 5.2983 - loss: 6.8884 - main_output_accuracy: 0.0041 - main_output_loss: 5.2989
# Epoch 2: val_main_output_accuracy did not improve from 0.00500
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.0048 - auxiliary_output_loss: 5.2983 - loss: 6.8884 - main_output_accuracy: 0.0041 - main_output_loss: 5.2989 - val_auxiliary_output_accuracy: 0.0047 - val_auxiliary_output_loss: 5.2960 - val_loss: 6.8869 - val_main_output_accuracy: 0.0050 - val_main_output_loss: 5.2981 - learning_rate: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.0091 - auxiliary_output_loss: 5.2532 - loss: 6.8511 - main_output_accuracy: 0.0061 - main_output_loss: 5.2751
# Epoch 3: val_main_output_accuracy improved from 0.00500 to 0.01730, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 274ms/step - auxiliary_output_accuracy: 0.0091 - auxiliary_output_loss: 5.2532 - loss: 6.8510 - main_output_accuracy: 0.0061 - main_output_loss: 5.2751 - val_auxiliary_output_accuracy: 0.0270 - val_auxiliary_output_loss: 4.9972 - val_loss: 6.5689 - val_main_output_accuracy: 0.0173 - val_main_output_loss: 5.0709 - learning_rate: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.0251 - auxiliary_output_loss: 5.0212 - loss: 6.5711 - main_output_accuracy: 0.0178 - main_output_loss: 5.0647
# Epoch 4: val_main_output_accuracy improved from 0.01730 to 0.03200, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.0252 - auxiliary_output_loss: 5.0212 - loss: 6.5710 - main_output_accuracy: 0.0178 - main_output_loss: 5.0647 - val_auxiliary_output_accuracy: 0.0448 - val_auxiliary_output_loss: 4.8272 - val_loss: 6.3456 - val_main_output_accuracy: 0.0320 - val_main_output_loss: 4.9022 - learning_rate: 0.0100
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.0418 - auxiliary_output_loss: 4.8511 - loss: 6.3563 - main_output_accuracy: 0.0304 - main_output_loss: 4.9009
# Epoch 5: val_main_output_accuracy improved from 0.03200 to 0.04800, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.0418 - auxiliary_output_loss: 4.8510 - loss: 6.3562 - main_output_accuracy: 0.0304 - main_output_loss: 4.9009 - val_auxiliary_output_accuracy: 0.0664 - val_auxiliary_output_loss: 4.6049 - val_loss: 6.1409 - val_main_output_accuracy: 0.0480 - val_main_output_loss: 4.7672 - learning_rate: 0.0096
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.0688 - auxiliary_output_loss: 4.6055 - loss: 6.0531 - main_output_accuracy: 0.0539 - main_output_loss: 4.6714
# Epoch 6: val_main_output_accuracy improved from 0.04800 to 0.08080, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.0688 - auxiliary_output_loss: 4.6054 - loss: 6.0530 - main_output_accuracy: 0.0539 - main_output_loss: 4.6714 - val_auxiliary_output_accuracy: 0.1047 - val_auxiliary_output_loss: 4.3145 - val_loss: 5.7352 - val_main_output_accuracy: 0.0808 - val_main_output_loss: 4.4432 - learning_rate: 0.0096
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.0922 - auxiliary_output_loss: 4.4069 - loss: 5.7797 - main_output_accuracy: 0.0812 - main_output_loss: 4.4577
# Epoch 7: val_main_output_accuracy improved from 0.08080 to 0.09740, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 274ms/step - auxiliary_output_accuracy: 0.0922 - auxiliary_output_loss: 4.4069 - loss: 5.7796 - main_output_accuracy: 0.0812 - main_output_loss: 4.4576 - val_auxiliary_output_accuracy: 0.1180 - val_auxiliary_output_loss: 4.2065 - val_loss: 5.5900 - val_main_output_accuracy: 0.0974 - val_main_output_loss: 4.3262 - learning_rate: 0.0096
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.1223 - auxiliary_output_loss: 4.2007 - loss: 5.4737 - main_output_accuracy: 0.1115 - main_output_loss: 4.2135
# Epoch 8: val_main_output_accuracy improved from 0.09740 to 0.11220, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.1223 - auxiliary_output_loss: 4.2006 - loss: 5.4736 - main_output_accuracy: 0.1115 - main_output_loss: 4.2134 - val_auxiliary_output_accuracy: 0.1328 - val_auxiliary_output_loss: 4.1016 - val_loss: 5.4696 - val_main_output_accuracy: 0.1122 - val_main_output_loss: 4.2379 - learning_rate: 0.0096
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0096.
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.1443 - auxiliary_output_loss: 3.9983 - loss: 5.1816 - main_output_accuracy: 0.1435 - main_output_loss: 3.9821
# Epoch 9: val_main_output_accuracy improved from 0.11220 to 0.13240, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.1443 - auxiliary_output_loss: 3.9982 - loss: 5.1815 - main_output_accuracy: 0.1435 - main_output_loss: 3.9820 - val_auxiliary_output_accuracy: 0.1528 - val_auxiliary_output_loss: 3.9932 - val_loss: 5.3608 - val_main_output_accuracy: 0.1324 - val_main_output_loss: 4.1711 - learning_rate: 0.0096
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.1739 - auxiliary_output_loss: 3.8263 - loss: 4.9353 - main_output_accuracy: 0.1709 - main_output_loss: 3.7874
# Epoch 10: val_main_output_accuracy improved from 0.13240 to 0.18540, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.1739 - auxiliary_output_loss: 3.8263 - loss: 4.9352 - main_output_accuracy: 0.1709 - main_output_loss: 3.7873 - val_auxiliary_output_accuracy: 0.1835 - val_auxiliary_output_loss: 3.7815 - val_loss: 4.8378 - val_main_output_accuracy: 0.1854 - val_main_output_loss: 3.7083 - learning_rate: 0.0092
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.1895 - auxiliary_output_loss: 3.7017 - loss: 4.7453 - main_output_accuracy: 0.1934 - main_output_loss: 3.6348
# Epoch 11: val_main_output_accuracy did not improve from 0.18540
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 273ms/step - auxiliary_output_accuracy: 0.1895 - auxiliary_output_loss: 3.7016 - loss: 4.7452 - main_output_accuracy: 0.1934 - main_output_loss: 3.6347 - val_auxiliary_output_accuracy: 0.1546 - val_auxiliary_output_loss: 4.0581 - val_loss: 5.2869 - val_main_output_accuracy: 0.1511 - val_main_output_loss: 4.0824 - learning_rate: 0.0092
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.2072 - auxiliary_output_loss: 3.5925 - loss: 4.5785 - main_output_accuracy: 0.2173 - main_output_loss: 3.5007
# Epoch 12: val_main_output_accuracy did not improve from 0.18540
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 273ms/step - auxiliary_output_accuracy: 0.2072 - auxiliary_output_loss: 3.5924 - loss: 4.5784 - main_output_accuracy: 0.2173 - main_output_loss: 3.5007 - val_auxiliary_output_accuracy: 0.1363 - val_auxiliary_output_loss: 4.4018 - val_loss: 5.7403 - val_main_output_accuracy: 0.1365 - val_main_output_loss: 4.4452 - learning_rate: 0.0092
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.2225 - auxiliary_output_loss: 3.5013 - loss: 4.4396 - main_output_accuracy: 0.2353 - main_output_loss: 3.3892
# Epoch 13: val_main_output_accuracy improved from 0.18540 to 0.23170, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.2225 - auxiliary_output_loss: 3.5013 - loss: 4.4395 - main_output_accuracy: 0.2354 - main_output_loss: 3.3891 - val_auxiliary_output_accuracy: 0.2291 - val_auxiliary_output_loss: 3.5088 - val_loss: 4.4766 - val_main_output_accuracy: 0.2317 - val_main_output_loss: 3.4404 - learning_rate: 0.0092
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.2347 - auxiliary_output_loss: 3.4207 - loss: 4.2976 - main_output_accuracy: 0.2556 - main_output_loss: 3.2714
# Epoch 14: val_main_output_accuracy did not improve from 0.23170
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.2347 - auxiliary_output_loss: 3.4207 - loss: 4.2976 - main_output_accuracy: 0.2556 - main_output_loss: 3.2714 - val_auxiliary_output_accuracy: 0.1951 - val_auxiliary_output_loss: 3.7474 - val_loss: 4.6758 - val_main_output_accuracy: 0.2167 - val_main_output_loss: 3.5699 - learning_rate: 0.0092
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.2511 - auxiliary_output_loss: 3.3293 - loss: 4.1597 - main_output_accuracy: 0.2741 - main_output_loss: 3.1610
# Epoch 15: val_main_output_accuracy did not improve from 0.23170
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.2511 - auxiliary_output_loss: 3.3292 - loss: 4.1597 - main_output_accuracy: 0.2741 - main_output_loss: 3.1609 - val_auxiliary_output_accuracy: 0.2113 - val_auxiliary_output_loss: 3.6616 - val_loss: 4.9786 - val_main_output_accuracy: 0.1893 - val_main_output_loss: 3.8903 - learning_rate: 0.0088
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.2595 - auxiliary_output_loss: 3.2667 - loss: 4.0559 - main_output_accuracy: 0.2910 - main_output_loss: 3.0759
# Epoch 16: val_main_output_accuracy improved from 0.23170 to 0.23540, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.2596 - auxiliary_output_loss: 3.2667 - loss: 4.0558 - main_output_accuracy: 0.2911 - main_output_loss: 3.0758 - val_auxiliary_output_accuracy: 0.1963 - val_auxiliary_output_loss: 3.8117 - val_loss: 4.6462 - val_main_output_accuracy: 0.2354 - val_main_output_loss: 3.5213 - learning_rate: 0.0088
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.2692 - auxiliary_output_loss: 3.2160 - loss: 3.9610 - main_output_accuracy: 0.3025 - main_output_loss: 2.9962
# Epoch 17: val_main_output_accuracy improved from 0.23540 to 0.25230, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.2692 - auxiliary_output_loss: 3.2160 - loss: 3.9609 - main_output_accuracy: 0.3025 - main_output_loss: 2.9961 - val_auxiliary_output_accuracy: 0.2143 - val_auxiliary_output_loss: 3.7248 - val_loss: 4.6007 - val_main_output_accuracy: 0.2523 - val_main_output_loss: 3.5127 - learning_rate: 0.0088
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.2787 - auxiliary_output_loss: 3.1530 - loss: 3.8571 - main_output_accuracy: 0.3216 - main_output_loss: 2.9112
# Epoch 18: val_main_output_accuracy improved from 0.25230 to 0.27460, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.2787 - auxiliary_output_loss: 3.1530 - loss: 3.8571 - main_output_accuracy: 0.3216 - main_output_loss: 2.9112 - val_auxiliary_output_accuracy: 0.2492 - val_auxiliary_output_loss: 3.4420 - val_loss: 4.3013 - val_main_output_accuracy: 0.2746 - val_main_output_loss: 3.2885 - learning_rate: 0.0088
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.008847359999999999.
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.2885 - auxiliary_output_loss: 3.0899 - loss: 3.7665 - main_output_accuracy: 0.3339 - main_output_loss: 2.8396
# Epoch 19: val_main_output_accuracy did not improve from 0.27460
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.2885 - auxiliary_output_loss: 3.0899 - loss: 3.7665 - main_output_accuracy: 0.3340 - main_output_loss: 2.8395 - val_auxiliary_output_accuracy: 0.2251 - val_auxiliary_output_loss: 3.7079 - val_loss: 4.5327 - val_main_output_accuracy: 0.2590 - val_main_output_loss: 3.4399 - learning_rate: 0.0088
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3020 - auxiliary_output_loss: 3.0319 - loss: 3.6702 - main_output_accuracy: 0.3471 - main_output_loss: 2.7606
# Epoch 20: val_main_output_accuracy did not improve from 0.27460
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.3020 - auxiliary_output_loss: 3.0319 - loss: 3.6701 - main_output_accuracy: 0.3471 - main_output_loss: 2.7605 - val_auxiliary_output_accuracy: 0.2154 - val_auxiliary_output_loss: 3.8285 - val_loss: 4.6781 - val_main_output_accuracy: 0.2506 - val_main_output_loss: 3.5472 - learning_rate: 0.0085
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3102 - auxiliary_output_loss: 2.9893 - loss: 3.5908 - main_output_accuracy: 0.3601 - main_output_loss: 2.6940
# Epoch 21: val_main_output_accuracy did not improve from 0.27460
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 273ms/step - auxiliary_output_accuracy: 0.3102 - auxiliary_output_loss: 2.9893 - loss: 3.5907 - main_output_accuracy: 0.3601 - main_output_loss: 2.6939 - val_auxiliary_output_accuracy: 0.2214 - val_auxiliary_output_loss: 3.7197 - val_loss: 4.6434 - val_main_output_accuracy: 0.2479 - val_main_output_loss: 3.5522 - learning_rate: 0.0085
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3165 - auxiliary_output_loss: 2.9469 - loss: 3.5260 - main_output_accuracy: 0.3706 - main_output_loss: 2.6420
# Epoch 22: val_main_output_accuracy improved from 0.27460 to 0.31290, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.3165 - auxiliary_output_loss: 2.9468 - loss: 3.5260 - main_output_accuracy: 0.3706 - main_output_loss: 2.6419 - val_auxiliary_output_accuracy: 0.2670 - val_auxiliary_output_loss: 3.3121 - val_loss: 4.0514 - val_main_output_accuracy: 0.3129 - val_main_output_loss: 3.0771 - learning_rate: 0.0085
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3254 - auxiliary_output_loss: 2.8975 - loss: 3.4469 - main_output_accuracy: 0.3835 - main_output_loss: 2.5777
# Epoch 23: val_main_output_accuracy did not improve from 0.31290
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.3254 - auxiliary_output_loss: 2.8975 - loss: 3.4469 - main_output_accuracy: 0.3836 - main_output_loss: 2.5777 - val_auxiliary_output_accuracy: 0.2463 - val_auxiliary_output_loss: 3.5794 - val_loss: 4.2201 - val_main_output_accuracy: 0.3056 - val_main_output_loss: 3.1669 - learning_rate: 0.0085
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.008493465599999998.
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3308 - auxiliary_output_loss: 2.8597 - loss: 3.3820 - main_output_accuracy: 0.3930 - main_output_loss: 2.5241
# Epoch 24: val_main_output_accuracy did not improve from 0.31290
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.3309 - auxiliary_output_loss: 2.8597 - loss: 3.3820 - main_output_accuracy: 0.3930 - main_output_loss: 2.5240 - val_auxiliary_output_accuracy: 0.2667 - val_auxiliary_output_loss: 3.4326 - val_loss: 4.2263 - val_main_output_accuracy: 0.3059 - val_main_output_loss: 3.2215 - learning_rate: 0.0085
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.3403 - auxiliary_output_loss: 2.8151 - loss: 3.2989 - main_output_accuracy: 0.4060 - main_output_loss: 2.4544
# Epoch 25: val_main_output_accuracy improved from 0.31290 to 0.32770, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.3403 - auxiliary_output_loss: 2.8150 - loss: 3.2988 - main_output_accuracy: 0.4060 - main_output_loss: 2.4543 - val_auxiliary_output_accuracy: 0.2741 - val_auxiliary_output_loss: 3.3834 - val_loss: 4.0236 - val_main_output_accuracy: 0.3277 - val_main_output_loss: 3.0310 - learning_rate: 0.0082
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.3469 - auxiliary_output_loss: 2.7759 - loss: 3.2407 - main_output_accuracy: 0.4140 - main_output_loss: 2.4079
# Epoch 26: val_main_output_accuracy improved from 0.32770 to 0.33200, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.3469 - auxiliary_output_loss: 2.7759 - loss: 3.2407 - main_output_accuracy: 0.4140 - main_output_loss: 2.4079 - val_auxiliary_output_accuracy: 0.2853 - val_auxiliary_output_loss: 3.3233 - val_loss: 4.0897 - val_main_output_accuracy: 0.3320 - val_main_output_loss: 3.1197 - learning_rate: 0.0082
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3518 - auxiliary_output_loss: 2.7466 - loss: 3.1925 - main_output_accuracy: 0.4228 - main_output_loss: 2.3685
# Epoch 27: val_main_output_accuracy improved from 0.33200 to 0.35760, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.3518 - auxiliary_output_loss: 2.7465 - loss: 3.1925 - main_output_accuracy: 0.4229 - main_output_loss: 2.3685 - val_auxiliary_output_accuracy: 0.3070 - val_auxiliary_output_loss: 3.1353 - val_loss: 3.7157 - val_main_output_accuracy: 0.3576 - val_main_output_loss: 2.7979 - learning_rate: 0.0082
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3598 - auxiliary_output_loss: 2.6971 - loss: 3.1170 - main_output_accuracy: 0.4354 - main_output_loss: 2.3078
# Epoch 28: val_main_output_accuracy did not improve from 0.35760
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.3598 - auxiliary_output_loss: 2.6970 - loss: 3.1169 - main_output_accuracy: 0.4354 - main_output_loss: 2.3078 - val_auxiliary_output_accuracy: 0.2750 - val_auxiliary_output_loss: 3.4667 - val_loss: 4.3269 - val_main_output_accuracy: 0.3180 - val_main_output_loss: 3.3215 - learning_rate: 0.0082
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.008153726976.
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3661 - auxiliary_output_loss: 2.6707 - loss: 3.0789 - main_output_accuracy: 0.4421 - main_output_loss: 2.2777
# Epoch 29: val_main_output_accuracy improved from 0.35760 to 0.36240, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 274ms/step - auxiliary_output_accuracy: 0.3661 - auxiliary_output_loss: 2.6706 - loss: 3.0789 - main_output_accuracy: 0.4421 - main_output_loss: 2.2777 - val_auxiliary_output_accuracy: 0.2967 - val_auxiliary_output_loss: 3.2387 - val_loss: 3.9070 - val_main_output_accuracy: 0.3624 - val_main_output_loss: 2.9678 - learning_rate: 0.0082
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3738 - auxiliary_output_loss: 2.6329 - loss: 3.0160 - main_output_accuracy: 0.4529 - main_output_loss: 2.2261
# Epoch 30: val_main_output_accuracy improved from 0.36240 to 0.39250, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.3738 - auxiliary_output_loss: 2.6328 - loss: 3.0159 - main_output_accuracy: 0.4529 - main_output_loss: 2.2261 - val_auxiliary_output_accuracy: 0.3465 - val_auxiliary_output_loss: 2.9447 - val_loss: 3.5902 - val_main_output_accuracy: 0.3925 - val_main_output_loss: 2.7387 - learning_rate: 0.0078
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3778 - auxiliary_output_loss: 2.5983 - loss: 2.9506 - main_output_accuracy: 0.4636 - main_output_loss: 2.1711
# Epoch 31: val_main_output_accuracy did not improve from 0.39250
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.3778 - auxiliary_output_loss: 2.5983 - loss: 2.9505 - main_output_accuracy: 0.4636 - main_output_loss: 2.1711 - val_auxiliary_output_accuracy: 0.2996 - val_auxiliary_output_loss: 3.3332 - val_loss: 3.9909 - val_main_output_accuracy: 0.3632 - val_main_output_loss: 3.0310 - learning_rate: 0.0078
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3834 - auxiliary_output_loss: 2.5771 - loss: 2.9103 - main_output_accuracy: 0.4688 - main_output_loss: 2.1372
# Epoch 32: val_main_output_accuracy did not improve from 0.39250
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.3835 - auxiliary_output_loss: 2.5771 - loss: 2.9103 - main_output_accuracy: 0.4688 - main_output_loss: 2.1371 - val_auxiliary_output_accuracy: 0.2987 - val_auxiliary_output_loss: 3.3130 - val_loss: 4.1962 - val_main_output_accuracy: 0.3357 - val_main_output_loss: 3.2424 - learning_rate: 0.0078
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3893 - auxiliary_output_loss: 2.5505 - loss: 2.8743 - main_output_accuracy: 0.4749 - main_output_loss: 2.1091
# Epoch 33: val_main_output_accuracy did not improve from 0.39250
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.3893 - auxiliary_output_loss: 2.5505 - loss: 2.8742 - main_output_accuracy: 0.4749 - main_output_loss: 2.1091 - val_auxiliary_output_accuracy: 0.3034 - val_auxiliary_output_loss: 3.2594 - val_loss: 3.9544 - val_main_output_accuracy: 0.3653 - val_main_output_loss: 3.0170 - learning_rate: 0.0078
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.007827577896959998.
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.3899 - auxiliary_output_loss: 2.5219 - loss: 2.8254 - main_output_accuracy: 0.4834 - main_output_loss: 2.0688
# Epoch 34: val_main_output_accuracy did not improve from 0.39250
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.3900 - auxiliary_output_loss: 2.5219 - loss: 2.8254 - main_output_accuracy: 0.4834 - main_output_loss: 2.0688 - val_auxiliary_output_accuracy: 0.2802 - val_auxiliary_output_loss: 3.4952 - val_loss: 4.3453 - val_main_output_accuracy: 0.3424 - val_main_output_loss: 3.3331 - learning_rate: 0.0078
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.007514474781081598.
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.3992 - auxiliary_output_loss: 2.4826 - loss: 2.7662 - main_output_accuracy: 0.4933 - main_output_loss: 2.0214
# Epoch 35: val_main_output_accuracy did not improve from 0.39250
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.3992 - auxiliary_output_loss: 2.4826 - loss: 2.7662 - main_output_accuracy: 0.4933 - main_output_loss: 2.0214 - val_auxiliary_output_accuracy: 0.2952 - val_auxiliary_output_loss: 3.4234 - val_loss: 4.1098 - val_main_output_accuracy: 0.3553 - val_main_output_loss: 3.1147 - learning_rate: 0.0075
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.007514474781081598.
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.4011 - auxiliary_output_loss: 2.4714 - loss: 2.7345 - main_output_accuracy: 0.4987 - main_output_loss: 1.9931
# Epoch 36: val_main_output_accuracy improved from 0.39250 to 0.39380, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4011 - auxiliary_output_loss: 2.4714 - loss: 2.7344 - main_output_accuracy: 0.4987 - main_output_loss: 1.9930 - val_auxiliary_output_accuracy: 0.3263 - val_auxiliary_output_loss: 3.1617 - val_loss: 3.8253 - val_main_output_accuracy: 0.3938 - val_main_output_loss: 2.9160 - learning_rate: 0.0075
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.007514474781081598.
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4103 - auxiliary_output_loss: 2.4339 - loss: 2.6868 - main_output_accuracy: 0.5062 - main_output_loss: 1.9566
# Epoch 37: val_main_output_accuracy improved from 0.39380 to 0.40950, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4103 - auxiliary_output_loss: 2.4339 - loss: 2.6868 - main_output_accuracy: 0.5062 - main_output_loss: 1.9566 - val_auxiliary_output_accuracy: 0.3377 - val_auxiliary_output_loss: 3.0302 - val_loss: 3.6286 - val_main_output_accuracy: 0.4095 - val_main_output_loss: 2.7613 - learning_rate: 0.0075
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.007514474781081598.
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4173 - auxiliary_output_loss: 2.4011 - loss: 2.6375 - main_output_accuracy: 0.5135 - main_output_loss: 1.9171
# Epoch 38: val_main_output_accuracy improved from 0.40950 to 0.42320, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4173 - auxiliary_output_loss: 2.4011 - loss: 2.6375 - main_output_accuracy: 0.5135 - main_output_loss: 1.9171 - val_auxiliary_output_accuracy: 0.3486 - val_auxiliary_output_loss: 2.9652 - val_loss: 3.5590 - val_main_output_accuracy: 0.4232 - val_main_output_loss: 2.6962 - learning_rate: 0.0075
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.007514474781081598.
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4193 - auxiliary_output_loss: 2.3847 - loss: 2.6073 - main_output_accuracy: 0.5192 - main_output_loss: 1.8919
# Epoch 39: val_main_output_accuracy did not improve from 0.42320
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4193 - auxiliary_output_loss: 2.3847 - loss: 2.6073 - main_output_accuracy: 0.5192 - main_output_loss: 1.8919 - val_auxiliary_output_accuracy: 0.3233 - val_auxiliary_output_loss: 3.1100 - val_loss: 3.8871 - val_main_output_accuracy: 0.3758 - val_main_output_loss: 2.9957 - learning_rate: 0.0075
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.007213895789838334.
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.4268 - auxiliary_output_loss: 2.3508 - loss: 2.5571 - main_output_accuracy: 0.5276 - main_output_loss: 1.8519
# Epoch 40: val_main_output_accuracy did not improve from 0.42320
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4268 - auxiliary_output_loss: 2.3508 - loss: 2.5571 - main_output_accuracy: 0.5276 - main_output_loss: 1.8518 - val_auxiliary_output_accuracy: 0.3170 - val_auxiliary_output_loss: 3.2455 - val_loss: 4.0571 - val_main_output_accuracy: 0.3741 - val_main_output_loss: 3.1189 - learning_rate: 0.0072
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.007213895789838334.
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4290 - auxiliary_output_loss: 2.3249 - loss: 2.5183 - main_output_accuracy: 0.5318 - main_output_loss: 1.8208
# Epoch 41: val_main_output_accuracy did not improve from 0.42320
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4290 - auxiliary_output_loss: 2.3249 - loss: 2.5183 - main_output_accuracy: 0.5318 - main_output_loss: 1.8208 - val_auxiliary_output_accuracy: 0.3225 - val_auxiliary_output_loss: 3.1981 - val_loss: 3.8605 - val_main_output_accuracy: 0.3926 - val_main_output_loss: 2.9313 - learning_rate: 0.0072
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.007213895789838334.
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4343 - auxiliary_output_loss: 2.3107 - loss: 2.4768 - main_output_accuracy: 0.5392 - main_output_loss: 1.7836
# Epoch 42: val_main_output_accuracy did not improve from 0.42320
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4343 - auxiliary_output_loss: 2.3107 - loss: 2.4767 - main_output_accuracy: 0.5392 - main_output_loss: 1.7835 - val_auxiliary_output_accuracy: 0.3213 - val_auxiliary_output_loss: 3.2132 - val_loss: 3.9180 - val_main_output_accuracy: 0.3721 - val_main_output_loss: 2.9813 - learning_rate: 0.0072
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.007213895789838334.
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4385 - auxiliary_output_loss: 2.2783 - loss: 2.4479 - main_output_accuracy: 0.5453 - main_output_loss: 1.7644
# Epoch 43: val_main_output_accuracy did not improve from 0.42320
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4385 - auxiliary_output_loss: 2.2783 - loss: 2.4478 - main_output_accuracy: 0.5453 - main_output_loss: 1.7643 - val_auxiliary_output_accuracy: 0.3248 - val_auxiliary_output_loss: 3.1715 - val_loss: 3.8192 - val_main_output_accuracy: 0.3966 - val_main_output_loss: 2.8953 - learning_rate: 0.0072
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.007213895789838334.
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4410 - auxiliary_output_loss: 2.2675 - loss: 2.4250 - main_output_accuracy: 0.5505 - main_output_loss: 1.7447
# Epoch 44: val_main_output_accuracy did not improve from 0.42320
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4410 - auxiliary_output_loss: 2.2675 - loss: 2.4249 - main_output_accuracy: 0.5505 - main_output_loss: 1.7447 - val_auxiliary_output_accuracy: 0.3264 - val_auxiliary_output_loss: 3.1891 - val_loss: 3.8466 - val_main_output_accuracy: 0.3921 - val_main_output_loss: 2.9218 - learning_rate: 0.0072
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.0069253399582448.
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4466 - auxiliary_output_loss: 2.2426 - loss: 2.3728 - main_output_accuracy: 0.5579 - main_output_loss: 1.7000
# Epoch 45: val_main_output_accuracy did not improve from 0.42320
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4466 - auxiliary_output_loss: 2.2426 - loss: 2.3728 - main_output_accuracy: 0.5579 - main_output_loss: 1.7000 - val_auxiliary_output_accuracy: 0.3552 - val_auxiliary_output_loss: 3.0761 - val_loss: 3.7919 - val_main_output_accuracy: 0.4071 - val_main_output_loss: 2.9033 - learning_rate: 0.0069
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.0069253399582448.
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4509 - auxiliary_output_loss: 2.2149 - loss: 2.3273 - main_output_accuracy: 0.5678 - main_output_loss: 1.6628
# Epoch 46: val_main_output_accuracy did not improve from 0.42320
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4510 - auxiliary_output_loss: 2.2149 - loss: 2.3273 - main_output_accuracy: 0.5678 - main_output_loss: 1.6628 - val_auxiliary_output_accuracy: 0.3550 - val_auxiliary_output_loss: 3.0222 - val_loss: 3.6941 - val_main_output_accuracy: 0.4188 - val_main_output_loss: 2.8185 - learning_rate: 0.0069
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.0069253399582448.
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4549 - auxiliary_output_loss: 2.2003 - loss: 2.3042 - main_output_accuracy: 0.5692 - main_output_loss: 1.6441
# Epoch 47: val_main_output_accuracy improved from 0.42320 to 0.43800, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4549 - auxiliary_output_loss: 2.2003 - loss: 2.3041 - main_output_accuracy: 0.5692 - main_output_loss: 1.6440 - val_auxiliary_output_accuracy: 0.3668 - val_auxiliary_output_loss: 2.9509 - val_loss: 3.5476 - val_main_output_accuracy: 0.4380 - val_main_output_loss: 2.6903 - learning_rate: 0.0069
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.0069253399582448.
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4582 - auxiliary_output_loss: 2.1804 - loss: 2.2712 - main_output_accuracy: 0.5774 - main_output_loss: 1.6171
# Epoch 48: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4582 - auxiliary_output_loss: 2.1804 - loss: 2.2712 - main_output_accuracy: 0.5774 - main_output_loss: 1.6171 - val_auxiliary_output_accuracy: 0.3598 - val_auxiliary_output_loss: 2.9378 - val_loss: 3.5749 - val_main_output_accuracy: 0.4284 - val_main_output_loss: 2.7351 - learning_rate: 0.0069
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.0069253399582448.
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4599 - auxiliary_output_loss: 2.1681 - loss: 2.2490 - main_output_accuracy: 0.5792 - main_output_loss: 1.5986
# Epoch 49: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4599 - auxiliary_output_loss: 2.1680 - loss: 2.2490 - main_output_accuracy: 0.5792 - main_output_loss: 1.5986 - val_auxiliary_output_accuracy: 0.3600 - val_auxiliary_output_loss: 2.9833 - val_loss: 3.6611 - val_main_output_accuracy: 0.4375 - val_main_output_loss: 2.7968 - learning_rate: 0.0069
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.006648326359915008.
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.4638 - auxiliary_output_loss: 2.1450 - loss: 2.2154 - main_output_accuracy: 0.5869 - main_output_loss: 1.5719
# Epoch 50: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4638 - auxiliary_output_loss: 2.1450 - loss: 2.2154 - main_output_accuracy: 0.5869 - main_output_loss: 1.5719 - val_auxiliary_output_accuracy: 0.3398 - val_auxiliary_output_loss: 3.1886 - val_loss: 3.9252 - val_main_output_accuracy: 0.4137 - val_main_output_loss: 3.0147 - learning_rate: 0.0066
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.006648326359915008.
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.4706 - auxiliary_output_loss: 2.1202 - loss: 2.1774 - main_output_accuracy: 0.5917 - main_output_loss: 1.5414
# Epoch 51: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4706 - auxiliary_output_loss: 2.1202 - loss: 2.1774 - main_output_accuracy: 0.5917 - main_output_loss: 1.5413 - val_auxiliary_output_accuracy: 0.3551 - val_auxiliary_output_loss: 3.0632 - val_loss: 3.7723 - val_main_output_accuracy: 0.4267 - val_main_output_loss: 2.8947 - learning_rate: 0.0066
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.006648326359915008.
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.4736 - auxiliary_output_loss: 2.1008 - loss: 2.1377 - main_output_accuracy: 0.5998 - main_output_loss: 1.5075
# Epoch 52: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4736 - auxiliary_output_loss: 2.1008 - loss: 2.1377 - main_output_accuracy: 0.5998 - main_output_loss: 1.5075 - val_auxiliary_output_accuracy: 0.3501 - val_auxiliary_output_loss: 3.0988 - val_loss: 3.9360 - val_main_output_accuracy: 0.4111 - val_main_output_loss: 3.0317 - learning_rate: 0.0066
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.006648326359915008.
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4736 - auxiliary_output_loss: 2.0899 - loss: 2.1222 - main_output_accuracy: 0.6034 - main_output_loss: 1.4952
# Epoch 53: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4736 - auxiliary_output_loss: 2.0899 - loss: 2.1221 - main_output_accuracy: 0.6034 - main_output_loss: 1.4952 - val_auxiliary_output_accuracy: 0.3619 - val_auxiliary_output_loss: 2.9914 - val_loss: 3.7297 - val_main_output_accuracy: 0.4228 - val_main_output_loss: 2.8774 - learning_rate: 0.0066
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.006648326359915008.
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4772 - auxiliary_output_loss: 2.0724 - loss: 2.0933 - main_output_accuracy: 0.6098 - main_output_loss: 1.4716
# Epoch 54: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.4772 - auxiliary_output_loss: 2.0724 - loss: 2.0933 - main_output_accuracy: 0.6098 - main_output_loss: 1.4716 - val_auxiliary_output_accuracy: 0.3555 - val_auxiliary_output_loss: 3.0780 - val_loss: 3.9624 - val_main_output_accuracy: 0.4215 - val_main_output_loss: 3.0798 - learning_rate: 0.0066
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.006382393305518408.
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4823 - auxiliary_output_loss: 2.0494 - loss: 2.0540 - main_output_accuracy: 0.6157 - main_output_loss: 1.4392
# Epoch 55: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4824 - auxiliary_output_loss: 2.0494 - loss: 2.0539 - main_output_accuracy: 0.6157 - main_output_loss: 1.4391 - val_auxiliary_output_accuracy: 0.3619 - val_auxiliary_output_loss: 3.0421 - val_loss: 3.9639 - val_main_output_accuracy: 0.4209 - val_main_output_loss: 3.0951 - learning_rate: 0.0064
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.006382393305518408.
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.4892 - auxiliary_output_loss: 2.0260 - loss: 2.0257 - main_output_accuracy: 0.6200 - main_output_loss: 1.4179
# Epoch 56: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4892 - auxiliary_output_loss: 2.0259 - loss: 2.0257 - main_output_accuracy: 0.6200 - main_output_loss: 1.4179 - val_auxiliary_output_accuracy: 0.3569 - val_auxiliary_output_loss: 3.0304 - val_loss: 4.0343 - val_main_output_accuracy: 0.4115 - val_main_output_loss: 3.1549 - learning_rate: 0.0064
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.006382393305518408.
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.4905 - auxiliary_output_loss: 2.0139 - loss: 2.0046 - main_output_accuracy: 0.6236 - main_output_loss: 1.4004
# Epoch 57: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4905 - auxiliary_output_loss: 2.0139 - loss: 2.0045 - main_output_accuracy: 0.6236 - main_output_loss: 1.4004 - val_auxiliary_output_accuracy: 0.3626 - val_auxiliary_output_loss: 3.0414 - val_loss: 3.8757 - val_main_output_accuracy: 0.4316 - val_main_output_loss: 2.9994 - learning_rate: 0.0064
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.006382393305518408.
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.4922 - auxiliary_output_loss: 1.9911 - loss: 1.9752 - main_output_accuracy: 0.6289 - main_output_loss: 1.3778
# Epoch 58: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4922 - auxiliary_output_loss: 1.9911 - loss: 1.9751 - main_output_accuracy: 0.6289 - main_output_loss: 1.3778 - val_auxiliary_output_accuracy: 0.3617 - val_auxiliary_output_loss: 3.1059 - val_loss: 4.0358 - val_main_output_accuracy: 0.4260 - val_main_output_loss: 3.1429 - learning_rate: 0.0064
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.006382393305518408.
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.4985 - auxiliary_output_loss: 1.9831 - loss: 1.9502 - main_output_accuracy: 0.6324 - main_output_loss: 1.3552
# Epoch 59: val_main_output_accuracy did not improve from 0.43800
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.4985 - auxiliary_output_loss: 1.9831 - loss: 1.9502 - main_output_accuracy: 0.6324 - main_output_loss: 1.3552 - val_auxiliary_output_accuracy: 0.3582 - val_auxiliary_output_loss: 3.0915 - val_loss: 3.9216 - val_main_output_accuracy: 0.4254 - val_main_output_loss: 3.0145 - learning_rate: 0.0064
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.006127097573297671.
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5001 - auxiliary_output_loss: 1.9640 - loss: 1.9128 - main_output_accuracy: 0.6428 - main_output_loss: 1.3236
# Epoch 60: val_main_output_accuracy improved from 0.43800 to 0.44110, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5001 - auxiliary_output_loss: 1.9640 - loss: 1.9127 - main_output_accuracy: 0.6428 - main_output_loss: 1.3235 - val_auxiliary_output_accuracy: 0.3774 - val_auxiliary_output_loss: 2.9580 - val_loss: 3.7609 - val_main_output_accuracy: 0.4411 - val_main_output_loss: 2.9173 - learning_rate: 0.0061
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.006127097573297671.
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.5022 - auxiliary_output_loss: 1.9409 - loss: 1.8805 - main_output_accuracy: 0.6519 - main_output_loss: 1.2982
# Epoch 61: val_main_output_accuracy did not improve from 0.44110
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.5022 - auxiliary_output_loss: 1.9409 - loss: 1.8804 - main_output_accuracy: 0.6519 - main_output_loss: 1.2982 - val_auxiliary_output_accuracy: 0.3611 - val_auxiliary_output_loss: 3.0658 - val_loss: 3.8903 - val_main_output_accuracy: 0.4371 - val_main_output_loss: 3.0010 - learning_rate: 0.0061
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.006127097573297671.
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5034 - auxiliary_output_loss: 1.9364 - loss: 1.8685 - main_output_accuracy: 0.6487 - main_output_loss: 1.2876
# Epoch 62: val_main_output_accuracy did not improve from 0.44110
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.5034 - auxiliary_output_loss: 1.9364 - loss: 1.8685 - main_output_accuracy: 0.6487 - main_output_loss: 1.2876 - val_auxiliary_output_accuracy: 0.3568 - val_auxiliary_output_loss: 3.1047 - val_loss: 4.1089 - val_main_output_accuracy: 0.4074 - val_main_output_loss: 3.2121 - learning_rate: 0.0061
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.006127097573297671.
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5135 - auxiliary_output_loss: 1.9104 - loss: 1.8451 - main_output_accuracy: 0.6546 - main_output_loss: 1.2719
# Epoch 63: val_main_output_accuracy did not improve from 0.44110
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.5135 - auxiliary_output_loss: 1.9104 - loss: 1.8450 - main_output_accuracy: 0.6546 - main_output_loss: 1.2719 - val_auxiliary_output_accuracy: 0.3681 - val_auxiliary_output_loss: 3.0507 - val_loss: 4.0061 - val_main_output_accuracy: 0.4266 - val_main_output_loss: 3.1289 - learning_rate: 0.0061
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.006127097573297671.
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5146 - auxiliary_output_loss: 1.9010 - loss: 1.8258 - main_output_accuracy: 0.6550 - main_output_loss: 1.2555
# Epoch 64: val_main_output_accuracy improved from 0.44110 to 0.44360, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 274ms/step - auxiliary_output_accuracy: 0.5146 - auxiliary_output_loss: 1.9009 - loss: 1.8257 - main_output_accuracy: 0.6550 - main_output_loss: 1.2555 - val_auxiliary_output_accuracy: 0.3786 - val_auxiliary_output_loss: 2.9848 - val_loss: 4.0388 - val_main_output_accuracy: 0.4436 - val_main_output_loss: 3.1802 - learning_rate: 0.0061
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.005882013670365765.
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - auxiliary_output_accuracy: 0.5162 - auxiliary_output_loss: 1.8851 - loss: 1.7847 - main_output_accuracy: 0.6658 - main_output_loss: 1.2192
# Epoch 65: val_main_output_accuracy did not improve from 0.44360
# ...
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.005420863798609088.
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5519 - auxiliary_output_loss: 1.6983 - loss: 1.4962 - main_output_accuracy: 0.7192 - main_output_loss: 0.9867
# Epoch 79: val_main_output_accuracy did not improve from 0.45820
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5519 - auxiliary_output_loss: 1.6983 - loss: 1.4961 - main_output_accuracy: 0.7192 - main_output_loss: 0.9866 - val_auxiliary_output_accuracy: 0.3781 - val_auxiliary_output_loss: 3.0526 - val_loss: 4.2084 - val_main_output_accuracy: 0.4360 - val_main_output_loss: 3.3282 - learning_rate: 0.0054
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.005204029246664724.
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5582 - auxiliary_output_loss: 1.6822 - loss: 1.4661 - main_output_accuracy: 0.7241 - main_output_loss: 0.9614
# Epoch 80: val_main_output_accuracy did not improve from 0.45820
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5582 - auxiliary_output_loss: 1.6822 - loss: 1.4661 - main_output_accuracy: 0.7241 - main_output_loss: 0.9614 - val_auxiliary_output_accuracy: 0.3911 - val_auxiliary_output_loss: 2.9144 - val_loss: 3.9761 - val_main_output_accuracy: 0.4476 - val_main_output_loss: 3.1509 - learning_rate: 0.0052
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.005204029246664724.
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5586 - auxiliary_output_loss: 1.6726 - loss: 1.4426 - main_output_accuracy: 0.7317 - main_output_loss: 0.9408
# Epoch 81: val_main_output_accuracy improved from 0.45820 to 0.46230, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 274ms/step - auxiliary_output_accuracy: 0.5586 - auxiliary_output_loss: 1.6725 - loss: 1.4426 - main_output_accuracy: 0.7317 - main_output_loss: 0.9408 - val_auxiliary_output_accuracy: 0.3896 - val_auxiliary_output_loss: 2.9205 - val_loss: 3.9366 - val_main_output_accuracy: 0.4623 - val_main_output_loss: 3.0907 - learning_rate: 0.0052
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.005204029246664724.
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5577 - auxiliary_output_loss: 1.6717 - loss: 1.4386 - main_output_accuracy: 0.7322 - main_output_loss: 0.9371
# Epoch 82: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5577 - auxiliary_output_loss: 1.6716 - loss: 1.4386 - main_output_accuracy: 0.7322 - main_output_loss: 0.9371 - val_auxiliary_output_accuracy: 0.3767 - val_auxiliary_output_loss: 3.0466 - val_loss: 4.1259 - val_main_output_accuracy: 0.4482 - val_main_output_loss: 3.2593 - learning_rate: 0.0052
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.005204029246664724.
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5641 - auxiliary_output_loss: 1.6472 - loss: 1.4108 - main_output_accuracy: 0.7374 - main_output_loss: 0.9166
# Epoch 83: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5641 - auxiliary_output_loss: 1.6472 - loss: 1.4108 - main_output_accuracy: 0.7374 - main_output_loss: 0.9166 - val_auxiliary_output_accuracy: 0.3942 - val_auxiliary_output_loss: 2.9286 - val_loss: 3.9343 - val_main_output_accuracy: 0.4599 - val_main_output_loss: 3.1018 - learning_rate: 0.0052
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.005204029246664724.
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5639 - auxiliary_output_loss: 1.6496 - loss: 1.4045 - main_output_accuracy: 0.7393 - main_output_loss: 0.9096
# Epoch 84: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5639 - auxiliary_output_loss: 1.6496 - loss: 1.4045 - main_output_accuracy: 0.7393 - main_output_loss: 0.9096 - val_auxiliary_output_accuracy: 0.3843 - val_auxiliary_output_loss: 2.9817 - val_loss: 4.0625 - val_main_output_accuracy: 0.4427 - val_main_output_loss: 3.2238 - learning_rate: 0.0052
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.004995868076798134.
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5676 - auxiliary_output_loss: 1.6274 - loss: 1.3835 - main_output_accuracy: 0.7426 - main_output_loss: 0.8953
# Epoch 85: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5676 - auxiliary_output_loss: 1.6273 - loss: 1.3835 - main_output_accuracy: 0.7426 - main_output_loss: 0.8952 - val_auxiliary_output_accuracy: 0.3603 - val_auxiliary_output_loss: 3.2210 - val_loss: 4.6446 - val_main_output_accuracy: 0.4208 - val_main_output_loss: 3.7194 - learning_rate: 0.0050
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.004995868076798134.
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5703 - auxiliary_output_loss: 1.6134 - loss: 1.3542 - main_output_accuracy: 0.7508 - main_output_loss: 0.8702
# Epoch 86: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5703 - auxiliary_output_loss: 1.6134 - loss: 1.3542 - main_output_accuracy: 0.7508 - main_output_loss: 0.8702 - val_auxiliary_output_accuracy: 0.3703 - val_auxiliary_output_loss: 3.2361 - val_loss: 4.6034 - val_main_output_accuracy: 0.4378 - val_main_output_loss: 3.6892 - learning_rate: 0.0050
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.004995868076798134.
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5723 - auxiliary_output_loss: 1.6107 - loss: 1.3437 - main_output_accuracy: 0.7542 - main_output_loss: 0.8605
# Epoch 87: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5723 - auxiliary_output_loss: 1.6107 - loss: 1.3437 - main_output_accuracy: 0.7542 - main_output_loss: 0.8605 - val_auxiliary_output_accuracy: 0.3892 - val_auxiliary_output_loss: 3.0096 - val_loss: 4.2626 - val_main_output_accuracy: 0.4396 - val_main_output_loss: 3.4140 - learning_rate: 0.0050
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.004995868076798134.
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5741 - auxiliary_output_loss: 1.5922 - loss: 1.3316 - main_output_accuracy: 0.7538 - main_output_loss: 0.8539
# Epoch 88: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5741 - auxiliary_output_loss: 1.5922 - loss: 1.3315 - main_output_accuracy: 0.7538 - main_output_loss: 0.8539 - val_auxiliary_output_accuracy: 0.4017 - val_auxiliary_output_loss: 2.9249 - val_loss: 4.1990 - val_main_output_accuracy: 0.4535 - val_main_output_loss: 3.3754 - learning_rate: 0.0050
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.004995868076798134.
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5783 - auxiliary_output_loss: 1.5854 - loss: 1.3153 - main_output_accuracy: 0.7586 - main_output_loss: 0.8397
# Epoch 89: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5783 - auxiliary_output_loss: 1.5854 - loss: 1.3153 - main_output_accuracy: 0.7586 - main_output_loss: 0.8397 - val_auxiliary_output_accuracy: 0.3894 - val_auxiliary_output_loss: 3.0803 - val_loss: 4.2886 - val_main_output_accuracy: 0.4532 - val_main_output_loss: 3.4309 - learning_rate: 0.0050
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.004796033353726209.
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5794 - auxiliary_output_loss: 1.5822 - loss: 1.2920 - main_output_accuracy: 0.7630 - main_output_loss: 0.8173
# Epoch 90: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5794 - auxiliary_output_loss: 1.5822 - loss: 1.2919 - main_output_accuracy: 0.7630 - main_output_loss: 0.8173 - val_auxiliary_output_accuracy: 0.3901 - val_auxiliary_output_loss: 3.0297 - val_loss: 4.4037 - val_main_output_accuracy: 0.4508 - val_main_output_loss: 3.5644 - learning_rate: 0.0048
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.004796033353726209.
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5802 - auxiliary_output_loss: 1.5677 - loss: 1.2781 - main_output_accuracy: 0.7637 - main_output_loss: 0.8077
# Epoch 91: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5802 - auxiliary_output_loss: 1.5677 - loss: 1.2780 - main_output_accuracy: 0.7637 - main_output_loss: 0.8077 - val_auxiliary_output_accuracy: 0.4007 - val_auxiliary_output_loss: 2.9619 - val_loss: 4.2410 - val_main_output_accuracy: 0.4605 - val_main_output_loss: 3.4050 - learning_rate: 0.0048
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.004796033353726209.
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5802 - auxiliary_output_loss: 1.5658 - loss: 1.2709 - main_output_accuracy: 0.7669 - main_output_loss: 0.8012
# Epoch 92: val_main_output_accuracy did not improve from 0.46230
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5802 - auxiliary_output_loss: 1.5657 - loss: 1.2709 - main_output_accuracy: 0.7669 - main_output_loss: 0.8011 - val_auxiliary_output_accuracy: 0.3929 - val_auxiliary_output_loss: 3.0053 - val_loss: 4.0317 - val_main_output_accuracy: 0.4574 - val_main_output_loss: 3.1802 - learning_rate: 0.0048
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.004796033353726209.
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5872 - auxiliary_output_loss: 1.5470 - loss: 1.2541 - main_output_accuracy: 0.7707 - main_output_loss: 0.7899
# Epoch 93: val_main_output_accuracy improved from 0.46230 to 0.46390, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5872 - auxiliary_output_loss: 1.5470 - loss: 1.2540 - main_output_accuracy: 0.7707 - main_output_loss: 0.7899 - val_auxiliary_output_accuracy: 0.3958 - val_auxiliary_output_loss: 2.9890 - val_loss: 4.2122 - val_main_output_accuracy: 0.4639 - val_main_output_loss: 3.3590 - learning_rate: 0.0048
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.004796033353726209.
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5864 - auxiliary_output_loss: 1.5438 - loss: 1.2518 - main_output_accuracy: 0.7708 - main_output_loss: 0.7887
# Epoch 94: val_main_output_accuracy did not improve from 0.46390
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.5864 - auxiliary_output_loss: 1.5437 - loss: 1.2518 - main_output_accuracy: 0.7709 - main_output_loss: 0.7887 - val_auxiliary_output_accuracy: 0.3969 - val_auxiliary_output_loss: 3.0173 - val_loss: 4.3134 - val_main_output_accuracy: 0.4630 - val_main_output_loss: 3.4641 - learning_rate: 0.0048
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.004604192019577161.
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5907 - auxiliary_output_loss: 1.5205 - loss: 1.2135 - main_output_accuracy: 0.7797 - main_output_loss: 0.7573
# Epoch 95: val_main_output_accuracy did not improve from 0.46390
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.5907 - auxiliary_output_loss: 1.5205 - loss: 1.2135 - main_output_accuracy: 0.7798 - main_output_loss: 0.7573 - val_auxiliary_output_accuracy: 0.3994 - val_auxiliary_output_loss: 3.0020 - val_loss: 4.2981 - val_main_output_accuracy: 0.4626 - val_main_output_loss: 3.4507 - learning_rate: 0.0046
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.004604192019577161.
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5937 - auxiliary_output_loss: 1.5201 - loss: 1.2049 - main_output_accuracy: 0.7798 - main_output_loss: 0.7489
# Epoch 96: val_main_output_accuracy did not improve from 0.46390
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.5937 - auxiliary_output_loss: 1.5201 - loss: 1.2049 - main_output_accuracy: 0.7798 - main_output_loss: 0.7489 - val_auxiliary_output_accuracy: 0.3902 - val_auxiliary_output_loss: 3.0166 - val_loss: 4.2049 - val_main_output_accuracy: 0.4605 - val_main_output_loss: 3.3423 - learning_rate: 0.0046
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.004604192019577161.
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - auxiliary_output_accuracy: 0.5943 - auxiliary_output_loss: 1.5084 - loss: 1.1976 - main_output_accuracy: 0.7821 - main_output_loss: 0.7451
# Epoch 97: val_main_output_accuracy improved from 0.46390 to 0.46850, saving model to googlenet_tinyimagenet_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5943 - auxiliary_output_loss: 1.5083 - loss: 1.1976 - main_output_accuracy: 0.7821 - main_output_loss: 0.7451 - val_auxiliary_output_accuracy: 0.3988 - val_auxiliary_output_loss: 2.9565 - val_loss: 4.1370 - val_main_output_accuracy: 0.4685 - val_main_output_loss: 3.2944 - learning_rate: 0.0046
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.004604192019577161.
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5953 - auxiliary_output_loss: 1.5061 - loss: 1.1809 - main_output_accuracy: 0.7848 - main_output_loss: 0.7291
# Epoch 98: val_main_output_accuracy did not improve from 0.46850
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 213s 272ms/step - auxiliary_output_accuracy: 0.5953 - auxiliary_output_loss: 1.5061 - loss: 1.1809 - main_output_accuracy: 0.7848 - main_output_loss: 0.7291 - val_auxiliary_output_accuracy: 0.3997 - val_auxiliary_output_loss: 2.9803 - val_loss: 4.2207 - val_main_output_accuracy: 0.4631 - val_main_output_loss: 3.3877 - learning_rate: 0.0046
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.004604192019577161.
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.5945 - auxiliary_output_loss: 1.4935 - loss: 1.1715 - main_output_accuracy: 0.7853 - main_output_loss: 0.7235
# Epoch 99: val_main_output_accuracy did not improve from 0.46850
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 273ms/step - auxiliary_output_accuracy: 0.5945 - auxiliary_output_loss: 1.4935 - loss: 1.1715 - main_output_accuracy: 0.7853 - main_output_loss: 0.7234 - val_auxiliary_output_accuracy: 0.4016 - val_auxiliary_output_loss: 2.9482 - val_loss: 4.2019 - val_main_output_accuracy: 0.4636 - val_main_output_loss: 3.3535 - learning_rate: 0.0046
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.004420024338794074.
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - auxiliary_output_accuracy: 0.6025 - auxiliary_output_loss: 1.4752 - loss: 1.1498 - main_output_accuracy: 0.7936 - main_output_loss: 0.7072
# Epoch 100: val_main_output_accuracy did not improve from 0.46850
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 272ms/step - auxiliary_output_accuracy: 0.6025 - auxiliary_output_loss: 1.4752 - loss: 1.1497 - main_output_accuracy: 0.7936 - main_output_loss: 0.7072 - val_auxiliary_output_accuracy: 0.4022 - val_auxiliary_output_loss: 3.0152 - val_loss: 4.2367 - val_main_output_accuracy: 0.4678 - val_main_output_loss: 3.3743 - learning_rate: 0.0044
# Restoring model weights from the end of the best epoch: 97.

# %% [markdown]
# ## Avaliação e Visualização de Resultados

# %%
# Carrega o melhor checkpoint salvo
best_model = tf.keras.models.load_model('googlenet_tinyimagenet_best.keras')

# Avalia na validação
results = best_model.evaluate(val_ds_dual, verbose=0)
print(f'\nAcurácia Final — Saída Principal (val): {results[3]*100:.2f}%')
print(f'Acurácia Final — Saída Auxiliar  (val): {results[4]*100:.2f}%')

# ── Curvas de Loss e Acurácia ────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['loss'],     label='Train Loss', color='steelblue')
axes[0].plot(history.history['val_loss'], label='Val Loss',   color='tomato')
axes[0].set_title('Curva de Loss Total')
axes[0].set_xlabel('Épocas')
axes[0].legend()
axes[0].grid(alpha=0.4)

axes[1].plot(history.history['main_output_accuracy'],     label='Train Acc', color='steelblue')
axes[1].plot(history.history['val_main_output_accuracy'], label='Val Acc',   color='tomato')
axes[1].set_title('Acurácia — Saída Principal')
axes[1].set_xlabel('Épocas')
axes[1].legend()
axes[1].grid(alpha=0.4)

plt.tight_layout()
plt.savefig('training_curves.png', dpi=150)
plt.show()
print('Gráfico salvo em training_curves.png')
# Out:
# Acurácia Final — Saída Principal (val): 39.88%
# Acurácia Final — Saída Auxiliar  (val): 46.85%
# Gráfico salvo em training_curves.png

# %% [markdown]
# ## Top-5 Accuracy
#
# No ImageNet, a métrica padrão é Top-5. Calculamos manualmente sobre o conjunto de validação.

# %%
top5_metric = tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5)

for images, (labels, _) in val_ds_dual:
    # labels estão em one-hot; convertemos para índices
    labels_idx = tf.argmax(labels, axis=1)
    main_preds = best_model(images, training=False)[0]
    top5_metric.update_state(labels_idx, main_preds)

print(f'Top-5 Accuracy (val): {top5_metric.result().numpy()*100:.2f}%')
# Out:
# Top-5 Accuracy (val): 71.78%

# %% [markdown]
# ## Predição em Imagens Externas
#
# Tiny ImageNet usa um subconjunto das 200 classes do WordNet. As classes são identificadas por códigos `nXXXXXXXX`. O dicionário abaixo mapeia código → nome legível para as classes mais comuns.

# %%
# Carrega o mapeamento class_id → nome legível (words.txt do dataset)
words_file = DATA_DIR / 'words.txt'
id_to_name = {}
if words_file.exists():
    with open(words_file, 'r') as f:
        for line in f:
            parts = line.strip().split('\t', 1)
            if len(parts) == 2:
                id_to_name[parts[0]] = parts[1].split(',')[0]  # pega o primeiro sinônimo

# Cria lista final: índice → nome legível
idx_to_readable = {}
for i, class_id in enumerate(CLASS_NAMES):
    idx_to_readable[i] = id_to_name.get(class_id, class_id)

print('Amostra de mapeamento:')
for i in range(5):
    print(f'  [{i}] {CLASS_NAMES[i]} → "{idx_to_readable[i]}')
# Out:
# Amostra de mapeamento:
#   [0] n01443537 → "goldfish
#   [1] n01629819 → "European fire salamander
#   [2] n01641577 → "bullfrog
#   [3] n01644900 → "tailed frog
#   [4] n01698640 → "American alligator

# %%
def predict_url(url, top_k=3):
    """Baixa uma imagem, redimensiona e retorna as top-k predições."""
    try:
        response = requests.get(url, timeout=10)
        img = Image.open(BytesIO(response.content)).convert('RGB')
        img_resized = img.resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)
        arr = np.array(img_resized, dtype=np.float32) / 255.0
        arr = np.expand_dims(arr, axis=0)

        # best_model retorna [main_out, aux_out]
        main_preds = best_model.predict(arr, verbose=0)[0][0]
        top_indices = np.argsort(main_preds)[::-1][:top_k]

        print(f'URL: {url.split("/")[-1]}')
        for rank, idx in enumerate(top_indices, 1):
            print(f'  Top-{rank}: {idx_to_readable[idx]} ({main_preds[idx]*100:.1f}%)')

        # Exibe imagem com predição
        fig, ax = plt.subplots(1, 1, figsize=(4, 4))
        ax.imshow(img_resized)
        ax.set_title(f'Pred: {idx_to_readable[top_indices[0]]}\n({main_preds[top_indices[0]]*100:.1f}%)',
                     fontsize=10)
        ax.axis('off')
        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f'Erro: {e}')

# Exemplos com objetos presentes no Tiny ImageNet
predict_url('https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Cat_November_2010-1a.jpg/640px-Cat_November_2010-1a.jpg')
predict_url('https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Camponotus_flavomarginatus_ant.jpg/640px-Camponotus_flavomarginatus_ant.jpg')
# Out:
# Erro: cannot identify image file <_io.BytesIO object at 0x7ca3117016c0>
# Erro: cannot identify image file <_io.BytesIO object at 0x7ca311764f40>

# %% [markdown]
# ## Resumo dos Resultados
#
# | Métrica | Valor |
# |---|---|
# | Top-1 Accuracy (val) | *(preencher após treino)* |
# | Top-5 Accuracy (val) | *(preencher após treino)* |
# | Épocas até convergência | *(preencher)* |
# | Parâmetros totais | *(ver model.summary())* |
#
# ### Referência de acurácia no Tiny ImageNet
# - Baseline MLP simples: ~5%
# - ResNet-18 padrão: ~65% Top-1
# - GoogLeNet adaptado: ~55–60% Top-1 esperado
