# %%
# exp_007 — GoogLeNet/InceptionV1 · Tiny ImageNet
# Acumula exp_006 com ajustes de regularização
# Hipótese: dropout 0.55 é excessivo com Mixup (redundância de regularização).
# Reduzir para 0.25 desbloqueia capacidade do modelo.
# Peso auxiliar 0.4 → 0.2: principais saídas já dominam, soltar âncora permite
# convergência mais natural nas épocas finais.
# SGD mantido: Adam merece experimento isolado (exp_008).

import datetime

EXPERIMENTO = {
    "id": "exp_007",
    "hipotese": (
        "Dropout 0.55 é redundante com Mixup. Reduzir para 0.25 desbloqueia modelo. "
        "Peso auxiliar 0.4 → 0.2 para convergência natural. SGD mantido."
    ),
    "mudancas": [
        "[exp_001] inception_5a: (256,160,320,32,128,128) → (192,128,256,32,96,96)",
        "[exp_001] inception_5b: (384,192,384,48,128,128) → (256,160,320,32,96,96)",
        "[exp_002] main_dropout: 0.4 → 0.55 → 0.25 [exp_007 — REDUÇÃO]",
        "[exp_004] loss_weight auxiliar: 0.3 → 0.4 → 0.2 [exp_007 — REDUÇÃO]",
        "[exp_004] ReduceLROnPlateau patience: 5 → 8",
        "[exp_004] LR warmup: 5 épocas (0.001 → 0.01)",
        "[exp_004] augmentation: nível exp_002",
        "[exp_005] stem_c2: stride=2, he_normal — sem MaxPool",
        "[exp_006] Mixup Augmentation: alpha=0.2",
        "[exp_006] label_smoothing: 0.0 (removido)",
        "[exp_007] ⚠️ DROPOUT: 0.55 → 0.25 (reduz redundância com Mixup)",
        "[exp_007] ⚠️ AUX_WEIGHT: 0.4 → 0.2 (soltar âncora auxiliar)",
    ],
    "resultado_top1": None,
    "resultado_top5": None,
    "epocas": None,
}

print(f"[{datetime.datetime.now():%Y-%m-%d %H:%M}] {EXPERIMENTO['id']}")
print(f"Hipótese: {EXPERIMENTO['hipotese']}")
print("\nMudanças acumuladas:")
for m in EXPERIMENTO["mudancas"]:
    print(f"  • {m}")
# Out:
# [2026-05-07 12:59] exp_007
# Hipótese: Dropout 0.55 é redundante com Mixup. Reduzir para 0.25 desbloqueia modelo. Peso auxiliar 0.4 → 0.2 para convergência natural. SGD mantido.
#
# Mudanças acumuladas:
#   • [exp_001] inception_5a: (256,160,320,32,128,128) → (192,128,256,32,96,96)
#   • [exp_001] inception_5b: (384,192,384,48,128,128) → (256,160,320,32,96,96)
#   • [exp_002] main_dropout: 0.4 → 0.55 → 0.25 [exp_007 — REDUÇÃO]
#   • [exp_004] loss_weight auxiliar: 0.3 → 0.4 → 0.2 [exp_007 — REDUÇÃO]
#   • [exp_004] ReduceLROnPlateau patience: 5 → 8
#   • [exp_004] LR warmup: 5 épocas (0.001 → 0.01)
#   • [exp_004] augmentation: nível exp_002
#   • [exp_005] stem_c2: stride=2, he_normal — sem MaxPool
#   • [exp_006] Mixup Augmentation: alpha=0.2
#   • [exp_006] label_smoothing: 0.0 (removido)
#   • [exp_007] ⚠️ DROPOUT: 0.55 → 0.25 (reduz redundância com Mixup)
#   • [exp_007] ⚠️ AUX_WEIGHT: 0.4 → 0.2 (soltar âncora auxiliar)

# %% [markdown]
# ## Histórico de Experimentos
#
# | ID | Mudanças-chave | Top-1 val (main) | Top-1 val (aux) | Top-5 val | Δ Top-1 |
# |---|---|---|---|---|---|
# | baseline | Modelo original | 39.88% | — | — | — |
# | exp_001 | inception_5a/5b: canais reduzidos ~30% | 40.08% | 44.76% | 71.05% | +4.88pp (aux) |
# | exp_002 | main_dropout: 0.4 → 0.55 | 39.29%* | 46.58% | 71.79% | +1.82pp (aux) |
# | exp_003 | label_smoothing 0.1 (ambas) + ReduceLR patience=5 + aug+ | 0.50% ❌ | 2.50% ❌ | 2.50% ❌ | colapso (16 épocas) |
# | exp_004 | label_smoothing 0.05 (só main) + peso aux 0.4 + warmup | 41.88% | 47.52% | 71.91% | +0.94pp (aux) |
# | exp_005 | Stem: stride conv (stem_c2 stride=2, he_normal) + sem stem_pool | **45.27%** | 38.35% | 70.31% | +3.39pp (main)† |
# | **exp_006** | **Mixup alpha=0.2 + sem label_smoothing + 120 épocas** | *(pendente)* | *(pendente)* | *(pendente)* | — |
#
# > \*O Top-1 do exp_002 reportado pelo `evaluate()` usa a saída principal (39.29%).
# > A saída auxiliar atingiu 46.58% — gap de ~7pp que exp_004/005 visam eliminar.
# >
# > †exp_005: o gap main/aux **inverteu** — a saída principal (45.27%) superou a auxiliar (38.35%)
# > pela primeira vez. Sinal de que a nova Stem melhorou o fluxo de gradiente até a cabeça principal.
# > O Δ é calculado em relação ao melhor da exp_004 (47.52% aux); comparando apenas as saídas
# > principais: exp_004 main=41.88% → exp_005 main=45.27% = **+3.39pp**.
#
# ## Resumo — exp_006
# | Métrica | Baseline | EXP01 | EXP02 | EXP03 ❌ | EXP04 | EXP05 | **EXP06** |
# |---|---|---|---|---|---|---|---|
# | Top-1 val (principal) | 39.88% | 40.08% | 39.29% | 0.50% | 41.88% | 45.27% | *(pendente)* |
# | Top-1 val (auxiliar) | — | 44.76% | 46.58% | 2.50% | 47.52% | 38.35% | *(pendente)* |
# | Top-5 val | — | 71.05% | 71.79% | 2.50% | 71.91% | 70.31% | *(pendente)* |
# | Épocas | — | 66 | 94 | 16 | 100 (melhor: 88) | 100 (melhor: 87) | *(pendente)* |
#
# **Mudanças acumuladas vs baseline:**
# - `inception_5a/5b`: canais reduzidos ~30% (exp_001)
# - `main_dropout`: 0.4 → 0.55 (exp_002)
# - `loss_weight` auxiliar: 0.3 → 0.4 (exp_004)
# - `ReduceLROnPlateau` patience: 5 → 8 (exp_004)
# - `LR warmup`: 5 épocas de 0.001 → 0.01 (exp_004)
# - `stem_c2`: stride=2, `he_normal` — `stem_pool` removido (exp_005)
# - **`Mixup` alpha=0.2 — `label_smoothing` removido (exp_006)** ← mudança isolada
# - **`EarlyStopping` patience: 20 → 25 (exp_006)**
# - **Épocas máx: 100 → 120 (exp_006)**
#
# **Por que remover label_smoothing com Mixup?**
# > Mixup já cria soft labels ao interpolar $\tilde{y} = \lambda y_i + (1-\lambda) y_j$.
# > Manter `label_smoothing=0.05` em cima disso aplica uma segunda suavização,
# > o que pode impedir que a rede aprenda fronteiras de decisão claras entre classes.
# > O efeito é cumulativo e tende a aumentar a loss sem benefício de regularização adicional.
#
# **Por que 120 épocas com Mixup?**
# > Com Mixup, a `train_loss` é artificialmente mais alta no início (problema mais difícil).
# > O modelo tipicamente converge 20-30 épocas mais tarde do que sem Mixup.
# > Nos experimentos anteriores, o melhor resultado ocorreu nas épocas 87-88 com limite de 100 —
# > havia espaço para melhoria. 120 épocas + ES patience=25 dá margem suficiente sem
# > custo computacional excessivo.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import itertools, math, csv, os, shutil, zipfile, warnings, datetime
import requests
from PIL import Image
from io import BytesIO
from pathlib import Path
from sklearn.metrics import confusion_matrix

warnings.filterwarnings('ignore')
print(f"TensorFlow: {tf.__version__}")
print(f"GPUs: {tf.config.list_physical_devices('GPU')}")
# Out:
# 2026-05-07 12:59:41.117929: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778158781.317838      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778158781.369667      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778158781.796469      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778158781.796506      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778158781.796508      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778158781.796511      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow: 2.19.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ── Hiperparâmetros ──────────────────────────────────────────────────────────
EPOCHS         = 120
BATCH_SIZE     = 128
NUM_CLASSES    = 200
IMG_SIZE       = 64
INITIAL_LR     = 0.01
WARMUP_EPOCHS  = 5
WARMUP_LR      = 0.001
DROPOUT_MAIN   = 0.25      # exp_007: 0.55 → 0.25 (reduz redundância com Mixup)
LABEL_SMOOTH   = 0.0       # Mixup já gera soft labels
AUX_WEIGHT     = 0.2       # exp_007: 0.4 → 0.2 (soltar âncora auxiliar)
MIXUP_ALPHA    = 0.2

tf.random.set_seed(42)
np.random.seed(42)
print(f"{EPOCHS} épocas | batch {BATCH_SIZE} | {IMG_SIZE}×{IMG_SIZE} | {NUM_CLASSES} classes")
print(f"dropout={DROPOUT_MAIN} [REDUZIDO] | label_smoothing={LABEL_SMOOTH} | aux_weight={AUX_WEIGHT} [REDUZIDO]")
print(f"LR warmup: {WARMUP_EPOCHS} épocas ({WARMUP_LR} → {INITIAL_LR})")
print(f"[exp_007] Mixup alpha={MIXUP_ALPHA} | EarlyStopping patience=25")
# Out:
# 120 épocas | batch 128 | 64×64 | 200 classes
# dropout=0.25 [REDUZIDO] | label_smoothing=0.0 | aux_weight=0.2 [REDUZIDO]
# LR warmup: 5 épocas (0.001 → 0.01)
# [exp_007] Mixup alpha=0.2 | EarlyStopping patience=25

# %%
TINY_URL = 'http://cs231n.stanford.edu/tiny-imagenet-200.zip'
DATA_DIR = Path('/kaggle/working/tiny-imagenet-200')
ZIP_PATH = Path('/kaggle/working/tiny-imagenet-200.zip')

if not ZIP_PATH.exists():
    print('Baixando Tiny ImageNet (~236 MB)...')
    r = requests.get(TINY_URL, stream=True)
    total = int(r.headers.get('content-length', 0))
    downloaded = 0
    with open(ZIP_PATH, 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024*1024):
            f.write(chunk)
            downloaded += len(chunk)
            print(f'\r  {downloaded/1e6:.1f}/{total/1e6:.1f} MB', end='')
    print('\nDownload completo!')
else:
    print('ZIP já existe.')

if not DATA_DIR.exists():
    print('Extraindo...')
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall('/kaggle/working')
    print('Extração concluída.')
else:
    print('Dataset já extraído.')

val_organized = DATA_DIR / 'val_organized'
if not val_organized.exists():
    print('Reorganizando val/...')
    val_organized.mkdir(parents=True)
    with open(DATA_DIR / 'val' / 'val_annotations.txt') as f:
        for line in f:
            fname, class_id = line.strip().split('\t')[:2]
            d = val_organized / class_id
            d.mkdir(exist_ok=True)
            shutil.copy(DATA_DIR / 'val' / 'images' / fname, d / fname)
    print(f'Val reorganizado: {len(list(val_organized.iterdir()))} classes')
else:
    print('val_organized já existe.')

TRAIN_DIR = DATA_DIR / 'train'
VAL_DIR   = val_organized
print(f'Treino: {TRAIN_DIR} | Val: {VAL_DIR}')
# Out:
# Baixando Tiny ImageNet (~236 MB)...
#   248.1/248.1 MB
# Download completo!
# Extraindo...
# Extração concluída.
# Reorganizando val/...
# Val reorganizado: 200 classes
# Treino: /kaggle/working/tiny-imagenet-200/train | Val: /kaggle/working/tiny-imagenet-200/val_organized

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR, image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE, label_mode='categorical', shuffle=True, seed=42
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR, image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE, label_mode='categorical', shuffle=False
)
CLASS_NAMES = train_ds.class_names
print(f'Classes: {len(CLASS_NAMES)}')

def normalize(img, lbl):
    return tf.cast(img, tf.float32) / 255.0, lbl

# Augmentation base — nível exp_002/004 (sem RandomBrightness, rotação=0.1)
# Mixup é aplicado DEPOIS da augmentation base no pipeline
augment = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomTranslation(0.1, 0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1),
], name='augmentation')

# ── Mixup ────────────────────────────────────────────────────────────────────
# Implementação vetorizada: opera sobre o batch inteiro sem loops Python.
# lambda ~ Beta(alpha, alpha); o batch é shuffled internamente para criar pares.
# Resultado: imagens e labels são misturas convexas de dois exemplos do batch.
@tf.function
def mixup(images, labels, alpha=MIXUP_ALPHA):
    batch_size = tf.shape(images)[0]

    # Amostra lambda da distribuição Beta(alpha, alpha)
    # tf.random.stateless não requer tensorflow_probability
    lam = tf.cast(
        tf.random.stateless_uniform([], seed=(42, 0), minval=0, maxval=1),
        tf.float32
    )
    # Aplica a simetria do Mixup: usa max(lam, 1-lam) para manter a imagem
    # dominante sempre acima de 0.5 — evita imagens 50/50 que confundem muito
    # Nota: para Beta(0.2,0.2) isso não é obrigatório mas melhora a legibilidade
    # dos exemplos de treino. Remova o max() para um Mixup mais agressivo.
    # lam = tf.math.maximum(lam, 1.0 - lam)

    # Shuffle do batch para criar pares aleatórios
    indices = tf.random.shuffle(tf.range(batch_size))
    images_shuffled = tf.gather(images, indices)
    labels_shuffled = tf.gather(labels, indices)

    # Interpolação
    mixed_images = lam * images + (1.0 - lam) * images_shuffled
    mixed_labels = lam * labels + (1.0 - lam) * labels_shuffled
    return mixed_images, mixed_labels

def apply_augment_and_mixup(img, lbl):
    img = augment(img, training=True)
    img, lbl = mixup(img, lbl)
    return img, lbl

train_ds = (
    train_ds
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .map(apply_augment_and_mixup, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)
# Val: SEM Mixup — avaliação sempre com imagens reais
val_ds = (
    val_ds
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)
print('Pipelines prontos (treino com Mixup, val sem Mixup).')
# Out:
# Found 100000 files belonging to 200 classes.
# I0000 00:00:1778158836.006055      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 10000 files belonging to 200 classes.
# Classes: 200
# Pipelines prontos (treino com Mixup, val sem Mixup).

# %%
def inception_module(x, f1, f3r, f3, f5r, f5, fp, name):
    """Módulo Inception: 4 ramos paralelos (Szegedy et al., 2014)."""
    ki = 'glorot_uniform'
    bi = tf.keras.initializers.Constant(0.2)
    kw = dict(padding='same', activation='relu', kernel_initializer=ki, bias_initializer=bi)

    b1 = tf.keras.layers.Conv2D(f1,  (1,1), **kw, name=f'{name}_1x1')(x)

    b2 = tf.keras.layers.Conv2D(f3r, (1,1), **kw, name=f'{name}_3x3_reduce')(x)
    b2 = tf.keras.layers.Conv2D(f3,  (3,3), **kw, name=f'{name}_3x3')(b2)

    b3 = tf.keras.layers.Conv2D(f5r, (1,1), **kw, name=f'{name}_5x5_reduce')(x)
    b3 = tf.keras.layers.Conv2D(f5,  (5,5), **kw, name=f'{name}_5x5')(b3)

    b4 = tf.keras.layers.MaxPooling2D((3,3), strides=(1,1), padding='same', name=f'{name}_pool')(x)
    b4 = tf.keras.layers.Conv2D(fp,  (1,1), **kw, name=f'{name}_pool_proj')(b4)

    return tf.keras.layers.Concatenate(axis=-1, name=name)([b1, b2, b3, b4])

# %%
def build_googlenet(num_classes=200, img_size=64, dropout=0.55):
    """
    GoogLeNet adaptado para 64×64. Acumula mudanças de exp_001 a exp_005.

    Stem (exp_005):
      Conv3x3(64, stride=1, glorot) → 64×64
      Conv3x3(64, stride=2, he_normal) → 32×32   ← downsampling aprendível
      Conv3x3(192, stride=1, glorot) → 32×32
      [sem MaxPool]

    Bloco 5 (exp_001):
      inception_5a: 640ch  (reduzido de 832ch)
      inception_5b: 768ch  (reduzido de 1024ch)

    Cabeça principal (exp_002):
      Dropout 0.55
    """
    bi    = tf.keras.initializers.Constant(0.2)
    kw_g  = dict(padding='same', activation='relu',
                 kernel_initializer='glorot_uniform', bias_initializer=bi)
    kw_he = dict(padding='same', activation='relu',
                 kernel_initializer='he_normal', bias_initializer=bi)

    inp = tf.keras.layers.Input(shape=(img_size, img_size, 3), name='input')

    # ── Stem exp_005 ─────────────────────────────────────────────────────────
    x = tf.keras.layers.Conv2D(64,  (3,3), **kw_g,             name='stem_c1')(inp)  # 64×64
    x = tf.keras.layers.Conv2D(64,  (3,3), strides=2, **kw_he, name='stem_c2')(x)    # 32×32
    x = tf.keras.layers.Conv2D(192, (3,3), **kw_g,             name='stem_c3')(x)    # 32×32

    # ── Bloco 3 ──────────────────────────────────────────────────────────────
    x = inception_module(x,  64,  96, 128, 16,  32,  32, 'inception_3a')
    x = inception_module(x, 128, 128, 192, 32,  96,  64, 'inception_3b')
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same', name='pool_3')(x)

    # ── Bloco 4 ──────────────────────────────────────────────────────────────
    x = inception_module(x, 192,  96, 208, 16,  48,  64, 'inception_4a')

    # ── Classificador Auxiliar ───────────────────────────────────────────────
    aux = tf.keras.layers.AveragePooling2D((5,5), strides=3, padding='same', name='aux_pool')(x)
    aux = tf.keras.layers.Conv2D(128, (1,1), **kw_g, name='aux_conv')(aux)
    aux = tf.keras.layers.Flatten(name='aux_flat')(aux)
    aux = tf.keras.layers.Dense(1024, activation='relu', name='aux_dense')(aux)
    aux = tf.keras.layers.Dropout(0.3, name='aux_drop')(aux)
    aux_out = tf.keras.layers.Dense(num_classes, activation='softmax', name='auxiliary_output')(aux)

    x = inception_module(x, 160, 112, 224, 24,  64,  64, 'inception_4b')
    x = inception_module(x, 128, 128, 256, 24,  64,  64, 'inception_4c')
    x = inception_module(x, 112, 144, 288, 32,  64,  64, 'inception_4d')
    x = inception_module(x, 256, 160, 320, 32, 128, 128, 'inception_4e')
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same', name='pool_4')(x)

    # ── Bloco 5 — canais reduzidos (exp_001) ─────────────────────────────────
    x = inception_module(x, 192, 128, 256, 32,  96,  96, 'inception_5a')  # 640ch
    x = inception_module(x, 256, 160, 320, 32,  96,  96, 'inception_5b')  # 768ch

    # ── Cabeça principal — dropout 0.55 (exp_002) ────────────────────────────
    x = tf.keras.layers.GlobalAveragePooling2D(name='gap')(x)
    x = tf.keras.layers.Dropout(dropout, name='main_dropout')(x)
    main_out = tf.keras.layers.Dense(num_classes, activation='softmax', name='main_output')(x)

    return tf.keras.Model(inputs=inp, outputs=[main_out, aux_out], name='GoogLeNet_exp007')


model = build_googlenet(NUM_CLASSES, IMG_SIZE, DROPOUT_MAIN)
model.summary()

print("\n── Verificação Stem exp_005/006 ──")
for name in ['stem_c1', 'stem_c2', 'stem_c3']:
    layer = model.get_layer(name)
    print(f"  {name}: output={layer.output.shape} | "
          f"kernel_initializer={layer.kernel_initializer.__class__.__name__} | "
          f"strides={layer.strides}")
# Out:
# Model: "GoogLeNet_exp007"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 64, 64, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_c1 (Conv2D)    │ (None, 64, 64,    │      1,792 │ input[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_c2 (Conv2D)    │ (None, 32, 32,    │     36,928 │ stem_c1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_c3 (Conv2D)    │ (None, 32, 32,    │    110,784 │ stem_c2[0][0]     │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3_r… │ (None, 32, 32,    │     18,528 │ stem_c3[0][0]     │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5_r… │ (None, 32, 32,    │      3,088 │ stem_c3[0][0]     │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool   │ (None, 32, 32,    │          0 │ stem_c3[0][0]     │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_1x1    │ (None, 32, 32,    │     12,352 │ stem_c3[0][0]     │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3    │ (None, 32, 32,    │    110,720 │ inception_3a_3x3… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5    │ (None, 32, 32,    │     12,832 │ inception_3a_5x5… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool_… │ (None, 32, 32,    │      6,176 │ inception_3a_poo… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a        │ (None, 32, 32,    │          0 │ inception_3a_1x1… │
# │ (Concatenate)       │ 256)              │            │ inception_3a_3x3… │
# │                     │                   │            │ inception_3a_5x5… │
# │                     │                   │            │ inception_3a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3_r… │ (None, 32, 32,    │     32,896 │ inception_3a[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5_r… │ (None, 32, 32,    │      8,224 │ inception_3a[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool   │ (None, 32, 32,    │          0 │ inception_3a[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_1x1    │ (None, 32, 32,    │     32,896 │ inception_3a[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3    │ (None, 32, 32,    │    221,376 │ inception_3b_3x3… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5    │ (None, 32, 32,    │     76,896 │ inception_3b_5x5… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool_… │ (None, 32, 32,    │     16,448 │ inception_3b_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b        │ (None, 32, 32,    │          0 │ inception_3b_1x1… │
# │ (Concatenate)       │ 480)              │            │ inception_3b_3x3… │
# │                     │                   │            │ inception_3b_5x5… │
# │                     │                   │            │ inception_3b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_3              │ (None, 16, 16,    │          0 │ inception_3b[0][… │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3_r… │ (None, 16, 16,    │     46,176 │ pool_3[0][0]      │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5_r… │ (None, 16, 16,    │      7,696 │ pool_3[0][0]      │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool   │ (None, 16, 16,    │          0 │ pool_3[0][0]      │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_1x1    │ (None, 16, 16,    │     92,352 │ pool_3[0][0]      │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3    │ (None, 16, 16,    │    179,920 │ inception_4a_3x3… │
# │ (Conv2D)            │ 208)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5    │ (None, 16, 16,    │     19,248 │ inception_4a_5x5… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool_… │ (None, 16, 16,    │     30,784 │ inception_4a_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a        │ (None, 16, 16,    │          0 │ inception_4a_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4a_3x3… │
# │                     │                   │            │ inception_4a_5x5… │
# │                     │                   │            │ inception_4a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_3x3_r… │ (None, 16, 16,    │     57,456 │ inception_4a[0][… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_5x5_r… │ (None, 16, 16,    │     12,312 │ inception_4a[0][… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_pool   │ (None, 16, 16,    │          0 │ inception_4a[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_1x1    │ (None, 16, 16,    │     82,080 │ inception_4a[0][… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_3x3    │ (None, 16, 16,    │    226,016 │ inception_4b_3x3… │
# │ (Conv2D)            │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_5x5    │ (None, 16, 16,    │     38,464 │ inception_4b_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_pool_… │ (None, 16, 16,    │     32,832 │ inception_4b_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b        │ (None, 16, 16,    │          0 │ inception_4b_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4b_3x3… │
# │                     │                   │            │ inception_4b_5x5… │
# │                     │                   │            │ inception_4b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_3x3_r… │ (None, 16, 16,    │     65,664 │ inception_4b[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_5x5_r… │ (None, 16, 16,    │     12,312 │ inception_4b[0][… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_pool   │ (None, 16, 16,    │          0 │ inception_4b[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_1x1    │ (None, 16, 16,    │     65,664 │ inception_4b[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_3x3    │ (None, 16, 16,    │    295,168 │ inception_4c_3x3… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_5x5    │ (None, 16, 16,    │     38,464 │ inception_4c_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_pool_… │ (None, 16, 16,    │     32,832 │ inception_4c_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c        │ (None, 16, 16,    │          0 │ inception_4c_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4c_3x3… │
# │                     │                   │            │ inception_4c_5x5… │
# │                     │                   │            │ inception_4c_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_3x3_r… │ (None, 16, 16,    │     73,872 │ inception_4c[0][… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_5x5_r… │ (None, 16, 16,    │     16,416 │ inception_4c[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_pool   │ (None, 16, 16,    │          0 │ inception_4c[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_1x1    │ (None, 16, 16,    │     57,456 │ inception_4c[0][… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_3x3    │ (None, 16, 16,    │    373,536 │ inception_4d_3x3… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_5x5    │ (None, 16, 16,    │     51,264 │ inception_4d_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_pool_… │ (None, 16, 16,    │     32,832 │ inception_4d_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d        │ (None, 16, 16,    │          0 │ inception_4d_1x1… │
# │ (Concatenate)       │ 528)              │            │ inception_4d_3x3… │
# │                     │                   │            │ inception_4d_5x5… │
# │                     │                   │            │ inception_4d_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3_r… │ (None, 16, 16,    │     84,640 │ inception_4d[0][… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5_r… │ (None, 16, 16,    │     16,928 │ inception_4d[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_pool   │ (None, 16, 16,    │          0 │ inception_4d[0][… │
# │ (MaxPooling2D)      │ 528)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_1x1    │ (None, 16, 16,    │    135,424 │ inception_4d[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3    │ (None, 16, 16,    │    461,120 │ inception_4e_3x3… │
# │ (Conv2D)            │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5    │ (None, 16, 16,    │    102,528 │ inception_4e_5x5… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_pool_… │ (None, 16, 16,    │     67,712 │ inception_4e_poo… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e        │ (None, 16, 16,    │          0 │ inception_4e_1x1… │
# │ (Concatenate)       │ 832)              │            │ inception_4e_3x3… │
# │                     │                   │            │ inception_4e_5x5… │
# │                     │                   │            │ inception_4e_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_4              │ (None, 8, 8, 832) │          0 │ inception_4e[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3_r… │ (None, 8, 8, 128) │    106,624 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_5x5_r… │ (None, 8, 8, 32)  │     26,656 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool   │ (None, 8, 8, 832) │          0 │ pool_4[0][0]      │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_1x1    │ (None, 8, 8, 192) │    159,936 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3    │ (None, 8, 8, 256) │    295,168 │ inception_5a_3x3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_5x5    │ (None, 8, 8, 96)  │     76,896 │ inception_5a_5x5… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool_… │ (None, 8, 8, 96)  │     79,968 │ inception_5a_poo… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a        │ (None, 8, 8, 640) │          0 │ inception_5a_1x1… │
# │ (Concatenate)       │                   │            │ inception_5a_3x3… │
# │                     │                   │            │ inception_5a_5x5… │
# │                     │                   │            │ inception_5a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3_r… │ (None, 8, 8, 160) │    102,560 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_5x5_r… │ (None, 8, 8, 32)  │     20,512 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool   │ (None, 8, 8, 640) │          0 │ inception_5a[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_pool            │ (None, 6, 6, 512) │          0 │ inception_4a[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_1x1    │ (None, 8, 8, 256) │    164,096 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3    │ (None, 8, 8, 320) │    461,120 │ inception_5b_3x3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_5x5    │ (None, 8, 8, 96)  │     76,896 │ inception_5b_5x5… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool_… │ (None, 8, 8, 96)  │     61,536 │ inception_5b_poo… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_conv (Conv2D)   │ (None, 6, 6, 128) │     65,664 │ aux_pool[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b        │ (None, 8, 8, 768) │          0 │ inception_5b_1x1… │
# │ (Concatenate)       │                   │            │ inception_5b_3x3… │
# │                     │                   │            │ inception_5b_5x5… │
# │                     │                   │            │ inception_5b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_flat (Flatten)  │ (None, 4608)      │          0 │ aux_conv[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 768)       │          0 │ inception_5b[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_dense (Dense)   │ (None, 1024)      │  4,719,616 │ aux_flat[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_dropout        │ (None, 768)       │          0 │ gap[0][0]         │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_drop (Dropout)  │ (None, 1024)      │          0 │ aux_dense[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_output (Dense) │ (None, 200)       │    153,800 │ main_dropout[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ auxiliary_output    │ (None, 200)       │    205,000 │ aux_drop[0][0]    │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,287,152 (39.24 MB)
#  Trainable params: 10,287,152 (39.24 MB)
#  Non-trainable params: 0 (0.00 B)
# ── Verificação Stem exp_005/006 ──
#   stem_c1: output=(None, 64, 64, 64) | kernel_initializer=GlorotUniform | strides=(1, 1)
#   stem_c2: output=(None, 32, 32, 64) | kernel_initializer=HeNormal | strides=(2, 2)
#   stem_c3: output=(None, 32, 32, 192) | kernel_initializer=GlorotUniform | strides=(1, 1)

# %%
# exp_007: label_smoothing=0.0 (Mixup já suaviza)
# AUX_WEIGHT reduzido de 0.4 para 0.2
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=WARMUP_LR, momentum=0.9, nesterov=True),
    loss={
        'main_output':      tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.0),
        'auxiliary_output': tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.0),
    },
    loss_weights={'main_output': 1.0, 'auxiliary_output': AUX_WEIGHT},
    metrics={'main_output': ['accuracy'], 'auxiliary_output': ['accuracy']},
)
print('Compilado com sucesso.')
print(f'  LR inicial (warmup): {WARMUP_LR} | LR alvo: {INITIAL_LR}')
print(f'  label_smoothing: 0.0 (removido — Mixup gera soft labels)')
print(f'  loss_weights: main=1.0 | auxiliary={AUX_WEIGHT} [REDUZIDO]')
# Out:
# Compilado com sucesso.
#   LR inicial (warmup): 0.001 | LR alvo: 0.01
#   label_smoothing: 0.0 (removido — Mixup gera soft labels)
#   loss_weights: main=1.0 | auxiliary=0.2 [REDUZIDO]

# %%
class LRWarmupCallback(tf.keras.callbacks.Callback):
    """Sobe o LR linearmente de warmup_lr até target_lr ao longo de warmup_epochs."""
    def __init__(self, warmup_epochs, warmup_lr, target_lr):
        super().__init__()
        self.warmup_epochs = warmup_epochs
        self.warmup_lr     = warmup_lr
        self.target_lr     = target_lr

    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.warmup_epochs:
            lr = self.warmup_lr + (self.target_lr - self.warmup_lr) * (epoch / self.warmup_epochs)
            self.model.optimizer.learning_rate.assign(lr)
            print(f'  [warmup] época {epoch+1}/{self.warmup_epochs} — LR = {lr:.5f}')
        elif epoch == self.warmup_epochs:
            self.model.optimizer.learning_rate.assign(self.target_lr)
            print(f'  [warmup] concluído — LR fixado em {self.target_lr}')

callbacks = [
    LRWarmupCallback(
        warmup_epochs=WARMUP_EPOCHS,
        warmup_lr=WARMUP_LR,
        target_lr=INITIAL_LR,
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_main_output_accuracy', factor=0.5,
        patience=8, min_lr=1e-5, verbose=1, mode='max'
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_main_output_accuracy', patience=25,   # exp_006: 20 → 25
        restore_best_weights=True, verbose=1, mode='max'
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'googlenet_exp007_best.keras', monitor='val_main_output_accuracy',
        save_best_only=True, verbose=1, mode='max'
    ),
    tf.keras.callbacks.CSVLogger('training_log_exp007.csv'),
]

# %%
def dual_labels(img, lbl):
    return img, (lbl, lbl)

train_ds_dual = train_ds.map(dual_labels)
val_ds_dual   = val_ds.map(dual_labels)

print(f'Iniciando exp_007 — {EPOCHS} épocas máx. | Mixup alpha={MIXUP_ALPHA}')
print(f'[Dropout: {DROPOUT_MAIN} | Aux Weight: {AUX_WEIGHT}]')
history = model.fit(
    train_ds_dual,
    validation_data=val_ds_dual,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Iniciando exp_007 — 120 épocas máx. | Mixup alpha=0.2
# [Dropout: 0.25 | Aux Weight: 0.2]
#   [warmup] época 1/5 — LR = 0.00100
# Epoch 1/120
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778158848.955057      75 service.cc:152] XLA service 0x7cfa180030a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778158848.955101      75 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1778158850.869809      75 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1778158882.383526      75 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - auxiliary_output_accuracy: 0.0046 - auxiliary_output_loss: 5.3515 - loss: 6.4098 - main_output_accuracy: 0.0050 - main_output_loss: 5.3395
# Epoch 1: val_main_output_accuracy improved from -inf to 0.00580, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 264s 283ms/step - auxiliary_output_accuracy: 0.0046 - auxiliary_output_loss: 5.3515 - loss: 6.4098 - main_output_accuracy: 0.0050 - main_output_loss: 5.3395 - val_auxiliary_output_accuracy: 0.0030 - val_auxiliary_output_loss: 5.2969 - val_loss: 6.3601 - val_main_output_accuracy: 0.0058 - val_main_output_loss: 5.3004 - learning_rate: 0.0010
#   [warmup] época 2/5 — LR = 0.00280
# Epoch 2/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.0053 - auxiliary_output_loss: 5.3005 - loss: 6.3665 - main_output_accuracy: 0.0046 - main_output_loss: 5.3064
# Epoch 2: val_main_output_accuracy did not improve from 0.00580
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.0053 - auxiliary_output_loss: 5.3005 - loss: 6.3665 - main_output_accuracy: 0.0046 - main_output_loss: 5.3064 - val_auxiliary_output_accuracy: 0.0064 - val_auxiliary_output_loss: 5.2949 - val_loss: 6.3577 - val_main_output_accuracy: 0.0050 - val_main_output_loss: 5.2985 - learning_rate: 0.0028
#   [warmup] época 3/5 — LR = 0.00460
# Epoch 3/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.0067 - auxiliary_output_loss: 5.2943 - loss: 6.3569 - main_output_accuracy: 0.0055 - main_output_loss: 5.2981
# Epoch 3: val_main_output_accuracy improved from 0.00580 to 0.01030, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.0067 - auxiliary_output_loss: 5.2943 - loss: 6.3569 - main_output_accuracy: 0.0055 - main_output_loss: 5.2981 - val_auxiliary_output_accuracy: 0.0124 - val_auxiliary_output_loss: 5.2038 - val_loss: 6.2309 - val_main_output_accuracy: 0.0103 - val_main_output_loss: 5.1911 - learning_rate: 0.0046
#   [warmup] época 4/5 — LR = 0.00640
# Epoch 4/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.0126 - auxiliary_output_loss: 5.2332 - loss: 6.2765 - main_output_accuracy: 0.0111 - main_output_loss: 5.2299
# Epoch 4: val_main_output_accuracy improved from 0.01030 to 0.01730, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.0126 - auxiliary_output_loss: 5.2332 - loss: 6.2765 - main_output_accuracy: 0.0111 - main_output_loss: 5.2299 - val_auxiliary_output_accuracy: 0.0205 - val_auxiliary_output_loss: 5.0858 - val_loss: 6.1232 - val_main_output_accuracy: 0.0173 - val_main_output_loss: 5.1071 - learning_rate: 0.0064
#   [warmup] época 5/5 — LR = 0.00820
# Epoch 5/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.0183 - auxiliary_output_loss: 5.1802 - loss: 6.2146 - main_output_accuracy: 0.0161 - main_output_loss: 5.1786
# Epoch 5: val_main_output_accuracy improved from 0.01730 to 0.02250, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.0183 - auxiliary_output_loss: 5.1801 - loss: 6.2146 - main_output_accuracy: 0.0161 - main_output_loss: 5.1786 - val_auxiliary_output_accuracy: 0.0294 - val_auxiliary_output_loss: 5.0092 - val_loss: 6.0193 - val_main_output_accuracy: 0.0225 - val_main_output_loss: 5.0192 - learning_rate: 0.0082
#   [warmup] concluído — LR fixado em 0.01
# Epoch 6/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.0244 - auxiliary_output_loss: 5.1345 - loss: 6.1592 - main_output_accuracy: 0.0219 - main_output_loss: 5.1323
# Epoch 6: val_main_output_accuracy improved from 0.02250 to 0.03250, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.0244 - auxiliary_output_loss: 5.1344 - loss: 6.1591 - main_output_accuracy: 0.0219 - main_output_loss: 5.1323 - val_auxiliary_output_accuracy: 0.0392 - val_auxiliary_output_loss: 4.8796 - val_loss: 5.9091 - val_main_output_accuracy: 0.0325 - val_main_output_loss: 4.9331 - learning_rate: 0.0100
# Epoch 7/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.0371 - auxiliary_output_loss: 5.0576 - loss: 6.0776 - main_output_accuracy: 0.0303 - main_output_loss: 5.0660
# Epoch 7: val_main_output_accuracy improved from 0.03250 to 0.05650, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.0371 - auxiliary_output_loss: 5.0576 - loss: 6.0775 - main_output_accuracy: 0.0303 - main_output_loss: 5.0660 - val_auxiliary_output_accuracy: 0.0654 - val_auxiliary_output_loss: 4.6724 - val_loss: 5.6446 - val_main_output_accuracy: 0.0565 - val_main_output_loss: 4.7105 - learning_rate: 0.0100
# Epoch 8/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.0519 - auxiliary_output_loss: 4.9637 - loss: 5.9633 - main_output_accuracy: 0.0470 - main_output_loss: 4.9706
# Epoch 8: val_main_output_accuracy improved from 0.05650 to 0.06000, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.0519 - auxiliary_output_loss: 4.9637 - loss: 5.9633 - main_output_accuracy: 0.0470 - main_output_loss: 4.9706 - val_auxiliary_output_accuracy: 0.0713 - val_auxiliary_output_loss: 4.6008 - val_loss: 5.5803 - val_main_output_accuracy: 0.0600 - val_main_output_loss: 4.6654 - learning_rate: 0.0100
# Epoch 9/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.0628 - auxiliary_output_loss: 4.8985 - loss: 5.8767 - main_output_accuracy: 0.0607 - main_output_loss: 4.8970
# Epoch 9: val_main_output_accuracy improved from 0.06000 to 0.07530, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.0628 - auxiliary_output_loss: 4.8985 - loss: 5.8767 - main_output_accuracy: 0.0607 - main_output_loss: 4.8970 - val_auxiliary_output_accuracy: 0.0846 - val_auxiliary_output_loss: 4.4856 - val_loss: 5.3914 - val_main_output_accuracy: 0.0753 - val_main_output_loss: 4.4943 - learning_rate: 0.0100
# Epoch 10/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.0743 - auxiliary_output_loss: 4.8403 - loss: 5.7948 - main_output_accuracy: 0.0741 - main_output_loss: 4.8268
# Epoch 10: val_main_output_accuracy improved from 0.07530 to 0.07990, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.0743 - auxiliary_output_loss: 4.8403 - loss: 5.7948 - main_output_accuracy: 0.0741 - main_output_loss: 4.8267 - val_auxiliary_output_accuracy: 0.0957 - val_auxiliary_output_loss: 4.4086 - val_loss: 5.3646 - val_main_output_accuracy: 0.0799 - val_main_output_loss: 4.4912 - learning_rate: 0.0100
# Epoch 11/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.0857 - auxiliary_output_loss: 4.7881 - loss: 5.7169 - main_output_accuracy: 0.0864 - main_output_loss: 4.7593
# Epoch 11: val_main_output_accuracy improved from 0.07990 to 0.12550, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.0857 - auxiliary_output_loss: 4.7881 - loss: 5.7168 - main_output_accuracy: 0.0864 - main_output_loss: 4.7592 - val_auxiliary_output_accuracy: 0.1217 - val_auxiliary_output_loss: 4.2035 - val_loss: 4.9978 - val_main_output_accuracy: 0.1255 - val_main_output_loss: 4.1561 - learning_rate: 0.0100
# Epoch 12/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.0973 - auxiliary_output_loss: 4.7298 - loss: 5.6342 - main_output_accuracy: 0.1030 - main_output_loss: 4.6883
# Epoch 12: val_main_output_accuracy improved from 0.12550 to 0.15680, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.0973 - auxiliary_output_loss: 4.7298 - loss: 5.6342 - main_output_accuracy: 0.1030 - main_output_loss: 4.6883 - val_auxiliary_output_accuracy: 0.1447 - val_auxiliary_output_loss: 4.0298 - val_loss: 4.7773 - val_main_output_accuracy: 0.1568 - val_main_output_loss: 3.9772 - learning_rate: 0.0100
# Epoch 13/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.1078 - auxiliary_output_loss: 4.6706 - loss: 5.5522 - main_output_accuracy: 0.1195 - main_output_loss: 4.6181
# Epoch 13: val_main_output_accuracy did not improve from 0.15680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.1078 - auxiliary_output_loss: 4.6706 - loss: 5.5522 - main_output_accuracy: 0.1195 - main_output_loss: 4.6181 - val_auxiliary_output_accuracy: 0.1546 - val_auxiliary_output_loss: 3.9824 - val_loss: 4.7747 - val_main_output_accuracy: 0.1549 - val_main_output_loss: 3.9923 - learning_rate: 0.0100
# Epoch 14/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1201 - auxiliary_output_loss: 4.6267 - loss: 5.4883 - main_output_accuracy: 0.1314 - main_output_loss: 4.5630
# Epoch 14: val_main_output_accuracy did not improve from 0.15680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 237ms/step - auxiliary_output_accuracy: 0.1201 - auxiliary_output_loss: 4.6267 - loss: 5.4883 - main_output_accuracy: 0.1314 - main_output_loss: 4.5630 - val_auxiliary_output_accuracy: 0.1533 - val_auxiliary_output_loss: 4.0210 - val_loss: 4.8114 - val_main_output_accuracy: 0.1474 - val_main_output_loss: 4.0241 - learning_rate: 0.0100
# Epoch 15/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1261 - auxiliary_output_loss: 4.5791 - loss: 5.4263 - main_output_accuracy: 0.1420 - main_output_loss: 4.5105
# Epoch 15: val_main_output_accuracy improved from 0.15680 to 0.17810, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.1261 - auxiliary_output_loss: 4.5790 - loss: 5.4263 - main_output_accuracy: 0.1421 - main_output_loss: 4.5105 - val_auxiliary_output_accuracy: 0.1783 - val_auxiliary_output_loss: 3.8458 - val_loss: 4.5758 - val_main_output_accuracy: 0.1781 - val_main_output_loss: 3.8143 - learning_rate: 0.0100
# Epoch 16/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1367 - auxiliary_output_loss: 4.5441 - loss: 5.3724 - main_output_accuracy: 0.1538 - main_output_loss: 4.4636
# Epoch 16: val_main_output_accuracy did not improve from 0.17810
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.1367 - auxiliary_output_loss: 4.5441 - loss: 5.3724 - main_output_accuracy: 0.1538 - main_output_loss: 4.4636 - val_auxiliary_output_accuracy: 0.1478 - val_auxiliary_output_loss: 4.0411 - val_loss: 4.8434 - val_main_output_accuracy: 0.1528 - val_main_output_loss: 4.0416 - learning_rate: 0.0100
# Epoch 17/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1449 - auxiliary_output_loss: 4.5117 - loss: 5.3216 - main_output_accuracy: 0.1676 - main_output_loss: 4.4192
# Epoch 17: val_main_output_accuracy improved from 0.17810 to 0.19070, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.1449 - auxiliary_output_loss: 4.5117 - loss: 5.3216 - main_output_accuracy: 0.1676 - main_output_loss: 4.4192 - val_auxiliary_output_accuracy: 0.1718 - val_auxiliary_output_loss: 3.8585 - val_loss: 4.4941 - val_main_output_accuracy: 0.1907 - val_main_output_loss: 3.7295 - learning_rate: 0.0100
# Epoch 18/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.1502 - auxiliary_output_loss: 4.4819 - loss: 5.2774 - main_output_accuracy: 0.1729 - main_output_loss: 4.3810
# Epoch 18: val_main_output_accuracy improved from 0.19070 to 0.22290, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.1502 - auxiliary_output_loss: 4.4819 - loss: 5.2774 - main_output_accuracy: 0.1729 - main_output_loss: 4.3810 - val_auxiliary_output_accuracy: 0.1906 - val_auxiliary_output_loss: 3.7791 - val_loss: 4.2940 - val_main_output_accuracy: 0.2229 - val_main_output_loss: 3.5507 - learning_rate: 0.0100
# Epoch 19/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.1580 - auxiliary_output_loss: 4.4542 - loss: 5.2377 - main_output_accuracy: 0.1841 - main_output_loss: 4.3469
# Epoch 19: val_main_output_accuracy did not improve from 0.22290
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.1580 - auxiliary_output_loss: 4.4542 - loss: 5.2377 - main_output_accuracy: 0.1841 - main_output_loss: 4.3468 - val_auxiliary_output_accuracy: 0.1669 - val_auxiliary_output_loss: 3.9302 - val_loss: 4.5226 - val_main_output_accuracy: 0.1910 - val_main_output_loss: 3.7440 - learning_rate: 0.0100
# Epoch 20/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1631 - auxiliary_output_loss: 4.4303 - loss: 5.1990 - main_output_accuracy: 0.1927 - main_output_loss: 4.3129
# Epoch 20: val_main_output_accuracy did not improve from 0.22290
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 237ms/step - auxiliary_output_accuracy: 0.1631 - auxiliary_output_loss: 4.4302 - loss: 5.1990 - main_output_accuracy: 0.1927 - main_output_loss: 4.3129 - val_auxiliary_output_accuracy: 0.1797 - val_auxiliary_output_loss: 3.8621 - val_loss: 4.4435 - val_main_output_accuracy: 0.2034 - val_main_output_loss: 3.6849 - learning_rate: 0.0100
# Epoch 21/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.1674 - auxiliary_output_loss: 4.4120 - loss: 5.1676 - main_output_accuracy: 0.2020 - main_output_loss: 4.2852
# Epoch 21: val_main_output_accuracy did not improve from 0.22290
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.1674 - auxiliary_output_loss: 4.4120 - loss: 5.1676 - main_output_accuracy: 0.2020 - main_output_loss: 4.2852 - val_auxiliary_output_accuracy: 0.1821 - val_auxiliary_output_loss: 3.8439 - val_loss: 4.4467 - val_main_output_accuracy: 0.2026 - val_main_output_loss: 3.6883 - learning_rate: 0.0100
# Epoch 22/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1717 - auxiliary_output_loss: 4.3893 - loss: 5.1330 - main_output_accuracy: 0.2082 - main_output_loss: 4.2551
# Epoch 22: val_main_output_accuracy improved from 0.22290 to 0.23690, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.1717 - auxiliary_output_loss: 4.3893 - loss: 5.1329 - main_output_accuracy: 0.2082 - main_output_loss: 4.2551 - val_auxiliary_output_accuracy: 0.1989 - val_auxiliary_output_loss: 3.7246 - val_loss: 4.1774 - val_main_output_accuracy: 0.2369 - val_main_output_loss: 3.4519 - learning_rate: 0.0100
# Epoch 23/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1773 - auxiliary_output_loss: 4.3718 - loss: 5.1060 - main_output_accuracy: 0.2176 - main_output_loss: 4.2316
# Epoch 23: val_main_output_accuracy did not improve from 0.23690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 237ms/step - auxiliary_output_accuracy: 0.1773 - auxiliary_output_loss: 4.3718 - loss: 5.1060 - main_output_accuracy: 0.2176 - main_output_loss: 4.2316 - val_auxiliary_output_accuracy: 0.1882 - val_auxiliary_output_loss: 3.7792 - val_loss: 4.2986 - val_main_output_accuracy: 0.2237 - val_main_output_loss: 3.5490 - learning_rate: 0.0100
# Epoch 24/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1788 - auxiliary_output_loss: 4.3606 - loss: 5.0833 - main_output_accuracy: 0.2213 - main_output_loss: 4.2112
# Epoch 24: val_main_output_accuracy did not improve from 0.23690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 237ms/step - auxiliary_output_accuracy: 0.1788 - auxiliary_output_loss: 4.3606 - loss: 5.0833 - main_output_accuracy: 0.2213 - main_output_loss: 4.2111 - val_auxiliary_output_accuracy: 0.1863 - val_auxiliary_output_loss: 3.8070 - val_loss: 4.3350 - val_main_output_accuracy: 0.2161 - val_main_output_loss: 3.5925 - learning_rate: 0.0100
# Epoch 25/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1816 - auxiliary_output_loss: 4.3435 - loss: 5.0564 - main_output_accuracy: 0.2281 - main_output_loss: 4.1877
# Epoch 25: val_main_output_accuracy did not improve from 0.23690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 237ms/step - auxiliary_output_accuracy: 0.1816 - auxiliary_output_loss: 4.3434 - loss: 5.0564 - main_output_accuracy: 0.2281 - main_output_loss: 4.1877 - val_auxiliary_output_accuracy: 0.1912 - val_auxiliary_output_loss: 3.7793 - val_loss: 4.2893 - val_main_output_accuracy: 0.2278 - val_main_output_loss: 3.5430 - learning_rate: 0.0100
# Epoch 26/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1866 - auxiliary_output_loss: 4.3289 - loss: 5.0355 - main_output_accuracy: 0.2357 - main_output_loss: 4.1697
# Epoch 26: val_main_output_accuracy did not improve from 0.23690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.1866 - auxiliary_output_loss: 4.3289 - loss: 5.0355 - main_output_accuracy: 0.2357 - main_output_loss: 4.1697 - val_auxiliary_output_accuracy: 0.2030 - val_auxiliary_output_loss: 3.7004 - val_loss: 4.2080 - val_main_output_accuracy: 0.2349 - val_main_output_loss: 3.4786 - learning_rate: 0.0100
# Epoch 27/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1904 - auxiliary_output_loss: 4.3175 - loss: 5.0116 - main_output_accuracy: 0.2420 - main_output_loss: 4.1481
# Epoch 27: val_main_output_accuracy improved from 0.23690 to 0.25330, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.1904 - auxiliary_output_loss: 4.3175 - loss: 5.0116 - main_output_accuracy: 0.2420 - main_output_loss: 4.1481 - val_auxiliary_output_accuracy: 0.2189 - val_auxiliary_output_loss: 3.6273 - val_loss: 4.1405 - val_main_output_accuracy: 0.2533 - val_main_output_loss: 3.4353 - learning_rate: 0.0100
# Epoch 28/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.1946 - auxiliary_output_loss: 4.3008 - loss: 4.9886 - main_output_accuracy: 0.2464 - main_output_loss: 4.1285
# Epoch 28: val_main_output_accuracy improved from 0.25330 to 0.27060, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.1946 - auxiliary_output_loss: 4.3008 - loss: 4.9886 - main_output_accuracy: 0.2464 - main_output_loss: 4.1284 - val_auxiliary_output_accuracy: 0.2270 - val_auxiliary_output_loss: 3.5653 - val_loss: 3.9725 - val_main_output_accuracy: 0.2706 - val_main_output_loss: 3.2766 - learning_rate: 0.0100
# Epoch 29/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.1978 - auxiliary_output_loss: 4.2891 - loss: 4.9683 - main_output_accuracy: 0.2511 - main_output_loss: 4.1104
# Epoch 29: val_main_output_accuracy improved from 0.27060 to 0.27710, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.1978 - auxiliary_output_loss: 4.2891 - loss: 4.9682 - main_output_accuracy: 0.2511 - main_output_loss: 4.1104 - val_auxiliary_output_accuracy: 0.2250 - val_auxiliary_output_loss: 3.5784 - val_loss: 3.9670 - val_main_output_accuracy: 0.2771 - val_main_output_loss: 3.2689 - learning_rate: 0.0100
# Epoch 30/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2005 - auxiliary_output_loss: 4.2737 - loss: 4.9424 - main_output_accuracy: 0.2578 - main_output_loss: 4.0876
# Epoch 30: val_main_output_accuracy did not improve from 0.27710
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2005 - auxiliary_output_loss: 4.2737 - loss: 4.9423 - main_output_accuracy: 0.2579 - main_output_loss: 4.0876 - val_auxiliary_output_accuracy: 0.2156 - val_auxiliary_output_loss: 3.6062 - val_loss: 4.0446 - val_main_output_accuracy: 0.2631 - val_main_output_loss: 3.3374 - learning_rate: 0.0100
# Epoch 31/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2035 - auxiliary_output_loss: 4.2651 - loss: 4.9272 - main_output_accuracy: 0.2634 - main_output_loss: 4.0742
# Epoch 31: val_main_output_accuracy did not improve from 0.27710
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.2035 - auxiliary_output_loss: 4.2651 - loss: 4.9272 - main_output_accuracy: 0.2634 - main_output_loss: 4.0742 - val_auxiliary_output_accuracy: 0.2128 - val_auxiliary_output_loss: 3.6222 - val_loss: 4.0469 - val_main_output_accuracy: 0.2605 - val_main_output_loss: 3.3298 - learning_rate: 0.0100
# Epoch 32/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2081 - auxiliary_output_loss: 4.2522 - loss: 4.9014 - main_output_accuracy: 0.2715 - main_output_loss: 4.0509
# Epoch 32: val_main_output_accuracy did not improve from 0.27710
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 186s 238ms/step - auxiliary_output_accuracy: 0.2081 - auxiliary_output_loss: 4.2522 - loss: 4.9013 - main_output_accuracy: 0.2715 - main_output_loss: 4.0509 - val_auxiliary_output_accuracy: 0.2096 - val_auxiliary_output_loss: 3.6448 - val_loss: 4.0739 - val_main_output_accuracy: 0.2591 - val_main_output_loss: 3.3555 - learning_rate: 0.0100
# Epoch 33/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2115 - auxiliary_output_loss: 4.2386 - loss: 4.8814 - main_output_accuracy: 0.2749 - main_output_loss: 4.0337
# Epoch 33: val_main_output_accuracy did not improve from 0.27710
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2115 - auxiliary_output_loss: 4.2386 - loss: 4.8814 - main_output_accuracy: 0.2749 - main_output_loss: 4.0336 - val_auxiliary_output_accuracy: 0.2311 - val_auxiliary_output_loss: 3.5542 - val_loss: 3.9900 - val_main_output_accuracy: 0.2761 - val_main_output_loss: 3.3027 - learning_rate: 0.0100
# Epoch 34/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2153 - auxiliary_output_loss: 4.2235 - loss: 4.8614 - main_output_accuracy: 0.2800 - main_output_loss: 4.0167
# Epoch 34: val_main_output_accuracy did not improve from 0.27710
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2153 - auxiliary_output_loss: 4.2235 - loss: 4.8614 - main_output_accuracy: 0.2800 - main_output_loss: 4.0167 - val_auxiliary_output_accuracy: 0.2291 - val_auxiliary_output_loss: 3.5501 - val_loss: 4.0537 - val_main_output_accuracy: 0.2614 - val_main_output_loss: 3.3525 - learning_rate: 0.0100
# Epoch 35/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2155 - auxiliary_output_loss: 4.2130 - loss: 4.8445 - main_output_accuracy: 0.2822 - main_output_loss: 4.0019
# Epoch 35: val_main_output_accuracy improved from 0.27710 to 0.29780, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2155 - auxiliary_output_loss: 4.2130 - loss: 4.8445 - main_output_accuracy: 0.2822 - main_output_loss: 4.0019 - val_auxiliary_output_accuracy: 0.2445 - val_auxiliary_output_loss: 3.4700 - val_loss: 3.8824 - val_main_output_accuracy: 0.2978 - val_main_output_loss: 3.2074 - learning_rate: 0.0100
# Epoch 36/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2218 - auxiliary_output_loss: 4.2028 - loss: 4.8298 - main_output_accuracy: 0.2889 - main_output_loss: 3.9893
# Epoch 36: val_main_output_accuracy improved from 0.29780 to 0.29900, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.2218 - auxiliary_output_loss: 4.2028 - loss: 4.8298 - main_output_accuracy: 0.2889 - main_output_loss: 3.9892 - val_auxiliary_output_accuracy: 0.2454 - val_auxiliary_output_loss: 3.4723 - val_loss: 3.8621 - val_main_output_accuracy: 0.2990 - val_main_output_loss: 3.1783 - learning_rate: 0.0100
# Epoch 37/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2250 - auxiliary_output_loss: 4.1942 - loss: 4.8132 - main_output_accuracy: 0.2949 - main_output_loss: 3.9744
# Epoch 37: val_main_output_accuracy did not improve from 0.29900
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2250 - auxiliary_output_loss: 4.1942 - loss: 4.8132 - main_output_accuracy: 0.2949 - main_output_loss: 3.9743 - val_auxiliary_output_accuracy: 0.2131 - val_auxiliary_output_loss: 3.7077 - val_loss: 4.2650 - val_main_output_accuracy: 0.2372 - val_main_output_loss: 3.5494 - learning_rate: 0.0100
# Epoch 38/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.2258 - auxiliary_output_loss: 4.1853 - loss: 4.7962 - main_output_accuracy: 0.2992 - main_output_loss: 3.9592
# Epoch 38: val_main_output_accuracy did not improve from 0.29900
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2258 - auxiliary_output_loss: 4.1853 - loss: 4.7962 - main_output_accuracy: 0.2992 - main_output_loss: 3.9592 - val_auxiliary_output_accuracy: 0.2338 - val_auxiliary_output_loss: 3.5385 - val_loss: 3.8853 - val_main_output_accuracy: 0.2940 - val_main_output_loss: 3.1970 - learning_rate: 0.0100
# Epoch 39/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.2299 - auxiliary_output_loss: 4.1692 - loss: 4.7778 - main_output_accuracy: 0.3020 - main_output_loss: 3.9439
# Epoch 39: val_main_output_accuracy improved from 0.29900 to 0.33920, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 240ms/step - auxiliary_output_accuracy: 0.2299 - auxiliary_output_loss: 4.1692 - loss: 4.7778 - main_output_accuracy: 0.3020 - main_output_loss: 3.9439 - val_auxiliary_output_accuracy: 0.2691 - val_auxiliary_output_loss: 3.3261 - val_loss: 3.5954 - val_main_output_accuracy: 0.3392 - val_main_output_loss: 2.9454 - learning_rate: 0.0100
# Epoch 40/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2323 - auxiliary_output_loss: 4.1670 - loss: 4.7707 - main_output_accuracy: 0.3060 - main_output_loss: 3.9373
# Epoch 40: val_main_output_accuracy did not improve from 0.33920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2323 - auxiliary_output_loss: 4.1670 - loss: 4.7707 - main_output_accuracy: 0.3060 - main_output_loss: 3.9373 - val_auxiliary_output_accuracy: 0.2457 - val_auxiliary_output_loss: 3.4541 - val_loss: 3.7917 - val_main_output_accuracy: 0.3122 - val_main_output_loss: 3.1121 - learning_rate: 0.0100
# Epoch 41/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.2357 - auxiliary_output_loss: 4.1581 - loss: 4.7521 - main_output_accuracy: 0.3124 - main_output_loss: 3.9204
# Epoch 41: val_main_output_accuracy improved from 0.33920 to 0.34210, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 240ms/step - auxiliary_output_accuracy: 0.2357 - auxiliary_output_loss: 4.1581 - loss: 4.7520 - main_output_accuracy: 0.3124 - main_output_loss: 3.9204 - val_auxiliary_output_accuracy: 0.2549 - val_auxiliary_output_loss: 3.3931 - val_loss: 3.5899 - val_main_output_accuracy: 0.3421 - val_main_output_loss: 2.9288 - learning_rate: 0.0100
# Epoch 42/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.2357 - auxiliary_output_loss: 4.1423 - loss: 4.7303 - main_output_accuracy: 0.3162 - main_output_loss: 3.9019
# Epoch 42: val_main_output_accuracy did not improve from 0.34210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2357 - auxiliary_output_loss: 4.1423 - loss: 4.7303 - main_output_accuracy: 0.3162 - main_output_loss: 3.9019 - val_auxiliary_output_accuracy: 0.2640 - val_auxiliary_output_loss: 3.3364 - val_loss: 3.6614 - val_main_output_accuracy: 0.3262 - val_main_output_loss: 3.0131 - learning_rate: 0.0100
# Epoch 43/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.2419 - auxiliary_output_loss: 4.1346 - loss: 4.7217 - main_output_accuracy: 0.3196 - main_output_loss: 3.8948
# Epoch 43: val_main_output_accuracy did not improve from 0.34210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2419 - auxiliary_output_loss: 4.1346 - loss: 4.7217 - main_output_accuracy: 0.3196 - main_output_loss: 3.8948 - val_auxiliary_output_accuracy: 0.2591 - val_auxiliary_output_loss: 3.3807 - val_loss: 3.6484 - val_main_output_accuracy: 0.3338 - val_main_output_loss: 2.9878 - learning_rate: 0.0100
# Epoch 44/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.2402 - auxiliary_output_loss: 4.1303 - loss: 4.7079 - main_output_accuracy: 0.3218 - main_output_loss: 3.8818
# Epoch 44: val_main_output_accuracy did not improve from 0.34210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2402 - auxiliary_output_loss: 4.1303 - loss: 4.7078 - main_output_accuracy: 0.3218 - main_output_loss: 3.8818 - val_auxiliary_output_accuracy: 0.2456 - val_auxiliary_output_loss: 3.4743 - val_loss: 3.8005 - val_main_output_accuracy: 0.3120 - val_main_output_loss: 3.1270 - learning_rate: 0.0100
# Epoch 45/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2439 - auxiliary_output_loss: 4.1202 - loss: 4.6934 - main_output_accuracy: 0.3251 - main_output_loss: 3.8694
# Epoch 45: val_main_output_accuracy did not improve from 0.34210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2439 - auxiliary_output_loss: 4.1202 - loss: 4.6934 - main_output_accuracy: 0.3251 - main_output_loss: 3.8694 - val_auxiliary_output_accuracy: 0.2749 - val_auxiliary_output_loss: 3.3275 - val_loss: 3.6566 - val_main_output_accuracy: 0.3346 - val_main_output_loss: 3.0037 - learning_rate: 0.0100
# Epoch 46/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2482 - auxiliary_output_loss: 4.1105 - loss: 4.6821 - main_output_accuracy: 0.3311 - main_output_loss: 3.8600
# Epoch 46: val_main_output_accuracy did not improve from 0.34210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2482 - auxiliary_output_loss: 4.1104 - loss: 4.6821 - main_output_accuracy: 0.3311 - main_output_loss: 3.8600 - val_auxiliary_output_accuracy: 0.2601 - val_auxiliary_output_loss: 3.3556 - val_loss: 3.6959 - val_main_output_accuracy: 0.3250 - val_main_output_loss: 3.0357 - learning_rate: 0.0100
# Epoch 47/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2516 - auxiliary_output_loss: 4.1004 - loss: 4.6660 - main_output_accuracy: 0.3343 - main_output_loss: 3.8459
# Epoch 47: val_main_output_accuracy did not improve from 0.34210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2516 - auxiliary_output_loss: 4.1004 - loss: 4.6660 - main_output_accuracy: 0.3343 - main_output_loss: 3.8459 - val_auxiliary_output_accuracy: 0.2616 - val_auxiliary_output_loss: 3.3790 - val_loss: 3.7351 - val_main_output_accuracy: 0.3194 - val_main_output_loss: 3.0756 - learning_rate: 0.0100
# Epoch 48/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2507 - auxiliary_output_loss: 4.0969 - loss: 4.6554 - main_output_accuracy: 0.3370 - main_output_loss: 3.8361
# Epoch 48: val_main_output_accuracy did not improve from 0.34210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2507 - auxiliary_output_loss: 4.0968 - loss: 4.6554 - main_output_accuracy: 0.3370 - main_output_loss: 3.8361 - val_auxiliary_output_accuracy: 0.2652 - val_auxiliary_output_loss: 3.3721 - val_loss: 3.7796 - val_main_output_accuracy: 0.3161 - val_main_output_loss: 3.1161 - learning_rate: 0.0100
# Epoch 49/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.2525 - auxiliary_output_loss: 4.0890 - loss: 4.6406 - main_output_accuracy: 0.3411 - main_output_loss: 3.8228
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 49: val_main_output_accuracy did not improve from 0.34210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2525 - auxiliary_output_loss: 4.0890 - loss: 4.6406 - main_output_accuracy: 0.3411 - main_output_loss: 3.8228 - val_auxiliary_output_accuracy: 0.2594 - val_auxiliary_output_loss: 3.4035 - val_loss: 3.7120 - val_main_output_accuracy: 0.3215 - val_main_output_loss: 3.0490 - learning_rate: 0.0100
# Epoch 50/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2601 - auxiliary_output_loss: 4.0620 - loss: 4.5869 - main_output_accuracy: 0.3576 - main_output_loss: 3.7745
# Epoch 50: val_main_output_accuracy did not improve from 0.34210
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2601 - auxiliary_output_loss: 4.0620 - loss: 4.5868 - main_output_accuracy: 0.3576 - main_output_loss: 3.7744 - val_auxiliary_output_accuracy: 0.2714 - val_auxiliary_output_loss: 3.3340 - val_loss: 3.6507 - val_main_output_accuracy: 0.3346 - val_main_output_loss: 3.0067 - learning_rate: 0.0050
# Epoch 51/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2644 - auxiliary_output_loss: 4.0405 - loss: 4.5521 - main_output_accuracy: 0.3661 - main_output_loss: 3.7440
# Epoch 51: val_main_output_accuracy improved from 0.34210 to 0.35470, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2644 - auxiliary_output_loss: 4.0405 - loss: 4.5521 - main_output_accuracy: 0.3661 - main_output_loss: 3.7440 - val_auxiliary_output_accuracy: 0.2799 - val_auxiliary_output_loss: 3.2968 - val_loss: 3.5331 - val_main_output_accuracy: 0.3547 - val_main_output_loss: 2.8899 - learning_rate: 0.0050
# Epoch 52/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2659 - auxiliary_output_loss: 4.0381 - loss: 4.5468 - main_output_accuracy: 0.3684 - main_output_loss: 3.7392
# Epoch 52: val_main_output_accuracy improved from 0.35470 to 0.37720, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.2659 - auxiliary_output_loss: 4.0381 - loss: 4.5468 - main_output_accuracy: 0.3684 - main_output_loss: 3.7392 - val_auxiliary_output_accuracy: 0.2851 - val_auxiliary_output_loss: 3.2423 - val_loss: 3.4076 - val_main_output_accuracy: 0.3772 - val_main_output_loss: 2.7759 - learning_rate: 0.0050
# Epoch 53/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2673 - auxiliary_output_loss: 4.0385 - loss: 4.5373 - main_output_accuracy: 0.3750 - main_output_loss: 3.7296
# Epoch 53: val_main_output_accuracy did not improve from 0.37720
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2673 - auxiliary_output_loss: 4.0385 - loss: 4.5373 - main_output_accuracy: 0.3750 - main_output_loss: 3.7296 - val_auxiliary_output_accuracy: 0.2894 - val_auxiliary_output_loss: 3.2169 - val_loss: 3.3985 - val_main_output_accuracy: 0.3752 - val_main_output_loss: 2.7721 - learning_rate: 0.0050
# Epoch 54/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2693 - auxiliary_output_loss: 4.0303 - loss: 4.5281 - main_output_accuracy: 0.3716 - main_output_loss: 3.7220
# Epoch 54: val_main_output_accuracy did not improve from 0.37720
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2693 - auxiliary_output_loss: 4.0303 - loss: 4.5280 - main_output_accuracy: 0.3716 - main_output_loss: 3.7220 - val_auxiliary_output_accuracy: 0.2808 - val_auxiliary_output_loss: 3.2550 - val_loss: 3.4435 - val_main_output_accuracy: 0.3697 - val_main_output_loss: 2.8110 - learning_rate: 0.0050
# Epoch 55/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2705 - auxiliary_output_loss: 4.0271 - loss: 4.5230 - main_output_accuracy: 0.3770 - main_output_loss: 3.7176
# Epoch 55: val_main_output_accuracy did not improve from 0.37720
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2705 - auxiliary_output_loss: 4.0271 - loss: 4.5230 - main_output_accuracy: 0.3770 - main_output_loss: 3.7175 - val_auxiliary_output_accuracy: 0.2875 - val_auxiliary_output_loss: 3.2317 - val_loss: 3.4814 - val_main_output_accuracy: 0.3613 - val_main_output_loss: 2.8525 - learning_rate: 0.0050
# Epoch 56/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2736 - auxiliary_output_loss: 4.0196 - loss: 4.5087 - main_output_accuracy: 0.3789 - main_output_loss: 3.7047
# Epoch 56: val_main_output_accuracy did not improve from 0.37720
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2736 - auxiliary_output_loss: 4.0196 - loss: 4.5086 - main_output_accuracy: 0.3789 - main_output_loss: 3.7047 - val_auxiliary_output_accuracy: 0.2836 - val_auxiliary_output_loss: 3.2714 - val_loss: 3.4429 - val_main_output_accuracy: 0.3706 - val_main_output_loss: 2.8041 - learning_rate: 0.0050
# Epoch 57/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2699 - auxiliary_output_loss: 4.0189 - loss: 4.5037 - main_output_accuracy: 0.3791 - main_output_loss: 3.7000
# Epoch 57: val_main_output_accuracy improved from 0.37720 to 0.38050, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2700 - auxiliary_output_loss: 4.0189 - loss: 4.5037 - main_output_accuracy: 0.3791 - main_output_loss: 3.6999 - val_auxiliary_output_accuracy: 0.2900 - val_auxiliary_output_loss: 3.2331 - val_loss: 3.4140 - val_main_output_accuracy: 0.3805 - val_main_output_loss: 2.7790 - learning_rate: 0.0050
# Epoch 58/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2757 - auxiliary_output_loss: 4.0111 - loss: 4.4963 - main_output_accuracy: 0.3813 - main_output_loss: 3.6940
# Epoch 58: val_main_output_accuracy improved from 0.38050 to 0.38240, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2757 - auxiliary_output_loss: 4.0111 - loss: 4.4962 - main_output_accuracy: 0.3813 - main_output_loss: 3.6940 - val_auxiliary_output_accuracy: 0.2957 - val_auxiliary_output_loss: 3.1948 - val_loss: 3.3589 - val_main_output_accuracy: 0.3824 - val_main_output_loss: 2.7320 - learning_rate: 0.0050
# Epoch 59/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2747 - auxiliary_output_loss: 4.0099 - loss: 4.4925 - main_output_accuracy: 0.3846 - main_output_loss: 3.6905
# Epoch 59: val_main_output_accuracy improved from 0.38240 to 0.38260, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2747 - auxiliary_output_loss: 4.0099 - loss: 4.4924 - main_output_accuracy: 0.3846 - main_output_loss: 3.6905 - val_auxiliary_output_accuracy: 0.2843 - val_auxiliary_output_loss: 3.2494 - val_loss: 3.3795 - val_main_output_accuracy: 0.3826 - val_main_output_loss: 2.7441 - learning_rate: 0.0050
# Epoch 60/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2798 - auxiliary_output_loss: 3.9985 - loss: 4.4821 - main_output_accuracy: 0.3866 - main_output_loss: 3.6824
# Epoch 60: val_main_output_accuracy did not improve from 0.38260
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2798 - auxiliary_output_loss: 3.9985 - loss: 4.4821 - main_output_accuracy: 0.3866 - main_output_loss: 3.6824 - val_auxiliary_output_accuracy: 0.2833 - val_auxiliary_output_loss: 3.2567 - val_loss: 3.4408 - val_main_output_accuracy: 0.3743 - val_main_output_loss: 2.8077 - learning_rate: 0.0050
# Epoch 61/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2798 - auxiliary_output_loss: 4.0020 - loss: 4.4804 - main_output_accuracy: 0.3887 - main_output_loss: 3.6800
# Epoch 61: val_main_output_accuracy did not improve from 0.38260
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2798 - auxiliary_output_loss: 4.0020 - loss: 4.4804 - main_output_accuracy: 0.3887 - main_output_loss: 3.6800 - val_auxiliary_output_accuracy: 0.2776 - val_auxiliary_output_loss: 3.2867 - val_loss: 3.4549 - val_main_output_accuracy: 0.3688 - val_main_output_loss: 2.8202 - learning_rate: 0.0050
# Epoch 62/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2798 - auxiliary_output_loss: 3.9989 - loss: 4.4709 - main_output_accuracy: 0.3925 - main_output_loss: 3.6711
# Epoch 62: val_main_output_accuracy improved from 0.38260 to 0.38680, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.2798 - auxiliary_output_loss: 3.9989 - loss: 4.4709 - main_output_accuracy: 0.3925 - main_output_loss: 3.6711 - val_auxiliary_output_accuracy: 0.2863 - val_auxiliary_output_loss: 3.2391 - val_loss: 3.3998 - val_main_output_accuracy: 0.3868 - val_main_output_loss: 2.7695 - learning_rate: 0.0050
# Epoch 63/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.2792 - auxiliary_output_loss: 3.9985 - loss: 4.4670 - main_output_accuracy: 0.3953 - main_output_loss: 3.6673
# Epoch 63: val_main_output_accuracy did not improve from 0.38680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2792 - auxiliary_output_loss: 3.9985 - loss: 4.4670 - main_output_accuracy: 0.3953 - main_output_loss: 3.6673 - val_auxiliary_output_accuracy: 0.2912 - val_auxiliary_output_loss: 3.2027 - val_loss: 3.4318 - val_main_output_accuracy: 0.3687 - val_main_output_loss: 2.8073 - learning_rate: 0.0050
# Epoch 64/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2799 - auxiliary_output_loss: 3.9910 - loss: 4.4566 - main_output_accuracy: 0.3959 - main_output_loss: 3.6584
# Epoch 64: val_main_output_accuracy did not improve from 0.38680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2800 - auxiliary_output_loss: 3.9910 - loss: 4.4566 - main_output_accuracy: 0.3959 - main_output_loss: 3.6584 - val_auxiliary_output_accuracy: 0.2792 - val_auxiliary_output_loss: 3.3006 - val_loss: 3.5227 - val_main_output_accuracy: 0.3622 - val_main_output_loss: 2.8829 - learning_rate: 0.0050
# Epoch 65/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2831 - auxiliary_output_loss: 3.9868 - loss: 4.4534 - main_output_accuracy: 0.3973 - main_output_loss: 3.6561
# Epoch 65: val_main_output_accuracy did not improve from 0.38680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2831 - auxiliary_output_loss: 3.9868 - loss: 4.4534 - main_output_accuracy: 0.3973 - main_output_loss: 3.6561 - val_auxiliary_output_accuracy: 0.2812 - val_auxiliary_output_loss: 3.2888 - val_loss: 3.4511 - val_main_output_accuracy: 0.3719 - val_main_output_loss: 2.8111 - learning_rate: 0.0050
# Epoch 66/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2855 - auxiliary_output_loss: 3.9813 - loss: 4.4445 - main_output_accuracy: 0.4011 - main_output_loss: 3.6483
# Epoch 66: val_main_output_accuracy did not improve from 0.38680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2855 - auxiliary_output_loss: 3.9813 - loss: 4.4445 - main_output_accuracy: 0.4012 - main_output_loss: 3.6483 - val_auxiliary_output_accuracy: 0.2849 - val_auxiliary_output_loss: 3.2688 - val_loss: 3.4889 - val_main_output_accuracy: 0.3673 - val_main_output_loss: 2.8511 - learning_rate: 0.0050
# Epoch 67/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2833 - auxiliary_output_loss: 3.9772 - loss: 4.4367 - main_output_accuracy: 0.4033 - main_output_loss: 3.6413
# Epoch 67: val_main_output_accuracy improved from 0.38680 to 0.38980, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.2833 - auxiliary_output_loss: 3.9772 - loss: 4.4367 - main_output_accuracy: 0.4033 - main_output_loss: 3.6413 - val_auxiliary_output_accuracy: 0.2944 - val_auxiliary_output_loss: 3.1939 - val_loss: 3.3359 - val_main_output_accuracy: 0.3898 - val_main_output_loss: 2.7118 - learning_rate: 0.0050
# Epoch 68/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2873 - auxiliary_output_loss: 3.9692 - loss: 4.4268 - main_output_accuracy: 0.4075 - main_output_loss: 3.6329
# Epoch 68: val_main_output_accuracy improved from 0.38980 to 0.39030, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.2873 - auxiliary_output_loss: 3.9692 - loss: 4.4268 - main_output_accuracy: 0.4075 - main_output_loss: 3.6329 - val_auxiliary_output_accuracy: 0.2885 - val_auxiliary_output_loss: 3.2399 - val_loss: 3.3288 - val_main_output_accuracy: 0.3903 - val_main_output_loss: 2.6966 - learning_rate: 0.0050
# Epoch 69/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2884 - auxiliary_output_loss: 3.9679 - loss: 4.4252 - main_output_accuracy: 0.4065 - main_output_loss: 3.6316
# Epoch 69: val_main_output_accuracy did not improve from 0.39030
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2884 - auxiliary_output_loss: 3.9679 - loss: 4.4251 - main_output_accuracy: 0.4065 - main_output_loss: 3.6316 - val_auxiliary_output_accuracy: 0.2933 - val_auxiliary_output_loss: 3.2256 - val_loss: 3.3949 - val_main_output_accuracy: 0.3795 - val_main_output_loss: 2.7696 - learning_rate: 0.0050
# Epoch 70/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.2877 - auxiliary_output_loss: 3.9650 - loss: 4.4224 - main_output_accuracy: 0.4052 - main_output_loss: 3.6294
# Epoch 70: val_main_output_accuracy did not improve from 0.39030
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2877 - auxiliary_output_loss: 3.9649 - loss: 4.4224 - main_output_accuracy: 0.4052 - main_output_loss: 3.6294 - val_auxiliary_output_accuracy: 0.2828 - val_auxiliary_output_loss: 3.2539 - val_loss: 3.4398 - val_main_output_accuracy: 0.3730 - val_main_output_loss: 2.8040 - learning_rate: 0.0050
# Epoch 71/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.2929 - auxiliary_output_loss: 3.9544 - loss: 4.4056 - main_output_accuracy: 0.4101 - main_output_loss: 3.6147
# Epoch 71: val_main_output_accuracy improved from 0.39030 to 0.39280, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.2929 - auxiliary_output_loss: 3.9544 - loss: 4.4055 - main_output_accuracy: 0.4101 - main_output_loss: 3.6147 - val_auxiliary_output_accuracy: 0.2960 - val_auxiliary_output_loss: 3.2126 - val_loss: 3.3312 - val_main_output_accuracy: 0.3928 - val_main_output_loss: 2.7051 - learning_rate: 0.0050
# Epoch 72/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - auxiliary_output_accuracy: 0.2935 - auxiliary_output_loss: 3.9541 - loss: 4.4046 - main_output_accuracy: 0.4090 - main_output_loss: 3.6138
# Epoch 72: val_main_output_accuracy did not improve from 0.39280
# ...
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 189s 241ms/step - auxiliary_output_accuracy: 0.3261 - auxiliary_output_loss: 3.8439 - loss: 4.2105 - main_output_accuracy: 0.4711 - main_output_loss: 3.4417 - val_auxiliary_output_accuracy: 0.3096 - val_auxiliary_output_loss: 3.1261 - val_loss: 3.1985 - val_main_output_accuracy: 0.4220 - val_main_output_loss: 2.5854 - learning_rate: 0.0025
# Epoch 97/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3259 - auxiliary_output_loss: 3.8421 - loss: 4.2005 - main_output_accuracy: 0.4748 - main_output_loss: 3.4321
# Epoch 97: val_main_output_accuracy did not improve from 0.42200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.3259 - auxiliary_output_loss: 3.8421 - loss: 4.2005 - main_output_accuracy: 0.4748 - main_output_loss: 3.4321 - val_auxiliary_output_accuracy: 0.3051 - val_auxiliary_output_loss: 3.1585 - val_loss: 3.2530 - val_main_output_accuracy: 0.4099 - val_main_output_loss: 2.6369 - learning_rate: 0.0025
# Epoch 98/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3256 - auxiliary_output_loss: 3.8488 - loss: 4.2007 - main_output_accuracy: 0.4754 - main_output_loss: 3.4309
# Epoch 98: val_main_output_accuracy improved from 0.42200 to 0.42840, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 240ms/step - auxiliary_output_accuracy: 0.3256 - auxiliary_output_loss: 3.8488 - loss: 4.2007 - main_output_accuracy: 0.4754 - main_output_loss: 3.4309 - val_auxiliary_output_accuracy: 0.3154 - val_auxiliary_output_loss: 3.1117 - val_loss: 3.1810 - val_main_output_accuracy: 0.4284 - val_main_output_loss: 2.5699 - learning_rate: 0.0025
# Epoch 99/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3296 - auxiliary_output_loss: 3.8387 - loss: 4.1982 - main_output_accuracy: 0.4766 - main_output_loss: 3.4305
# Epoch 99: val_main_output_accuracy did not improve from 0.42840
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.3296 - auxiliary_output_loss: 3.8387 - loss: 4.1982 - main_output_accuracy: 0.4766 - main_output_loss: 3.4304 - val_auxiliary_output_accuracy: 0.3070 - val_auxiliary_output_loss: 3.1485 - val_loss: 3.2782 - val_main_output_accuracy: 0.4092 - val_main_output_loss: 2.6596 - learning_rate: 0.0025
# Epoch 100/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3282 - auxiliary_output_loss: 3.8424 - loss: 4.1959 - main_output_accuracy: 0.4799 - main_output_loss: 3.4274
# Epoch 100: val_main_output_accuracy improved from 0.42840 to 0.43130, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 240ms/step - auxiliary_output_accuracy: 0.3282 - auxiliary_output_loss: 3.8424 - loss: 4.1959 - main_output_accuracy: 0.4799 - main_output_loss: 3.4274 - val_auxiliary_output_accuracy: 0.3179 - val_auxiliary_output_loss: 3.0614 - val_loss: 3.1171 - val_main_output_accuracy: 0.4313 - val_main_output_loss: 2.5176 - learning_rate: 0.0025
# Epoch 101/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3298 - auxiliary_output_loss: 3.8341 - loss: 4.1871 - main_output_accuracy: 0.4798 - main_output_loss: 3.4203
# Epoch 101: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.3298 - auxiliary_output_loss: 3.8341 - loss: 4.1871 - main_output_accuracy: 0.4798 - main_output_loss: 3.4202 - val_auxiliary_output_accuracy: 0.3077 - val_auxiliary_output_loss: 3.1416 - val_loss: 3.2389 - val_main_output_accuracy: 0.4162 - val_main_output_loss: 2.6257 - learning_rate: 0.0025
# Epoch 102/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3316 - auxiliary_output_loss: 3.8364 - loss: 4.1830 - main_output_accuracy: 0.4820 - main_output_loss: 3.4157
# Epoch 102: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.3316 - auxiliary_output_loss: 3.8364 - loss: 4.1830 - main_output_accuracy: 0.4820 - main_output_loss: 3.4157 - val_auxiliary_output_accuracy: 0.3088 - val_auxiliary_output_loss: 3.1119 - val_loss: 3.1679 - val_main_output_accuracy: 0.4245 - val_main_output_loss: 2.5588 - learning_rate: 0.0025
# Epoch 103/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3301 - auxiliary_output_loss: 3.8353 - loss: 4.1784 - main_output_accuracy: 0.4804 - main_output_loss: 3.4114
# Epoch 103: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.3301 - auxiliary_output_loss: 3.8353 - loss: 4.1784 - main_output_accuracy: 0.4804 - main_output_loss: 3.4114 - val_auxiliary_output_accuracy: 0.3102 - val_auxiliary_output_loss: 3.1324 - val_loss: 3.2158 - val_main_output_accuracy: 0.4189 - val_main_output_loss: 2.5993 - learning_rate: 0.0025
# Epoch 104/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3320 - auxiliary_output_loss: 3.8323 - loss: 4.1792 - main_output_accuracy: 0.4845 - main_output_loss: 3.4127
# Epoch 104: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.3320 - auxiliary_output_loss: 3.8323 - loss: 4.1792 - main_output_accuracy: 0.4846 - main_output_loss: 3.4127 - val_auxiliary_output_accuracy: 0.3059 - val_auxiliary_output_loss: 3.1559 - val_loss: 3.2400 - val_main_output_accuracy: 0.4142 - val_main_output_loss: 2.6228 - learning_rate: 0.0025
# Epoch 105/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3323 - auxiliary_output_loss: 3.8253 - loss: 4.1704 - main_output_accuracy: 0.4837 - main_output_loss: 3.4054
# Epoch 105: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3323 - auxiliary_output_loss: 3.8253 - loss: 4.1704 - main_output_accuracy: 0.4837 - main_output_loss: 3.4053 - val_auxiliary_output_accuracy: 0.3150 - val_auxiliary_output_loss: 3.0854 - val_loss: 3.1775 - val_main_output_accuracy: 0.4244 - val_main_output_loss: 2.5700 - learning_rate: 0.0025
# Epoch 106/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3329 - auxiliary_output_loss: 3.8334 - loss: 4.1761 - main_output_accuracy: 0.4835 - main_output_loss: 3.4094
# Epoch 106: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3329 - auxiliary_output_loss: 3.8334 - loss: 4.1760 - main_output_accuracy: 0.4835 - main_output_loss: 3.4094 - val_auxiliary_output_accuracy: 0.3106 - val_auxiliary_output_loss: 3.1274 - val_loss: 3.1675 - val_main_output_accuracy: 0.4264 - val_main_output_loss: 2.5557 - learning_rate: 0.0025
# Epoch 107/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3316 - auxiliary_output_loss: 3.8283 - loss: 4.1681 - main_output_accuracy: 0.4872 - main_output_loss: 3.4024
# Epoch 107: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3316 - auxiliary_output_loss: 3.8283 - loss: 4.1681 - main_output_accuracy: 0.4872 - main_output_loss: 3.4024 - val_auxiliary_output_accuracy: 0.3121 - val_auxiliary_output_loss: 3.1136 - val_loss: 3.2247 - val_main_output_accuracy: 0.4160 - val_main_output_loss: 2.6135 - learning_rate: 0.0025
# Epoch 108/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3326 - auxiliary_output_loss: 3.8220 - loss: 4.1581 - main_output_accuracy: 0.4902 - main_output_loss: 3.3937
# Epoch 108: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 108: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3326 - auxiliary_output_loss: 3.8220 - loss: 4.1581 - main_output_accuracy: 0.4902 - main_output_loss: 3.3937 - val_auxiliary_output_accuracy: 0.3151 - val_auxiliary_output_loss: 3.1128 - val_loss: 3.1786 - val_main_output_accuracy: 0.4295 - val_main_output_loss: 2.5696 - learning_rate: 0.0025
# Epoch 109/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3351 - auxiliary_output_loss: 3.8141 - loss: 4.1425 - main_output_accuracy: 0.4961 - main_output_loss: 3.3797
# Epoch 109: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3351 - auxiliary_output_loss: 3.8141 - loss: 4.1425 - main_output_accuracy: 0.4961 - main_output_loss: 3.3797 - val_auxiliary_output_accuracy: 0.3161 - val_auxiliary_output_loss: 3.1064 - val_loss: 3.1780 - val_main_output_accuracy: 0.4264 - val_main_output_loss: 2.5696 - learning_rate: 0.0012
# Epoch 110/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3378 - auxiliary_output_loss: 3.8092 - loss: 4.1299 - main_output_accuracy: 0.4975 - main_output_loss: 3.3681
# Epoch 110: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3378 - auxiliary_output_loss: 3.8092 - loss: 4.1299 - main_output_accuracy: 0.4975 - main_output_loss: 3.3681 - val_auxiliary_output_accuracy: 0.3170 - val_auxiliary_output_loss: 3.0868 - val_loss: 3.1677 - val_main_output_accuracy: 0.4294 - val_main_output_loss: 2.5612 - learning_rate: 0.0012
# Epoch 111/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3378 - auxiliary_output_loss: 3.8084 - loss: 4.1341 - main_output_accuracy: 0.4979 - main_output_loss: 3.3724
# Epoch 111: val_main_output_accuracy did not improve from 0.43130
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3378 - auxiliary_output_loss: 3.8084 - loss: 4.1341 - main_output_accuracy: 0.4979 - main_output_loss: 3.3724 - val_auxiliary_output_accuracy: 0.3216 - val_auxiliary_output_loss: 3.0755 - val_loss: 3.1607 - val_main_output_accuracy: 0.4266 - val_main_output_loss: 2.5534 - learning_rate: 0.0012
# Epoch 112/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3374 - auxiliary_output_loss: 3.8075 - loss: 4.1243 - main_output_accuracy: 0.4999 - main_output_loss: 3.3628
# Epoch 112: val_main_output_accuracy improved from 0.43130 to 0.43380, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 240ms/step - auxiliary_output_accuracy: 0.3374 - auxiliary_output_loss: 3.8075 - loss: 4.1243 - main_output_accuracy: 0.4999 - main_output_loss: 3.3628 - val_auxiliary_output_accuracy: 0.3233 - val_auxiliary_output_loss: 3.0734 - val_loss: 3.1251 - val_main_output_accuracy: 0.4338 - val_main_output_loss: 2.5185 - learning_rate: 0.0012
# Epoch 113/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.3380 - auxiliary_output_loss: 3.8074 - loss: 4.1266 - main_output_accuracy: 0.4987 - main_output_loss: 3.3651
# Epoch 113: val_main_output_accuracy did not improve from 0.43380
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.3380 - auxiliary_output_loss: 3.8074 - loss: 4.1266 - main_output_accuracy: 0.4987 - main_output_loss: 3.3651 - val_auxiliary_output_accuracy: 0.3207 - val_auxiliary_output_loss: 3.0806 - val_loss: 3.1457 - val_main_output_accuracy: 0.4280 - val_main_output_loss: 2.5394 - learning_rate: 0.0012
# Epoch 114/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3382 - auxiliary_output_loss: 3.8075 - loss: 4.1226 - main_output_accuracy: 0.5033 - main_output_loss: 3.3611
# Epoch 114: val_main_output_accuracy did not improve from 0.43380
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3382 - auxiliary_output_loss: 3.8075 - loss: 4.1226 - main_output_accuracy: 0.5033 - main_output_loss: 3.3611 - val_auxiliary_output_accuracy: 0.3145 - val_auxiliary_output_loss: 3.1085 - val_loss: 3.1995 - val_main_output_accuracy: 0.4217 - val_main_output_loss: 2.5854 - learning_rate: 0.0012
# Epoch 115/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3372 - auxiliary_output_loss: 3.8021 - loss: 4.1170 - main_output_accuracy: 0.5019 - main_output_loss: 3.3565
# Epoch 115: val_main_output_accuracy did not improve from 0.43380
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.3372 - auxiliary_output_loss: 3.8021 - loss: 4.1169 - main_output_accuracy: 0.5019 - main_output_loss: 3.3565 - val_auxiliary_output_accuracy: 0.3153 - val_auxiliary_output_loss: 3.1216 - val_loss: 3.1962 - val_main_output_accuracy: 0.4269 - val_main_output_loss: 2.5840 - learning_rate: 0.0012
# Epoch 116/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3419 - auxiliary_output_loss: 3.8061 - loss: 4.1214 - main_output_accuracy: 0.5034 - main_output_loss: 3.3602
# Epoch 116: val_main_output_accuracy did not improve from 0.43380
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3419 - auxiliary_output_loss: 3.8061 - loss: 4.1214 - main_output_accuracy: 0.5035 - main_output_loss: 3.3602 - val_auxiliary_output_accuracy: 0.3146 - val_auxiliary_output_loss: 3.1035 - val_loss: 3.2058 - val_main_output_accuracy: 0.4182 - val_main_output_loss: 2.5944 - learning_rate: 0.0012
# Epoch 117/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3401 - auxiliary_output_loss: 3.8024 - loss: 4.1173 - main_output_accuracy: 0.5023 - main_output_loss: 3.3568
# Epoch 117: val_main_output_accuracy did not improve from 0.43380
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 239ms/step - auxiliary_output_accuracy: 0.3401 - auxiliary_output_loss: 3.8024 - loss: 4.1173 - main_output_accuracy: 0.5023 - main_output_loss: 3.3568 - val_auxiliary_output_accuracy: 0.3142 - val_auxiliary_output_loss: 3.1110 - val_loss: 3.1704 - val_main_output_accuracy: 0.4275 - val_main_output_loss: 2.5573 - learning_rate: 0.0012
# Epoch 118/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - auxiliary_output_accuracy: 0.3404 - auxiliary_output_loss: 3.8001 - loss: 4.1132 - main_output_accuracy: 0.5049 - main_output_loss: 3.3532
# Epoch 118: val_main_output_accuracy improved from 0.43380 to 0.43950, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 240ms/step - auxiliary_output_accuracy: 0.3404 - auxiliary_output_loss: 3.8000 - loss: 4.1132 - main_output_accuracy: 0.5049 - main_output_loss: 3.3532 - val_auxiliary_output_accuracy: 0.3246 - val_auxiliary_output_loss: 3.0466 - val_loss: 3.1072 - val_main_output_accuracy: 0.4395 - val_main_output_loss: 2.5053 - learning_rate: 0.0012
# Epoch 119/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.3400 - auxiliary_output_loss: 3.7992 - loss: 4.1167 - main_output_accuracy: 0.5017 - main_output_loss: 3.3569
# Epoch 119: val_main_output_accuracy did not improve from 0.43950
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 187s 238ms/step - auxiliary_output_accuracy: 0.3400 - auxiliary_output_loss: 3.7992 - loss: 4.1167 - main_output_accuracy: 0.5017 - main_output_loss: 3.3569 - val_auxiliary_output_accuracy: 0.3159 - val_auxiliary_output_loss: 3.1017 - val_loss: 3.1975 - val_main_output_accuracy: 0.4235 - val_main_output_loss: 2.5864 - learning_rate: 0.0012
# Epoch 120/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - auxiliary_output_accuracy: 0.3410 - auxiliary_output_loss: 3.8008 - loss: 4.1112 - main_output_accuracy: 0.5065 - main_output_loss: 3.3510
# Epoch 120: val_main_output_accuracy improved from 0.43950 to 0.44190, saving model to googlenet_exp007_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 188s 239ms/step - auxiliary_output_accuracy: 0.3410 - auxiliary_output_loss: 3.8008 - loss: 4.1111 - main_output_accuracy: 0.5065 - main_output_loss: 3.3510 - val_auxiliary_output_accuracy: 0.3265 - val_auxiliary_output_loss: 3.0446 - val_loss: 3.0989 - val_main_output_accuracy: 0.4419 - val_main_output_loss: 2.4976 - learning_rate: 0.0012
# Restoring model weights from the end of the best epoch: 120.

# %%
best_model = tf.keras.models.load_model('googlenet_exp007_best.keras')
results    = best_model.evaluate(val_ds_dual, verbose=0)
print('\nresults[] completo (para debug de índices):')
for i, v in enumerate(results):
    print(f'  results[{i}] = {v:.4f}')
# Out:
# results[] completo (para debug de índices):
#   results[0] = 3.0989
#   results[1] = 2.4976
#   results[2] = 3.0446
#   results[3] = 0.3265
#   results[4] = 0.4419

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

axes[0].plot(history.history['loss'],     label='Train', color='steelblue')
axes[0].plot(history.history['val_loss'], label='Val',   color='tomato')
axes[0].set_title('Loss Total')
axes[0].set_xlabel('Épocas'); axes[0].legend(); axes[0].grid(alpha=0.4)
axes[0].annotate('Train loss mais alta\né normal com Mixup',
                 xy=(0.05, 0.95), xycoords='axes fraction',
                 fontsize=8, color='gray', va='top')

axes[1].plot(history.history['main_output_accuracy'],     label='Train', color='steelblue')
axes[1].plot(history.history['val_main_output_accuracy'], label='Val',   color='tomato')
axes[1].set_title('Acurácia — Saída Principal')
axes[1].set_xlabel('Épocas'); axes[1].legend(); axes[1].grid(alpha=0.4)

axes[2].plot(history.history['auxiliary_output_accuracy'],     label='Train (aux)', color='mediumpurple')
axes[2].plot(history.history['val_auxiliary_output_accuracy'], label='Val (aux)',   color='darkorange')
axes[2].plot(history.history['val_main_output_accuracy'],      label='Val (main)',  color='tomato', linestyle='--')
axes[2].set_title('Acurácia — Main vs. Auxiliar (gap)')
axes[2].set_xlabel('Épocas'); axes[2].legend(); axes[2].grid(alpha=0.4)

plt.suptitle('exp_006 — Curvas de Treinamento (com Mixup)', fontsize=13)
plt.tight_layout()
plt.savefig('training_curves_exp007.png', dpi=150)
plt.show()

# %%
id_to_name = {}
words_file = DATA_DIR / 'words.txt'
if words_file.exists():
    with open(words_file) as f:
        for line in f:
            parts = line.strip().split('\t', 1)
            if len(parts) == 2:
                id_to_name[parts[0]] = parts[1].split(',')[0]

idx_to_name = {i: id_to_name.get(cid, cid) for i, cid in enumerate(CLASS_NAMES)}
print('Mapeamento carregado.')
# Out:
# Mapeamento carregado.

# %%
# Coleta predições usando output[0] (main_output) diretamente — mais confiável
all_true, all_pred, all_probs = [], [], []
for imgs, (lbls, _) in val_ds_dual:
    lbl_idx = tf.argmax(lbls, axis=1).numpy()
    probs   = best_model(imgs, training=False)[0].numpy()  # [0] = main_output
    all_true.extend(lbl_idx)
    all_pred.extend(np.argmax(probs, axis=1))
    all_probs.append(probs)

all_true  = np.array(all_true)
all_pred  = np.array(all_pred)
all_probs = np.concatenate(all_probs, axis=0)

# Top-5
top5_metric = tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5)
top5_metric.update_state(all_true, all_probs)
top5_acc = top5_metric.result().numpy()

# Auxiliar — output[1]
all_probs_aux = []
for imgs, (_, _) in val_ds_dual:
    probs_aux = best_model(imgs, training=False)[1].numpy()  # [1] = auxiliary_output
    all_probs_aux.append(probs_aux)
all_probs_aux = np.concatenate(all_probs_aux, axis=0)
aux_acc = (np.argmax(all_probs_aux, axis=1) == all_true).mean()

per_class_acc = {
    c: (all_pred[all_true == c] == c).mean()
    for c in range(NUM_CLASSES) if (all_true == c).sum() > 0
}
sorted_acc = sorted(per_class_acc.items(), key=lambda x: x[1], reverse=True)
main_acc   = (all_true == all_pred).mean()

print(f"{'='*55}")
print(f"  Top-1 — Saída Principal  : {main_acc*100:.2f}%")
print(f"  Top-1 — Saída Auxiliar   : {aux_acc*100:.2f}%")
print(f"  Gap main/aux             : {abs(main_acc - aux_acc)*100:.2f}pp")
print(f"  Top-5 — Saída Principal  : {top5_acc*100:.2f}%")
print(f"  Média per-class (main)   : {np.mean(list(per_class_acc.values()))*100:.2f}%")
print(f"  Melhor classe            : {idx_to_name.get(sorted_acc[0][0])} ({sorted_acc[0][1]*100:.1f}%)")
print(f"  Pior classe              : {idx_to_name.get(sorted_acc[-1][0])} ({sorted_acc[-1][1]*100:.1f}%)")
print(f"{'='*55}")
# Out:
# =======================================================
#   Top-1 — Saída Principal  : 44.19%
#   Top-1 — Saída Auxiliar   : 32.65%
#   Gap main/aux             : 11.54pp
#   Top-5 — Saída Principal  : 69.14%
#   Média per-class (main)   : 44.19%
#   Melhor classe            : school bus (94.0%)
#   Pior classe              : plunger (2.0%)
# =======================================================

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
for ax, data, title, color in [
    (axes[0], sorted_acc[:20],  'Top-20 (melhor acurácia)', '#2ecc71'),
    (axes[1], sorted_acc[-20:], 'Bottom-20 (pior acurácia)', '#e74c3c'),
]:
    lbls = [idx_to_name.get(c, str(c)) for c, _ in data]
    vals = [v * 100 for _, v in data]
    bars = ax.barh(lbls[::-1], vals[::-1], color=color, alpha=0.8)
    ax.axvline(np.mean(list(per_class_acc.values())) * 100,
               color='gray', linestyle='--', lw=1, label='Média')
    ax.set_xlabel('Acurácia (%)'); ax.set_title(title)
    ax.set_xlim(0, 100); ax.legend(fontsize=8); ax.grid(axis='x', alpha=0.3)
    for bar, val in zip(bars, vals[::-1]):
        ax.text(val + 0.5, bar.get_y() + bar.get_height()/2,
                f'{val:.1f}%', va='center', fontsize=7)

plt.tight_layout()
plt.savefig('per_class_exp007.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
top20_idx = [c for c, _ in sorted(
    ((c, (all_true == c).sum()) for c in range(NUM_CLASSES)), key=lambda x: -x[1]
)[:20]]

mask = np.isin(all_true, top20_idx)
cm   = confusion_matrix(all_true[mask], all_pred[mask], labels=top20_idx)
cm_n = cm.astype(float) / cm.sum(axis=1, keepdims=True)

fig, ax = plt.subplots(figsize=(14, 12))
im = ax.imshow(cm_n, cmap='Blues', vmin=0, vmax=1)
plt.colorbar(im, ax=ax, fraction=0.03)
tick_lbl = [idx_to_name.get(c, str(c))[:12] for c in top20_idx]
ax.set_xticks(range(20)); ax.set_xticklabels(tick_lbl, rotation=45, ha='right', fontsize=7)
ax.set_yticks(range(20)); ax.set_yticklabels(tick_lbl, fontsize=7)
ax.set_title('Confusion Matrix — 20 classes mais frequentes (normalizada)')
ax.set_ylabel('Real'); ax.set_xlabel('Predito')
for i, j in itertools.product(range(20), range(20)):
    if cm_n[i, j] > 0.15:
        ax.text(j, i, f'{cm_n[i,j]:.2f}', ha='center', va='center',
                color='white' if cm_n[i,j] > 0.5 else 'black', fontsize=6)
plt.tight_layout()
plt.savefig('confusion_matrix_exp007.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
N, COLS = 20, 5
ROWS = math.ceil(N / COLS)

sample_imgs, (sample_lbls, _) = next(iter(val_ds_dual))
sample_imgs = sample_imgs[:N]
true_idx    = tf.argmax(sample_lbls[:N], axis=1).numpy()
probs_main  = best_model(sample_imgs, training=False)[0].numpy()
pred_idx    = np.argmax(probs_main, axis=1)
confs       = np.max(probs_main, axis=1)

fig, axes = plt.subplots(ROWS, COLS, figsize=(COLS*3, ROWS*3.4))
for i, ax in enumerate(axes.flat[:N]):
    correct = true_idx[i] == pred_idx[i]
    cor = '#2ecc71' if correct else '#e74c3c'
    ax.imshow(sample_imgs[i].numpy())
    for s in ax.spines.values():
        s.set_edgecolor(cor); s.set_linewidth(4)
    ax.set_title(
        f"Real: {idx_to_name.get(true_idx[i], '')}\n"
        f"Pred: {idx_to_name.get(pred_idx[i], '')}\n{confs[i]*100:.1f}%",
        fontsize=7.5, color=cor, pad=3
    )
    ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
for ax in axes.flat[N:]:
    ax.axis('off')

n_ok = (true_idx == pred_idx).sum()
fig.legend(handles=[
    mpatches.Patch(color='#2ecc71', label='Acerto'),
    mpatches.Patch(color='#e74c3c', label='Erro')
], loc='lower center', ncol=2, fontsize=10, bbox_to_anchor=(0.5, 0), frameon=False)
fig.suptitle(f'Real vs. Predito — {n_ok}/{N} corretos ({n_ok/N*100:.0f}%)', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('real_vs_predito_exp007.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
TEST_URLS = [
    ('goldfish',      'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Goldfish3.jpg/320px-Goldfish3.jpg'),
    ('tabby cat',     'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Cat_November_2010-1a.jpg/320px-Cat_November_2010-1a.jpg'),
    ('ant',           'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Camponotus_flavomarginatus_ant.jpg/320px-Camponotus_flavomarginatus_ant.jpg'),
    ('school bus',    'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Iconbus.jpg/320px-Iconbus.jpg'),
    ('Egyptian cat',  'https://upload.wikimedia.org/wikipedia/commons/thumb/9/94/Sobekhotep_IV_MET_44.4.21.jpg/320px-Sobekhotep_IV_MET_44.4.21.jpg'),
    ('monarch',       'https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Monarch_Butterfly_Danaus_plexippus_on_Echinacea_purpurea_1.jpg/320px-Monarch_Butterfly_Danaus_plexippus_on_Echinacea_purpurea_1.jpg'),
]

def predict_url(label, url, top_k=5):
    try:
        r   = requests.get(url, timeout=10, headers={'User-Agent': 'Mozilla/5.0'})
        img = Image.open(BytesIO(r.content)).convert('RGB')
        img_r = img.resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)
        arr   = np.array(img_r, dtype=np.float32)[None] / 255.0

        probs   = best_model(arr, training=False)[0][0].numpy()
        top_idx = np.argsort(probs)[::-1][:top_k]

        fig, axes = plt.subplots(1, 2, figsize=(8, 3.5),
                                 gridspec_kw={'width_ratios': [1, 2]})
        axes[0].imshow(img_r); axes[0].axis('off')
        axes[0].set_title(f'[esperado: {label}]', fontsize=8, color='gray')

        names  = [idx_to_name.get(i, str(i)) for i in top_idx]
        vals   = [probs[i]*100 for i in top_idx]
        colors = ['#2ecc71' if label.lower() in n.lower() else '#5b8dd9' for n in names]
        axes[1].barh(names[::-1], vals[::-1], color=colors[::-1])
        axes[1].set_xlabel('Confiança (%)')
        axes[1].set_title('Top-5 Predições')
        axes[1].set_xlim(0, 100)

        plt.suptitle(f'Predição externa — {label}', fontsize=10)
        plt.tight_layout()
        plt.show()
        print(f'  Top-1: {names[0]} ({vals[0]:.1f}%) | esperado: {label}')
    except Exception as e:
        print(f'  Erro ({label}): {e}')

for lbl, url in TEST_URLS:
    predict_url(lbl, url)
# Out:
#   Erro (goldfish): cannot identify image file <_io.BytesIO object at 0x7cfa177e0360>
#   Erro (tabby cat): cannot identify image file <_io.BytesIO object at 0x7cfa164c82c0>
#   Erro (ant): cannot identify image file <_io.BytesIO object at 0x7cfa16d7dda0>
#   Erro (school bus): cannot identify image file <_io.BytesIO object at 0x7cfa164c82c0>
#   Erro (Egyptian cat): cannot identify image file <_io.BytesIO object at 0x7cfa177e1990>
#   Erro (monarch): cannot identify image file <_io.BytesIO object at 0x7cfa164c8bd0>

# %%
EXPERIMENTO['resultado_top1'] = round(float(main_acc) * 100, 2)
EXPERIMENTO['resultado_top5'] = round(float(top5_acc) * 100, 2)
EXPERIMENTO['epocas']         = len(history.history['loss'])

log_path   = 'experimentos_log.csv'
fieldnames = ['id', 'hipotese', 'mudancas', 'resultado_top1', 'resultado_top5', 'epocas', 'timestamp']
row = {
    **EXPERIMENTO,
    'mudancas':  ' | '.join(EXPERIMENTO['mudancas']),
    'timestamp': datetime.datetime.now().isoformat(),
}
file_exists = os.path.isfile(log_path)
with open(log_path, 'a', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    if not file_exists:
        writer.writeheader()
    writer.writerow(row)

print(f'✓ {EXPERIMENTO["id"]} salvo em {log_path}')
print(f'  Top-1 (main): {EXPERIMENTO["resultado_top1"]}% | Top-5: {EXPERIMENTO["resultado_top5"]}% | Épocas: {EXPERIMENTO["epocas"]}')
print(f'  Top-1 (aux):  {aux_acc*100:.2f}%')
print(f'  Gap main/aux: {abs(main_acc - aux_acc)*100:.2f}pp')
# Out:
# ✓ exp_007 salvo em experimentos_log.csv
#   Top-1 (main): 44.19% | Top-5: 69.14% | Épocas: 120
#   Top-1 (aux):  32.65%
#   Gap main/aux: 11.54pp
