# %%
# exp06 — GoogLeNet/InceptionV1 · Tiny ImageNet
# Acumula exp_001 (filtros 5a/5b reduzidos) + exp_002 (dropout 0.55)
# + exp_004 (aux_weight 0.4, LR warmup) + exp_005 (Stem stride conv)
# Hipótese: Mixup Augmentation (alpha=0.2) reduz overfitting e suaviza
# fronteiras de decisão, aumentando a consistência da val_accuracy.
# label_smoothing REMOVIDO: Mixup já gera soft labels — aplicar os dois
# simultaneamente suaviza as labels duas vezes e pode prejudicar o treino.
# Épocas aumentadas para 120 (EarlyStopping patience=25) pois Mixup
# torna o problema mais difícil e o modelo converge mais lentamente.

import datetime

EXPERIMENTO = {
    "id": "exp_006",
    "hipotese": (
        "Mixup (alpha=0.2) reduz overfitting e suaviza fronteiras de decisão. "
        "label_smoothing removido (Mixup já gera soft labels). "
        "Épocas aumentadas para 120 para acomodar convergência mais lenta com Mixup."
    ),
    "mudancas": [
        "[exp_001] inception_5a: (256,160,320,32,128,128) → (192,128,256,32,96,96)",
        "[exp_001] inception_5b: (384,192,384,48,128,128) → (256,160,320,32,96,96)",
        "[exp_002] main_dropout: 0.4 → 0.55",
        "[exp_004] loss_weight auxiliar: 0.3 → 0.4",
        "[exp_004] ReduceLROnPlateau patience: 5 → 8",
        "[exp_004] LR warmup: 5 épocas (0.001 → 0.01)",
        "[exp_004] augmentation: nível exp_002",
        "[exp_005] stem_c2: stride=2, he_normal — stem_pool removido",
        "[exp_006] Mixup Augmentation: alpha=0.2",
        "[exp_006] label_smoothing: 0.05 → 0.0 (removido — incompatível com Mixup)",
        "[exp_006] EarlyStopping patience: 20 → 25",
        "[exp_006] Épocas máx: 100 → 120",
    ],
    "resultado_top1": None,
    "resultado_top5": None,
    "epocas": None,
}

print(f"[{datetime.datetime.now():%Y-%m-%d %H:%M}] {EXPERIMENTO['id']}")
print(f"Hipótese: {EXPERIMENTO['hipotese']}")
print("\nMudanças acumuladas:")
for m in EXPERIMENTO["mudancas"]:
    print(f"  • {m}")
# Out:
# [2026-05-05 23:31] exp_006
# Hipótese: Mixup (alpha=0.2) reduz overfitting e suaviza fronteiras de decisão. label_smoothing removido (Mixup já gera soft labels). Épocas aumentadas para 120 para acomodar convergência mais lenta com Mixup.
#
# Mudanças acumuladas:
#   • [exp_001] inception_5a: (256,160,320,32,128,128) → (192,128,256,32,96,96)
#   • [exp_001] inception_5b: (384,192,384,48,128,128) → (256,160,320,32,96,96)
#   • [exp_002] main_dropout: 0.4 → 0.55
#   • [exp_004] loss_weight auxiliar: 0.3 → 0.4
#   • [exp_004] ReduceLROnPlateau patience: 5 → 8
#   • [exp_004] LR warmup: 5 épocas (0.001 → 0.01)
#   • [exp_004] augmentation: nível exp_002
#   • [exp_005] stem_c2: stride=2, he_normal — stem_pool removido
#   • [exp_006] Mixup Augmentation: alpha=0.2
#   • [exp_006] label_smoothing: 0.05 → 0.0 (removido — incompatível com Mixup)
#   • [exp_006] EarlyStopping patience: 20 → 25
#   • [exp_006] Épocas máx: 100 → 120

# %% [markdown]
# ## Histórico de Experimentos
#
# | ID | Mudanças-chave | Top-1 val (main) | Top-1 val (aux) | Top-5 val | Δ Top-1 |
# |---|---|---|---|---|---|
# | baseline | Modelo original | 39.88% | — | — | — |
# | exp_001 | inception_5a/5b: canais reduzidos ~30% | 40.08% | 44.76% | 71.05% | +4.88pp (aux) |
# | exp_002 | main_dropout: 0.4 → 0.55 | 39.29%* | 46.58% | 71.79% | +1.82pp (aux) |
# | exp_003 | label_smoothing 0.1 (ambas) + ReduceLR patience=5 + aug+ | 0.50% ❌ | 2.50% ❌ | 2.50% ❌ | colapso (16 épocas) |
# | exp_004 | label_smoothing 0.05 (só main) + peso aux 0.4 + warmup | 41.88% | 47.52% | 71.91% | +0.94pp (aux) |
# | exp_005 | Stem: stride conv (stem_c2 stride=2, he_normal) + sem stem_pool | **45.27%** | 38.35% | 70.31% | +3.39pp (main)† |
# | **exp_006** | **Mixup alpha=0.2 + sem label_smoothing + 120 épocas** | *(pendente)* | *(pendente)* | *(pendente)* | — |
#
# > \*O Top-1 do exp_002 reportado pelo `evaluate()` usa a saída principal (39.29%).
# > A saída auxiliar atingiu 46.58% — gap de ~7pp que exp_004/005 visam eliminar.
# >
# > †exp_005: o gap main/aux **inverteu** — a saída principal (45.27%) superou a auxiliar (38.35%)
# > pela primeira vez. Sinal de que a nova Stem melhorou o fluxo de gradiente até a cabeça principal.
# > O Δ é calculado em relação ao melhor da exp_004 (47.52% aux); comparando apenas as saídas
# > principais: exp_004 main=41.88% → exp_005 main=45.27% = **+3.39pp**.
#
# ## Resumo — exp_006
# | Métrica | Baseline | EXP01 | EXP02 | EXP03 ❌ | EXP04 | EXP05 | **EXP06** |
# |---|---|---|---|---|---|---|---|
# | Top-1 val (principal) | 39.88% | 40.08% | 39.29% | 0.50% | 41.88% | 45.27% | *(pendente)* |
# | Top-1 val (auxiliar) | — | 44.76% | 46.58% | 2.50% | 47.52% | 38.35% | *(pendente)* |
# | Top-5 val | — | 71.05% | 71.79% | 2.50% | 71.91% | 70.31% | *(pendente)* |
# | Épocas | — | 66 | 94 | 16 | 100 (melhor: 88) | 100 (melhor: 87) | *(pendente)* |
#
# **Mudanças acumuladas vs baseline:**
# - `inception_5a/5b`: canais reduzidos ~30% (exp_001)
# - `main_dropout`: 0.4 → 0.55 (exp_002)
# - `loss_weight` auxiliar: 0.3 → 0.4 (exp_004)
# - `ReduceLROnPlateau` patience: 5 → 8 (exp_004)
# - `LR warmup`: 5 épocas de 0.001 → 0.01 (exp_004)
# - `stem_c2`: stride=2, `he_normal` — `stem_pool` removido (exp_005)
# - **`Mixup` alpha=0.2 — `label_smoothing` removido (exp_006)** ← mudança isolada
# - **`EarlyStopping` patience: 20 → 25 (exp_006)**
# - **Épocas máx: 100 → 120 (exp_006)**
#
# **Por que remover label_smoothing com Mixup?**
# > Mixup já cria soft labels ao interpolar $\tilde{y} = \lambda y_i + (1-\lambda) y_j$.
# > Manter `label_smoothing=0.05` em cima disso aplica uma segunda suavização,
# > o que pode impedir que a rede aprenda fronteiras de decisão claras entre classes.
# > O efeito é cumulativo e tende a aumentar a loss sem benefício de regularização adicional.
#
# **Por que 120 épocas com Mixup?**
# > Com Mixup, a `train_loss` é artificialmente mais alta no início (problema mais difícil).
# > O modelo tipicamente converge 20-30 épocas mais tarde do que sem Mixup.
# > Nos experimentos anteriores, o melhor resultado ocorreu nas épocas 87-88 com limite de 100 —
# > havia espaço para melhoria. 120 épocas + ES patience=25 dá margem suficiente sem
# > custo computacional excessivo.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import itertools, math, csv, os, shutil, zipfile, warnings, datetime
import requests
from PIL import Image
from io import BytesIO
from pathlib import Path
from sklearn.metrics import confusion_matrix

warnings.filterwarnings('ignore')
print(f"TensorFlow: {tf.__version__}")
print(f"GPUs: {tf.config.list_physical_devices('GPU')}")
# Out:
# 2026-05-05 23:31:40.146633: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778023900.337537      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778023900.393454      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778023900.832109      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778023900.832149      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778023900.832151      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778023900.832154      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow: 2.19.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ── Hiperparâmetros ──────────────────────────────────────────────────────────
EPOCHS         = 120     # exp_006: aumentado de 100 → 120
BATCH_SIZE     = 128
NUM_CLASSES    = 200
IMG_SIZE       = 64
INITIAL_LR     = 0.01
WARMUP_EPOCHS  = 5
WARMUP_LR      = 0.001
DROPOUT_MAIN   = 0.55
LABEL_SMOOTH   = 0.0    # exp_006: REMOVIDO — Mixup já gera soft labels
AUX_WEIGHT     = 0.4
MIXUP_ALPHA    = 0.2    # exp_006: Mixup com distribuição Beta(0.2, 0.2)

tf.random.set_seed(42)
np.random.seed(42)
print(f"{EPOCHS} épocas | batch {BATCH_SIZE} | {IMG_SIZE}×{IMG_SIZE} | {NUM_CLASSES} classes")
print(f"dropout={DROPOUT_MAIN} | label_smoothing={LABEL_SMOOTH} (removido) | aux_weight={AUX_WEIGHT}")
print(f"LR warmup: {WARMUP_EPOCHS} épocas ({WARMUP_LR} → {INITIAL_LR})")
print(f"[exp_006] Mixup alpha={MIXUP_ALPHA} | EarlyStopping patience=25")
# Out:
# 120 épocas | batch 128 | 64×64 | 200 classes
# dropout=0.55 | label_smoothing=0.0 (removido) | aux_weight=0.4
# LR warmup: 5 épocas (0.001 → 0.01)
# [exp_006] Mixup alpha=0.2 | EarlyStopping patience=25

# %%
TINY_URL = 'http://cs231n.stanford.edu/tiny-imagenet-200.zip'
DATA_DIR = Path('/kaggle/working/tiny-imagenet-200')
ZIP_PATH = Path('/kaggle/working/tiny-imagenet-200.zip')

if not ZIP_PATH.exists():
    print('Baixando Tiny ImageNet (~236 MB)...')
    r = requests.get(TINY_URL, stream=True)
    total = int(r.headers.get('content-length', 0))
    downloaded = 0
    with open(ZIP_PATH, 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024*1024):
            f.write(chunk)
            downloaded += len(chunk)
            print(f'\r  {downloaded/1e6:.1f}/{total/1e6:.1f} MB', end='')
    print('\nDownload completo!')
else:
    print('ZIP já existe.')

if not DATA_DIR.exists():
    print('Extraindo...')
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall('/kaggle/working')
    print('Extração concluída.')
else:
    print('Dataset já extraído.')

val_organized = DATA_DIR / 'val_organized'
if not val_organized.exists():
    print('Reorganizando val/...')
    val_organized.mkdir(parents=True)
    with open(DATA_DIR / 'val' / 'val_annotations.txt') as f:
        for line in f:
            fname, class_id = line.strip().split('\t')[:2]
            d = val_organized / class_id
            d.mkdir(exist_ok=True)
            shutil.copy(DATA_DIR / 'val' / 'images' / fname, d / fname)
    print(f'Val reorganizado: {len(list(val_organized.iterdir()))} classes')
else:
    print('val_organized já existe.')

TRAIN_DIR = DATA_DIR / 'train'
VAL_DIR   = val_organized
print(f'Treino: {TRAIN_DIR} | Val: {VAL_DIR}')
# Out:
# Baixando Tiny ImageNet (~236 MB)...
#   248.1/248.1 MB
# Download completo!
# Extraindo...
# Extração concluída.
# Reorganizando val/...
# Val reorganizado: 200 classes
# Treino: /kaggle/working/tiny-imagenet-200/train | Val: /kaggle/working/tiny-imagenet-200/val_organized

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR, image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE, label_mode='categorical', shuffle=True, seed=42
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR, image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE, label_mode='categorical', shuffle=False
)
CLASS_NAMES = train_ds.class_names
print(f'Classes: {len(CLASS_NAMES)}')

def normalize(img, lbl):
    return tf.cast(img, tf.float32) / 255.0, lbl

# Augmentation base — nível exp_002/004 (sem RandomBrightness, rotação=0.1)
# Mixup é aplicado DEPOIS da augmentation base no pipeline
augment = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomTranslation(0.1, 0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1),
], name='augmentation')

# ── Mixup ────────────────────────────────────────────────────────────────────
# Implementação vetorizada: opera sobre o batch inteiro sem loops Python.
# lambda ~ Beta(alpha, alpha); o batch é shuffled internamente para criar pares.
# Resultado: imagens e labels são misturas convexas de dois exemplos do batch.
@tf.function
def mixup(images, labels, alpha=MIXUP_ALPHA):
    batch_size = tf.shape(images)[0]

    # Amostra lambda da distribuição Beta(alpha, alpha)
    # tf.random.stateless não requer tensorflow_probability
    lam = tf.cast(
        tf.random.stateless_uniform([], seed=(42, 0), minval=0, maxval=1),
        tf.float32
    )
    # Aplica a simetria do Mixup: usa max(lam, 1-lam) para manter a imagem
    # dominante sempre acima de 0.5 — evita imagens 50/50 que confundem muito
    # Nota: para Beta(0.2,0.2) isso não é obrigatório mas melhora a legibilidade
    # dos exemplos de treino. Remova o max() para um Mixup mais agressivo.
    # lam = tf.math.maximum(lam, 1.0 - lam)

    # Shuffle do batch para criar pares aleatórios
    indices = tf.random.shuffle(tf.range(batch_size))
    images_shuffled = tf.gather(images, indices)
    labels_shuffled = tf.gather(labels, indices)

    # Interpolação
    mixed_images = lam * images + (1.0 - lam) * images_shuffled
    mixed_labels = lam * labels + (1.0 - lam) * labels_shuffled
    return mixed_images, mixed_labels

def apply_augment_and_mixup(img, lbl):
    img = augment(img, training=True)
    img, lbl = mixup(img, lbl)
    return img, lbl

train_ds = (
    train_ds
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .map(apply_augment_and_mixup, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)
# Val: SEM Mixup — avaliação sempre com imagens reais
val_ds = (
    val_ds
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)
print('Pipelines prontos (treino com Mixup, val sem Mixup).')
# Out:
# Found 100000 files belonging to 200 classes.
# I0000 00:00:1778023947.311513      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 10000 files belonging to 200 classes.
# Classes: 200
# Pipelines prontos (treino com Mixup, val sem Mixup).

# %%
def inception_module(x, f1, f3r, f3, f5r, f5, fp, name):
    """Módulo Inception: 4 ramos paralelos (Szegedy et al., 2014)."""
    ki = 'glorot_uniform'
    bi = tf.keras.initializers.Constant(0.2)
    kw = dict(padding='same', activation='relu', kernel_initializer=ki, bias_initializer=bi)

    b1 = tf.keras.layers.Conv2D(f1,  (1,1), **kw, name=f'{name}_1x1')(x)

    b2 = tf.keras.layers.Conv2D(f3r, (1,1), **kw, name=f'{name}_3x3_reduce')(x)
    b2 = tf.keras.layers.Conv2D(f3,  (3,3), **kw, name=f'{name}_3x3')(b2)

    b3 = tf.keras.layers.Conv2D(f5r, (1,1), **kw, name=f'{name}_5x5_reduce')(x)
    b3 = tf.keras.layers.Conv2D(f5,  (5,5), **kw, name=f'{name}_5x5')(b3)

    b4 = tf.keras.layers.MaxPooling2D((3,3), strides=(1,1), padding='same', name=f'{name}_pool')(x)
    b4 = tf.keras.layers.Conv2D(fp,  (1,1), **kw, name=f'{name}_pool_proj')(b4)

    return tf.keras.layers.Concatenate(axis=-1, name=name)([b1, b2, b3, b4])

# %%
def build_googlenet(num_classes=200, img_size=64, dropout=0.55):
    """
    GoogLeNet adaptado para 64×64. Acumula mudanças de exp_001 a exp_005.

    Stem (exp_005):
      Conv3x3(64, stride=1, glorot) → 64×64
      Conv3x3(64, stride=2, he_normal) → 32×32   ← downsampling aprendível
      Conv3x3(192, stride=1, glorot) → 32×32
      [sem MaxPool]

    Bloco 5 (exp_001):
      inception_5a: 640ch  (reduzido de 832ch)
      inception_5b: 768ch  (reduzido de 1024ch)

    Cabeça principal (exp_002):
      Dropout 0.55
    """
    bi    = tf.keras.initializers.Constant(0.2)
    kw_g  = dict(padding='same', activation='relu',
                 kernel_initializer='glorot_uniform', bias_initializer=bi)
    kw_he = dict(padding='same', activation='relu',
                 kernel_initializer='he_normal', bias_initializer=bi)

    inp = tf.keras.layers.Input(shape=(img_size, img_size, 3), name='input')

    # ── Stem exp_005 ─────────────────────────────────────────────────────────
    x = tf.keras.layers.Conv2D(64,  (3,3), **kw_g,             name='stem_c1')(inp)  # 64×64
    x = tf.keras.layers.Conv2D(64,  (3,3), strides=2, **kw_he, name='stem_c2')(x)    # 32×32
    x = tf.keras.layers.Conv2D(192, (3,3), **kw_g,             name='stem_c3')(x)    # 32×32

    # ── Bloco 3 ──────────────────────────────────────────────────────────────
    x = inception_module(x,  64,  96, 128, 16,  32,  32, 'inception_3a')
    x = inception_module(x, 128, 128, 192, 32,  96,  64, 'inception_3b')
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same', name='pool_3')(x)

    # ── Bloco 4 ──────────────────────────────────────────────────────────────
    x = inception_module(x, 192,  96, 208, 16,  48,  64, 'inception_4a')

    # ── Classificador Auxiliar ───────────────────────────────────────────────
    aux = tf.keras.layers.AveragePooling2D((5,5), strides=3, padding='same', name='aux_pool')(x)
    aux = tf.keras.layers.Conv2D(128, (1,1), **kw_g, name='aux_conv')(aux)
    aux = tf.keras.layers.Flatten(name='aux_flat')(aux)
    aux = tf.keras.layers.Dense(1024, activation='relu', name='aux_dense')(aux)
    aux = tf.keras.layers.Dropout(0.3, name='aux_drop')(aux)
    aux_out = tf.keras.layers.Dense(num_classes, activation='softmax', name='auxiliary_output')(aux)

    x = inception_module(x, 160, 112, 224, 24,  64,  64, 'inception_4b')
    x = inception_module(x, 128, 128, 256, 24,  64,  64, 'inception_4c')
    x = inception_module(x, 112, 144, 288, 32,  64,  64, 'inception_4d')
    x = inception_module(x, 256, 160, 320, 32, 128, 128, 'inception_4e')
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same', name='pool_4')(x)

    # ── Bloco 5 — canais reduzidos (exp_001) ─────────────────────────────────
    x = inception_module(x, 192, 128, 256, 32,  96,  96, 'inception_5a')  # 640ch
    x = inception_module(x, 256, 160, 320, 32,  96,  96, 'inception_5b')  # 768ch

    # ── Cabeça principal — dropout 0.55 (exp_002) ────────────────────────────
    x = tf.keras.layers.GlobalAveragePooling2D(name='gap')(x)
    x = tf.keras.layers.Dropout(dropout, name='main_dropout')(x)
    main_out = tf.keras.layers.Dense(num_classes, activation='softmax', name='main_output')(x)

    return tf.keras.Model(inputs=inp, outputs=[main_out, aux_out], name='GoogLeNet_exp006')


model = build_googlenet(NUM_CLASSES, IMG_SIZE, DROPOUT_MAIN)
model.summary()

print("\n── Verificação Stem exp_005/006 ──")
for name in ['stem_c1', 'stem_c2', 'stem_c3']:
    layer = model.get_layer(name)
    print(f"  {name}: output={layer.output.shape} | "
          f"kernel_initializer={layer.kernel_initializer.__class__.__name__} | "
          f"strides={layer.strides}")
# Out:
# Model: "GoogLeNet_exp006"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 64, 64, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_c1 (Conv2D)    │ (None, 64, 64,    │      1,792 │ input[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_c2 (Conv2D)    │ (None, 32, 32,    │     36,928 │ stem_c1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_c3 (Conv2D)    │ (None, 32, 32,    │    110,784 │ stem_c2[0][0]     │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3_r… │ (None, 32, 32,    │     18,528 │ stem_c3[0][0]     │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5_r… │ (None, 32, 32,    │      3,088 │ stem_c3[0][0]     │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool   │ (None, 32, 32,    │          0 │ stem_c3[0][0]     │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_1x1    │ (None, 32, 32,    │     12,352 │ stem_c3[0][0]     │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3    │ (None, 32, 32,    │    110,720 │ inception_3a_3x3… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5    │ (None, 32, 32,    │     12,832 │ inception_3a_5x5… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool_… │ (None, 32, 32,    │      6,176 │ inception_3a_poo… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a        │ (None, 32, 32,    │          0 │ inception_3a_1x1… │
# │ (Concatenate)       │ 256)              │            │ inception_3a_3x3… │
# │                     │                   │            │ inception_3a_5x5… │
# │                     │                   │            │ inception_3a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3_r… │ (None, 32, 32,    │     32,896 │ inception_3a[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5_r… │ (None, 32, 32,    │      8,224 │ inception_3a[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool   │ (None, 32, 32,    │          0 │ inception_3a[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_1x1    │ (None, 32, 32,    │     32,896 │ inception_3a[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3    │ (None, 32, 32,    │    221,376 │ inception_3b_3x3… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5    │ (None, 32, 32,    │     76,896 │ inception_3b_5x5… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool_… │ (None, 32, 32,    │     16,448 │ inception_3b_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b        │ (None, 32, 32,    │          0 │ inception_3b_1x1… │
# │ (Concatenate)       │ 480)              │            │ inception_3b_3x3… │
# │                     │                   │            │ inception_3b_5x5… │
# │                     │                   │            │ inception_3b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_3              │ (None, 16, 16,    │          0 │ inception_3b[0][… │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3_r… │ (None, 16, 16,    │     46,176 │ pool_3[0][0]      │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5_r… │ (None, 16, 16,    │      7,696 │ pool_3[0][0]      │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool   │ (None, 16, 16,    │          0 │ pool_3[0][0]      │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_1x1    │ (None, 16, 16,    │     92,352 │ pool_3[0][0]      │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3    │ (None, 16, 16,    │    179,920 │ inception_4a_3x3… │
# │ (Conv2D)            │ 208)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5    │ (None, 16, 16,    │     19,248 │ inception_4a_5x5… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool_… │ (None, 16, 16,    │     30,784 │ inception_4a_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a        │ (None, 16, 16,    │          0 │ inception_4a_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4a_3x3… │
# │                     │                   │            │ inception_4a_5x5… │
# │                     │                   │            │ inception_4a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_3x3_r… │ (None, 16, 16,    │     57,456 │ inception_4a[0][… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_5x5_r… │ (None, 16, 16,    │     12,312 │ inception_4a[0][… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_pool   │ (None, 16, 16,    │          0 │ inception_4a[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_1x1    │ (None, 16, 16,    │     82,080 │ inception_4a[0][… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_3x3    │ (None, 16, 16,    │    226,016 │ inception_4b_3x3… │
# │ (Conv2D)            │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_5x5    │ (None, 16, 16,    │     38,464 │ inception_4b_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b_pool_… │ (None, 16, 16,    │     32,832 │ inception_4b_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b        │ (None, 16, 16,    │          0 │ inception_4b_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4b_3x3… │
# │                     │                   │            │ inception_4b_5x5… │
# │                     │                   │            │ inception_4b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_3x3_r… │ (None, 16, 16,    │     65,664 │ inception_4b[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_5x5_r… │ (None, 16, 16,    │     12,312 │ inception_4b[0][… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_pool   │ (None, 16, 16,    │          0 │ inception_4b[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_1x1    │ (None, 16, 16,    │     65,664 │ inception_4b[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_3x3    │ (None, 16, 16,    │    295,168 │ inception_4c_3x3… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_5x5    │ (None, 16, 16,    │     38,464 │ inception_4c_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c_pool_… │ (None, 16, 16,    │     32,832 │ inception_4c_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c        │ (None, 16, 16,    │          0 │ inception_4c_1x1… │
# │ (Concatenate)       │ 512)              │            │ inception_4c_3x3… │
# │                     │                   │            │ inception_4c_5x5… │
# │                     │                   │            │ inception_4c_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_3x3_r… │ (None, 16, 16,    │     73,872 │ inception_4c[0][… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_5x5_r… │ (None, 16, 16,    │     16,416 │ inception_4c[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_pool   │ (None, 16, 16,    │          0 │ inception_4c[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_1x1    │ (None, 16, 16,    │     57,456 │ inception_4c[0][… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_3x3    │ (None, 16, 16,    │    373,536 │ inception_4d_3x3… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_5x5    │ (None, 16, 16,    │     51,264 │ inception_4d_5x5… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d_pool_… │ (None, 16, 16,    │     32,832 │ inception_4d_poo… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d        │ (None, 16, 16,    │          0 │ inception_4d_1x1… │
# │ (Concatenate)       │ 528)              │            │ inception_4d_3x3… │
# │                     │                   │            │ inception_4d_5x5… │
# │                     │                   │            │ inception_4d_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3_r… │ (None, 16, 16,    │     84,640 │ inception_4d[0][… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5_r… │ (None, 16, 16,    │     16,928 │ inception_4d[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_pool   │ (None, 16, 16,    │          0 │ inception_4d[0][… │
# │ (MaxPooling2D)      │ 528)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_1x1    │ (None, 16, 16,    │    135,424 │ inception_4d[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3    │ (None, 16, 16,    │    461,120 │ inception_4e_3x3… │
# │ (Conv2D)            │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5    │ (None, 16, 16,    │    102,528 │ inception_4e_5x5… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_pool_… │ (None, 16, 16,    │     67,712 │ inception_4e_poo… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e        │ (None, 16, 16,    │          0 │ inception_4e_1x1… │
# │ (Concatenate)       │ 832)              │            │ inception_4e_3x3… │
# │                     │                   │            │ inception_4e_5x5… │
# │                     │                   │            │ inception_4e_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_4              │ (None, 8, 8, 832) │          0 │ inception_4e[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3_r… │ (None, 8, 8, 128) │    106,624 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_5x5_r… │ (None, 8, 8, 32)  │     26,656 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool   │ (None, 8, 8, 832) │          0 │ pool_4[0][0]      │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_1x1    │ (None, 8, 8, 192) │    159,936 │ pool_4[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3    │ (None, 8, 8, 256) │    295,168 │ inception_5a_3x3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_5x5    │ (None, 8, 8, 96)  │     76,896 │ inception_5a_5x5… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool_… │ (None, 8, 8, 96)  │     79,968 │ inception_5a_poo… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a        │ (None, 8, 8, 640) │          0 │ inception_5a_1x1… │
# │ (Concatenate)       │                   │            │ inception_5a_3x3… │
# │                     │                   │            │ inception_5a_5x5… │
# │                     │                   │            │ inception_5a_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3_r… │ (None, 8, 8, 160) │    102,560 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_5x5_r… │ (None, 8, 8, 32)  │     20,512 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool   │ (None, 8, 8, 640) │          0 │ inception_5a[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_pool            │ (None, 6, 6, 512) │          0 │ inception_4a[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_1x1    │ (None, 8, 8, 256) │    164,096 │ inception_5a[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3    │ (None, 8, 8, 320) │    461,120 │ inception_5b_3x3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_5x5    │ (None, 8, 8, 96)  │     76,896 │ inception_5b_5x5… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool_… │ (None, 8, 8, 96)  │     61,536 │ inception_5b_poo… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_conv (Conv2D)   │ (None, 6, 6, 128) │     65,664 │ aux_pool[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b        │ (None, 8, 8, 768) │          0 │ inception_5b_1x1… │
# │ (Concatenate)       │                   │            │ inception_5b_3x3… │
# │                     │                   │            │ inception_5b_5x5… │
# │                     │                   │            │ inception_5b_poo… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_flat (Flatten)  │ (None, 4608)      │          0 │ aux_conv[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 768)       │          0 │ inception_5b[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_dense (Dense)   │ (None, 1024)      │  4,719,616 │ aux_flat[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_dropout        │ (None, 768)       │          0 │ gap[0][0]         │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_drop (Dropout)  │ (None, 1024)      │          0 │ aux_dense[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_output (Dense) │ (None, 200)       │    153,800 │ main_dropout[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ auxiliary_output    │ (None, 200)       │    205,000 │ aux_drop[0][0]    │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,287,152 (39.24 MB)
#  Trainable params: 10,287,152 (39.24 MB)
#  Non-trainable params: 0 (0.00 B)
# ── Verificação Stem exp_005/006 ──
#   stem_c1: output=(None, 64, 64, 64) | kernel_initializer=GlorotUniform | strides=(1, 1)
#   stem_c2: output=(None, 32, 32, 64) | kernel_initializer=HeNormal | strides=(2, 2)
#   stem_c3: output=(None, 32, 32, 192) | kernel_initializer=GlorotUniform | strides=(1, 1)

# %%
# exp_006: label_smoothing=0.0 em ambas as saídas
# Mixup já suaviza as labels — aplicar label_smoothing em cima seria dupla suavização
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=WARMUP_LR, momentum=0.9, nesterov=True),
    loss={
        'main_output':      tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.0),
        'auxiliary_output': tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.0),
    },
    loss_weights={'main_output': 1.0, 'auxiliary_output': AUX_WEIGHT},
    metrics={'main_output': ['accuracy'], 'auxiliary_output': ['accuracy']},
)
print('Compilado com sucesso.')
print(f'  LR inicial (warmup): {WARMUP_LR} | LR alvo: {INITIAL_LR}')
print(f'  label_smoothing: 0.0 (removido — Mixup gera soft labels)')
print(f'  loss_weights: main=1.0 | auxiliary={AUX_WEIGHT}')
# Out:
# Compilado com sucesso.
#   LR inicial (warmup): 0.001 | LR alvo: 0.01
#   label_smoothing: 0.0 (removido — Mixup gera soft labels)
#   loss_weights: main=1.0 | auxiliary=0.4

# %%
class LRWarmupCallback(tf.keras.callbacks.Callback):
    """Sobe o LR linearmente de warmup_lr até target_lr ao longo de warmup_epochs."""
    def __init__(self, warmup_epochs, warmup_lr, target_lr):
        super().__init__()
        self.warmup_epochs = warmup_epochs
        self.warmup_lr     = warmup_lr
        self.target_lr     = target_lr

    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.warmup_epochs:
            lr = self.warmup_lr + (self.target_lr - self.warmup_lr) * (epoch / self.warmup_epochs)
            self.model.optimizer.learning_rate.assign(lr)
            print(f'  [warmup] época {epoch+1}/{self.warmup_epochs} — LR = {lr:.5f}')
        elif epoch == self.warmup_epochs:
            self.model.optimizer.learning_rate.assign(self.target_lr)
            print(f'  [warmup] concluído — LR fixado em {self.target_lr}')

callbacks = [
    LRWarmupCallback(
        warmup_epochs=WARMUP_EPOCHS,
        warmup_lr=WARMUP_LR,
        target_lr=INITIAL_LR,
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_main_output_accuracy', factor=0.5,
        patience=8, min_lr=1e-5, verbose=1, mode='max'
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_main_output_accuracy', patience=25,   # exp_006: 20 → 25
        restore_best_weights=True, verbose=1, mode='max'
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'googlenet_exp006_best.keras', monitor='val_main_output_accuracy',
        save_best_only=True, verbose=1, mode='max'
    ),
    tf.keras.callbacks.CSVLogger('training_log_exp006.csv'),
]

# %%
def dual_labels(img, lbl):
    return img, (lbl, lbl)

train_ds_dual = train_ds.map(dual_labels)
val_ds_dual   = val_ds.map(dual_labels)

print(f'Iniciando exp_006 — {EPOCHS} épocas máx. | Mixup alpha={MIXUP_ALPHA}')
print('Nota: train_loss será mais alta que nos experimentos anteriores (comportamento normal com Mixup).')
history = model.fit(
    train_ds_dual,
    validation_data=val_ds_dual,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Iniciando exp_006 — 120 épocas máx. | Mixup alpha=0.2
# Nota: train_loss será mais alta que nos experimentos anteriores (comportamento normal com Mixup).
#   [warmup] época 1/5 — LR = 0.00100
# Epoch 1/120
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778023959.258543      74 service.cc:152] XLA service 0x7d8aec004630 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778023959.258585      74 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1778023961.033689      74 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1778023991.299752      74 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - auxiliary_output_accuracy: 0.0051 - auxiliary_output_loss: 5.3277 - loss: 7.4921 - main_output_accuracy: 0.0045 - main_output_loss: 5.3610
# Epoch 1: val_main_output_accuracy improved from -inf to 0.00540, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 256s 276ms/step - auxiliary_output_accuracy: 0.0051 - auxiliary_output_loss: 5.3277 - loss: 7.4920 - main_output_accuracy: 0.0045 - main_output_loss: 5.3609 - val_auxiliary_output_accuracy: 0.0067 - val_auxiliary_output_loss: 5.2965 - val_loss: 7.4178 - val_main_output_accuracy: 0.0054 - val_main_output_loss: 5.2987 - learning_rate: 0.0010
#   [warmup] época 2/5 — LR = 0.00280
# Epoch 2/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.0050 - auxiliary_output_loss: 5.2987 - loss: 7.4211 - main_output_accuracy: 0.0049 - main_output_loss: 5.3016
# Epoch 2: val_main_output_accuracy did not improve from 0.00540
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.0050 - auxiliary_output_loss: 5.2987 - loss: 7.4211 - main_output_accuracy: 0.0049 - main_output_loss: 5.3016 - val_auxiliary_output_accuracy: 0.0099 - val_auxiliary_output_loss: 5.2848 - val_loss: 7.4117 - val_main_output_accuracy: 0.0050 - val_main_output_loss: 5.2984 - learning_rate: 0.0028
#   [warmup] época 3/5 — LR = 0.00460
# Epoch 3/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.0106 - auxiliary_output_loss: 5.2663 - loss: 7.4032 - main_output_accuracy: 0.0052 - main_output_loss: 5.2967
# Epoch 3: val_main_output_accuracy improved from 0.00540 to 0.00950, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.0106 - auxiliary_output_loss: 5.2662 - loss: 7.4031 - main_output_accuracy: 0.0052 - main_output_loss: 5.2967 - val_auxiliary_output_accuracy: 0.0135 - val_auxiliary_output_loss: 5.1468 - val_loss: 7.2825 - val_main_output_accuracy: 0.0095 - val_main_output_loss: 5.2264 - learning_rate: 0.0046
#   [warmup] época 4/5 — LR = 0.00640
# Epoch 4/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.0178 - auxiliary_output_loss: 5.1857 - loss: 7.3165 - main_output_accuracy: 0.0109 - main_output_loss: 5.2422
# Epoch 4: val_main_output_accuracy improved from 0.00950 to 0.01620, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.0178 - auxiliary_output_loss: 5.1857 - loss: 7.3165 - main_output_accuracy: 0.0109 - main_output_loss: 5.2422 - val_auxiliary_output_accuracy: 0.0335 - val_auxiliary_output_loss: 4.9619 - val_loss: 7.0998 - val_main_output_accuracy: 0.0162 - val_main_output_loss: 5.1164 - learning_rate: 0.0064
#   [warmup] época 5/5 — LR = 0.00820
# Epoch 5/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.0283 - auxiliary_output_loss: 5.1156 - loss: 7.2440 - main_output_accuracy: 0.0146 - main_output_loss: 5.1978
# Epoch 5: val_main_output_accuracy improved from 0.01620 to 0.02360, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.0283 - auxiliary_output_loss: 5.1156 - loss: 7.2440 - main_output_accuracy: 0.0146 - main_output_loss: 5.1977 - val_auxiliary_output_accuracy: 0.0429 - val_auxiliary_output_loss: 4.8645 - val_loss: 6.9964 - val_main_output_accuracy: 0.0236 - val_main_output_loss: 5.0536 - learning_rate: 0.0082
#   [warmup] concluído — LR fixado em 0.01
# Epoch 6/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.0361 - auxiliary_output_loss: 5.0585 - loss: 7.1697 - main_output_accuracy: 0.0227 - main_output_loss: 5.1463
# Epoch 6: val_main_output_accuracy improved from 0.02360 to 0.03470, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.0361 - auxiliary_output_loss: 5.0585 - loss: 7.1696 - main_output_accuracy: 0.0227 - main_output_loss: 5.1462 - val_auxiliary_output_accuracy: 0.0563 - val_auxiliary_output_loss: 4.7356 - val_loss: 6.8213 - val_main_output_accuracy: 0.0347 - val_main_output_loss: 4.9285 - learning_rate: 0.0100
# Epoch 7/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.0488 - auxiliary_output_loss: 4.9828 - loss: 7.0681 - main_output_accuracy: 0.0301 - main_output_loss: 5.0750
# Epoch 7: val_main_output_accuracy improved from 0.03470 to 0.04170, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.0488 - auxiliary_output_loss: 4.9828 - loss: 7.0681 - main_output_accuracy: 0.0301 - main_output_loss: 5.0750 - val_auxiliary_output_accuracy: 0.0739 - val_auxiliary_output_loss: 4.5890 - val_loss: 6.6417 - val_main_output_accuracy: 0.0417 - val_main_output_loss: 4.8053 - learning_rate: 0.0100
# Epoch 8/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.0629 - auxiliary_output_loss: 4.8901 - loss: 6.9579 - main_output_accuracy: 0.0410 - main_output_loss: 5.0019
# Epoch 8: val_main_output_accuracy improved from 0.04170 to 0.05260, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.0630 - auxiliary_output_loss: 4.8901 - loss: 6.9579 - main_output_accuracy: 0.0410 - main_output_loss: 5.0019 - val_auxiliary_output_accuracy: 0.0844 - val_auxiliary_output_loss: 4.4947 - val_loss: 6.5223 - val_main_output_accuracy: 0.0526 - val_main_output_loss: 4.7247 - learning_rate: 0.0100
# Epoch 9/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.0770 - auxiliary_output_loss: 4.8246 - loss: 6.8733 - main_output_accuracy: 0.0511 - main_output_loss: 4.9434
# Epoch 9: val_main_output_accuracy improved from 0.05260 to 0.06480, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.0770 - auxiliary_output_loss: 4.8246 - loss: 6.8732 - main_output_accuracy: 0.0511 - main_output_loss: 4.9434 - val_auxiliary_output_accuracy: 0.1079 - val_auxiliary_output_loss: 4.3151 - val_loss: 6.3138 - val_main_output_accuracy: 0.0648 - val_main_output_loss: 4.5867 - learning_rate: 0.0100
# Epoch 10/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.0887 - auxiliary_output_loss: 4.7628 - loss: 6.7876 - main_output_accuracy: 0.0632 - main_output_loss: 4.8825
# Epoch 10: val_main_output_accuracy improved from 0.06480 to 0.06670, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.0887 - auxiliary_output_loss: 4.7628 - loss: 6.7876 - main_output_accuracy: 0.0632 - main_output_loss: 4.8825 - val_auxiliary_output_accuracy: 0.1030 - val_auxiliary_output_loss: 4.3152 - val_loss: 6.2813 - val_main_output_accuracy: 0.0667 - val_main_output_loss: 4.5607 - learning_rate: 0.0100
# Epoch 11/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.1030 - auxiliary_output_loss: 4.6947 - loss: 6.6984 - main_output_accuracy: 0.0749 - main_output_loss: 4.8205
# Epoch 11: val_main_output_accuracy improved from 0.06670 to 0.10120, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.1030 - auxiliary_output_loss: 4.6947 - loss: 6.6984 - main_output_accuracy: 0.0749 - main_output_loss: 4.8205 - val_auxiliary_output_accuracy: 0.1393 - val_auxiliary_output_loss: 4.0936 - val_loss: 5.9492 - val_main_output_accuracy: 0.1012 - val_main_output_loss: 4.3129 - learning_rate: 0.0100
# Epoch 12/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.1138 - auxiliary_output_loss: 4.6387 - loss: 6.6154 - main_output_accuracy: 0.0873 - main_output_loss: 4.7600
# Epoch 12: val_main_output_accuracy improved from 0.10120 to 0.14090, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.1138 - auxiliary_output_loss: 4.6386 - loss: 6.6154 - main_output_accuracy: 0.0873 - main_output_loss: 4.7599 - val_auxiliary_output_accuracy: 0.1656 - val_auxiliary_output_loss: 3.9037 - val_loss: 5.6674 - val_main_output_accuracy: 0.1409 - val_main_output_loss: 4.1104 - learning_rate: 0.0100
# Epoch 13/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.1273 - auxiliary_output_loss: 4.5881 - loss: 6.5379 - main_output_accuracy: 0.1006 - main_output_loss: 4.7026
# Epoch 13: val_main_output_accuracy did not improve from 0.14090
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 183s 234ms/step - auxiliary_output_accuracy: 0.1273 - auxiliary_output_loss: 4.5881 - loss: 6.5378 - main_output_accuracy: 0.1006 - main_output_loss: 4.7026 - val_auxiliary_output_accuracy: 0.1685 - val_auxiliary_output_loss: 3.8901 - val_loss: 5.6754 - val_main_output_accuracy: 0.1268 - val_main_output_loss: 4.1305 - learning_rate: 0.0100
# Epoch 14/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.1348 - auxiliary_output_loss: 4.5445 - loss: 6.4666 - main_output_accuracy: 0.1122 - main_output_loss: 4.6488
# Epoch 14: val_main_output_accuracy improved from 0.14090 to 0.14730, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.1348 - auxiliary_output_loss: 4.5445 - loss: 6.4666 - main_output_accuracy: 0.1122 - main_output_loss: 4.6488 - val_auxiliary_output_accuracy: 0.1741 - val_auxiliary_output_loss: 3.8516 - val_loss: 5.5483 - val_main_output_accuracy: 0.1473 - val_main_output_loss: 4.0199 - learning_rate: 0.0100
# Epoch 15/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.1455 - auxiliary_output_loss: 4.5008 - loss: 6.4039 - main_output_accuracy: 0.1217 - main_output_loss: 4.6036
# Epoch 15: val_main_output_accuracy improved from 0.14730 to 0.15450, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.1455 - auxiliary_output_loss: 4.5008 - loss: 6.4039 - main_output_accuracy: 0.1217 - main_output_loss: 4.6036 - val_auxiliary_output_accuracy: 0.1830 - val_auxiliary_output_loss: 3.7982 - val_loss: 5.4562 - val_main_output_accuracy: 0.1545 - val_main_output_loss: 3.9495 - learning_rate: 0.0100
# Epoch 16/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.1551 - auxiliary_output_loss: 4.4700 - loss: 6.3479 - main_output_accuracy: 0.1337 - main_output_loss: 4.5599
# Epoch 16: val_main_output_accuracy improved from 0.15450 to 0.16190, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.1551 - auxiliary_output_loss: 4.4699 - loss: 6.3478 - main_output_accuracy: 0.1337 - main_output_loss: 4.5599 - val_auxiliary_output_accuracy: 0.1844 - val_auxiliary_output_loss: 3.7902 - val_loss: 5.4214 - val_main_output_accuracy: 0.1619 - val_main_output_loss: 3.9167 - learning_rate: 0.0100
# Epoch 17/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.1614 - auxiliary_output_loss: 4.4370 - loss: 6.2915 - main_output_accuracy: 0.1404 - main_output_loss: 4.5167
# Epoch 17: val_main_output_accuracy improved from 0.16190 to 0.17470, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.1614 - auxiliary_output_loss: 4.4370 - loss: 6.2915 - main_output_accuracy: 0.1404 - main_output_loss: 4.5167 - val_auxiliary_output_accuracy: 0.1968 - val_auxiliary_output_loss: 3.7030 - val_loss: 5.2629 - val_main_output_accuracy: 0.1747 - val_main_output_loss: 3.7930 - learning_rate: 0.0100
# Epoch 18/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.1684 - auxiliary_output_loss: 4.4089 - loss: 6.2500 - main_output_accuracy: 0.1492 - main_output_loss: 4.4864
# Epoch 18: val_main_output_accuracy improved from 0.17470 to 0.19540, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.1684 - auxiliary_output_loss: 4.4089 - loss: 6.2499 - main_output_accuracy: 0.1492 - main_output_loss: 4.4864 - val_auxiliary_output_accuracy: 0.2004 - val_auxiliary_output_loss: 3.7047 - val_loss: 5.1866 - val_main_output_accuracy: 0.1954 - val_main_output_loss: 3.7147 - learning_rate: 0.0100
# Epoch 19/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.1737 - auxiliary_output_loss: 4.3843 - loss: 6.2088 - main_output_accuracy: 0.1579 - main_output_loss: 4.4551
# Epoch 19: val_main_output_accuracy did not improve from 0.19540
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.1737 - auxiliary_output_loss: 4.3843 - loss: 6.2088 - main_output_accuracy: 0.1579 - main_output_loss: 4.4551 - val_auxiliary_output_accuracy: 0.1887 - val_auxiliary_output_loss: 3.7347 - val_loss: 5.2924 - val_main_output_accuracy: 0.1803 - val_main_output_loss: 3.8071 - learning_rate: 0.0100
# Epoch 20/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.1780 - auxiliary_output_loss: 4.3655 - loss: 6.1773 - main_output_accuracy: 0.1652 - main_output_loss: 4.4311
# Epoch 20: val_main_output_accuracy did not improve from 0.19540
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.1780 - auxiliary_output_loss: 4.3655 - loss: 6.1773 - main_output_accuracy: 0.1652 - main_output_loss: 4.4311 - val_auxiliary_output_accuracy: 0.1948 - val_auxiliary_output_loss: 3.7368 - val_loss: 5.2760 - val_main_output_accuracy: 0.1851 - val_main_output_loss: 3.7920 - learning_rate: 0.0100
# Epoch 21/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.1838 - auxiliary_output_loss: 4.3432 - loss: 6.1401 - main_output_accuracy: 0.1721 - main_output_loss: 4.4029
# Epoch 21: val_main_output_accuracy did not improve from 0.19540
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.1838 - auxiliary_output_loss: 4.3432 - loss: 6.1401 - main_output_accuracy: 0.1721 - main_output_loss: 4.4028 - val_auxiliary_output_accuracy: 0.1949 - val_auxiliary_output_loss: 3.7355 - val_loss: 5.2722 - val_main_output_accuracy: 0.1819 - val_main_output_loss: 3.7893 - learning_rate: 0.0100
# Epoch 22/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.1891 - auxiliary_output_loss: 4.3212 - loss: 6.1032 - main_output_accuracy: 0.1796 - main_output_loss: 4.3748
# Epoch 22: val_main_output_accuracy improved from 0.19540 to 0.21140, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.1891 - auxiliary_output_loss: 4.3211 - loss: 6.1032 - main_output_accuracy: 0.1796 - main_output_loss: 4.3748 - val_auxiliary_output_accuracy: 0.2194 - val_auxiliary_output_loss: 3.6046 - val_loss: 5.0207 - val_main_output_accuracy: 0.2114 - val_main_output_loss: 3.5938 - learning_rate: 0.0100
# Epoch 23/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.1933 - auxiliary_output_loss: 4.3038 - loss: 6.0755 - main_output_accuracy: 0.1854 - main_output_loss: 4.3540
# Epoch 23: val_main_output_accuracy improved from 0.21140 to 0.22330, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.1933 - auxiliary_output_loss: 4.3038 - loss: 6.0754 - main_output_accuracy: 0.1854 - main_output_loss: 4.3539 - val_auxiliary_output_accuracy: 0.2266 - val_auxiliary_output_loss: 3.5557 - val_loss: 4.9422 - val_main_output_accuracy: 0.2233 - val_main_output_loss: 3.5321 - learning_rate: 0.0100
# Epoch 24/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2000 - auxiliary_output_loss: 4.2839 - loss: 6.0465 - main_output_accuracy: 0.1921 - main_output_loss: 4.3330
# Epoch 24: val_main_output_accuracy did not improve from 0.22330
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2000 - auxiliary_output_loss: 4.2839 - loss: 6.0465 - main_output_accuracy: 0.1921 - main_output_loss: 4.3330 - val_auxiliary_output_accuracy: 0.2084 - val_auxiliary_output_loss: 3.6956 - val_loss: 5.1716 - val_main_output_accuracy: 0.2031 - val_main_output_loss: 3.7131 - learning_rate: 0.0100
# Epoch 25/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2012 - auxiliary_output_loss: 4.2731 - loss: 6.0206 - main_output_accuracy: 0.1981 - main_output_loss: 4.3113
# Epoch 25: val_main_output_accuracy did not improve from 0.22330
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2012 - auxiliary_output_loss: 4.2731 - loss: 6.0206 - main_output_accuracy: 0.1981 - main_output_loss: 4.3113 - val_auxiliary_output_accuracy: 0.2163 - val_auxiliary_output_loss: 3.6125 - val_loss: 5.0184 - val_main_output_accuracy: 0.2164 - val_main_output_loss: 3.5823 - learning_rate: 0.0100
# Epoch 26/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2078 - auxiliary_output_loss: 4.2512 - loss: 5.9906 - main_output_accuracy: 0.2018 - main_output_loss: 4.2901
# Epoch 26: val_main_output_accuracy improved from 0.22330 to 0.24150, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.2078 - auxiliary_output_loss: 4.2512 - loss: 5.9906 - main_output_accuracy: 0.2018 - main_output_loss: 4.2901 - val_auxiliary_output_accuracy: 0.2244 - val_auxiliary_output_loss: 3.5685 - val_loss: 4.8459 - val_main_output_accuracy: 0.2415 - val_main_output_loss: 3.4344 - learning_rate: 0.0100
# Epoch 27/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2105 - auxiliary_output_loss: 4.2423 - loss: 5.9741 - main_output_accuracy: 0.2068 - main_output_loss: 4.2772
# Epoch 27: val_main_output_accuracy did not improve from 0.24150
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2105 - auxiliary_output_loss: 4.2423 - loss: 5.9741 - main_output_accuracy: 0.2068 - main_output_loss: 4.2772 - val_auxiliary_output_accuracy: 0.2150 - val_auxiliary_output_loss: 3.6536 - val_loss: 5.0153 - val_main_output_accuracy: 0.2290 - val_main_output_loss: 3.5743 - learning_rate: 0.0100
# Epoch 28/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2161 - auxiliary_output_loss: 4.2225 - loss: 5.9447 - main_output_accuracy: 0.2130 - main_output_loss: 4.2557
# Epoch 28: val_main_output_accuracy did not improve from 0.24150
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2161 - auxiliary_output_loss: 4.2225 - loss: 5.9447 - main_output_accuracy: 0.2130 - main_output_loss: 4.2557 - val_auxiliary_output_accuracy: 0.2328 - val_auxiliary_output_loss: 3.5401 - val_loss: 4.8783 - val_main_output_accuracy: 0.2382 - val_main_output_loss: 3.4793 - learning_rate: 0.0100
# Epoch 29/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2181 - auxiliary_output_loss: 4.2164 - loss: 5.9342 - main_output_accuracy: 0.2148 - main_output_loss: 4.2477
# Epoch 29: val_main_output_accuracy improved from 0.24150 to 0.24250, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.2181 - auxiliary_output_loss: 4.2164 - loss: 5.9342 - main_output_accuracy: 0.2148 - main_output_loss: 4.2477 - val_auxiliary_output_accuracy: 0.2360 - val_auxiliary_output_loss: 3.5131 - val_loss: 4.8475 - val_main_output_accuracy: 0.2425 - val_main_output_loss: 3.4602 - learning_rate: 0.0100
# Epoch 30/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2223 - auxiliary_output_loss: 4.1989 - loss: 5.8975 - main_output_accuracy: 0.2238 - main_output_loss: 4.2179
# Epoch 30: val_main_output_accuracy improved from 0.24250 to 0.25240, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.2223 - auxiliary_output_loss: 4.1989 - loss: 5.8975 - main_output_accuracy: 0.2238 - main_output_loss: 4.2179 - val_auxiliary_output_accuracy: 0.2499 - val_auxiliary_output_loss: 3.4293 - val_loss: 4.7388 - val_main_output_accuracy: 0.2524 - val_main_output_loss: 3.3854 - learning_rate: 0.0100
# Epoch 31/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2246 - auxiliary_output_loss: 4.1843 - loss: 5.8793 - main_output_accuracy: 0.2281 - main_output_loss: 4.2056
# Epoch 31: val_main_output_accuracy did not improve from 0.25240
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2246 - auxiliary_output_loss: 4.1843 - loss: 5.8793 - main_output_accuracy: 0.2281 - main_output_loss: 4.2056 - val_auxiliary_output_accuracy: 0.2282 - val_auxiliary_output_loss: 3.5707 - val_loss: 4.9382 - val_main_output_accuracy: 0.2277 - val_main_output_loss: 3.5217 - learning_rate: 0.0100
# Epoch 32/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2308 - auxiliary_output_loss: 4.1738 - loss: 5.8628 - main_output_accuracy: 0.2335 - main_output_loss: 4.1933
# Epoch 32: val_main_output_accuracy did not improve from 0.25240
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2309 - auxiliary_output_loss: 4.1738 - loss: 5.8628 - main_output_accuracy: 0.2335 - main_output_loss: 4.1933 - val_auxiliary_output_accuracy: 0.2389 - val_auxiliary_output_loss: 3.4677 - val_loss: 4.8408 - val_main_output_accuracy: 0.2375 - val_main_output_loss: 3.4680 - learning_rate: 0.0100
# Epoch 33/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2318 - auxiliary_output_loss: 4.1605 - loss: 5.8400 - main_output_accuracy: 0.2367 - main_output_loss: 4.1758
# Epoch 33: val_main_output_accuracy did not improve from 0.25240
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2318 - auxiliary_output_loss: 4.1605 - loss: 5.8400 - main_output_accuracy: 0.2367 - main_output_loss: 4.1758 - val_auxiliary_output_accuracy: 0.2358 - val_auxiliary_output_loss: 3.5065 - val_loss: 4.8821 - val_main_output_accuracy: 0.2364 - val_main_output_loss: 3.5043 - learning_rate: 0.0100
# Epoch 34/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2400 - auxiliary_output_loss: 4.1420 - loss: 5.8136 - main_output_accuracy: 0.2436 - main_output_loss: 4.1568
# Epoch 34: val_main_output_accuracy improved from 0.25240 to 0.27240, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.2400 - auxiliary_output_loss: 4.1420 - loss: 5.8135 - main_output_accuracy: 0.2436 - main_output_loss: 4.1567 - val_auxiliary_output_accuracy: 0.2599 - val_auxiliary_output_loss: 3.3926 - val_loss: 4.6742 - val_main_output_accuracy: 0.2724 - val_main_output_loss: 3.3303 - learning_rate: 0.0100
# Epoch 35/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2415 - auxiliary_output_loss: 4.1337 - loss: 5.7948 - main_output_accuracy: 0.2470 - main_output_loss: 4.1413
# Epoch 35: val_main_output_accuracy improved from 0.27240 to 0.27620, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 235ms/step - auxiliary_output_accuracy: 0.2415 - auxiliary_output_loss: 4.1337 - loss: 5.7948 - main_output_accuracy: 0.2470 - main_output_loss: 4.1413 - val_auxiliary_output_accuracy: 0.2532 - val_auxiliary_output_loss: 3.4396 - val_loss: 4.6653 - val_main_output_accuracy: 0.2762 - val_main_output_loss: 3.3093 - learning_rate: 0.0100
# Epoch 36/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2438 - auxiliary_output_loss: 4.1214 - loss: 5.7749 - main_output_accuracy: 0.2524 - main_output_loss: 4.1263
# Epoch 36: val_main_output_accuracy did not improve from 0.27620
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2438 - auxiliary_output_loss: 4.1214 - loss: 5.7749 - main_output_accuracy: 0.2524 - main_output_loss: 4.1263 - val_auxiliary_output_accuracy: 0.2705 - val_auxiliary_output_loss: 3.3482 - val_loss: 4.6342 - val_main_output_accuracy: 0.2723 - val_main_output_loss: 3.3085 - learning_rate: 0.0100
# Epoch 37/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2472 - auxiliary_output_loss: 4.1148 - loss: 5.7618 - main_output_accuracy: 0.2557 - main_output_loss: 4.1158
# Epoch 37: val_main_output_accuracy did not improve from 0.27620
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2472 - auxiliary_output_loss: 4.1148 - loss: 5.7618 - main_output_accuracy: 0.2557 - main_output_loss: 4.1158 - val_auxiliary_output_accuracy: 0.2305 - val_auxiliary_output_loss: 3.5810 - val_loss: 4.9621 - val_main_output_accuracy: 0.2323 - val_main_output_loss: 3.5554 - learning_rate: 0.0100
# Epoch 38/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2511 - auxiliary_output_loss: 4.1047 - loss: 5.7466 - main_output_accuracy: 0.2596 - main_output_loss: 4.1047
# Epoch 38: val_main_output_accuracy improved from 0.27620 to 0.27900, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.2511 - auxiliary_output_loss: 4.1047 - loss: 5.7466 - main_output_accuracy: 0.2596 - main_output_loss: 4.1047 - val_auxiliary_output_accuracy: 0.2573 - val_auxiliary_output_loss: 3.4094 - val_loss: 4.6298 - val_main_output_accuracy: 0.2790 - val_main_output_loss: 3.2827 - learning_rate: 0.0100
# Epoch 39/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2534 - auxiliary_output_loss: 4.0891 - loss: 5.7196 - main_output_accuracy: 0.2643 - main_output_loss: 4.0839
# Epoch 39: val_main_output_accuracy improved from 0.27900 to 0.30300, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.2534 - auxiliary_output_loss: 4.0891 - loss: 5.7195 - main_output_accuracy: 0.2643 - main_output_loss: 4.0839 - val_auxiliary_output_accuracy: 0.2740 - val_auxiliary_output_loss: 3.2916 - val_loss: 4.4328 - val_main_output_accuracy: 0.3030 - val_main_output_loss: 3.1305 - learning_rate: 0.0100
# Epoch 40/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2582 - auxiliary_output_loss: 4.0799 - loss: 5.7140 - main_output_accuracy: 0.2675 - main_output_loss: 4.0821
# Epoch 40: val_main_output_accuracy did not improve from 0.30300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2582 - auxiliary_output_loss: 4.0799 - loss: 5.7140 - main_output_accuracy: 0.2675 - main_output_loss: 4.0821 - val_auxiliary_output_accuracy: 0.2755 - val_auxiliary_output_loss: 3.3173 - val_loss: 4.5194 - val_main_output_accuracy: 0.2976 - val_main_output_loss: 3.1995 - learning_rate: 0.0100
# Epoch 41/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2591 - auxiliary_output_loss: 4.0708 - loss: 5.6946 - main_output_accuracy: 0.2708 - main_output_loss: 4.0663
# Epoch 41: val_main_output_accuracy improved from 0.30300 to 0.30620, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2591 - auxiliary_output_loss: 4.0708 - loss: 5.6946 - main_output_accuracy: 0.2708 - main_output_loss: 4.0663 - val_auxiliary_output_accuracy: 0.2907 - val_auxiliary_output_loss: 3.2290 - val_loss: 4.3788 - val_main_output_accuracy: 0.3062 - val_main_output_loss: 3.1057 - learning_rate: 0.0100
# Epoch 42/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2624 - auxiliary_output_loss: 4.0568 - loss: 5.6686 - main_output_accuracy: 0.2749 - main_output_loss: 4.0459
# Epoch 42: val_main_output_accuracy improved from 0.30620 to 0.31350, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 235ms/step - auxiliary_output_accuracy: 0.2624 - auxiliary_output_loss: 4.0568 - loss: 5.6686 - main_output_accuracy: 0.2749 - main_output_loss: 4.0458 - val_auxiliary_output_accuracy: 0.2802 - val_auxiliary_output_loss: 3.2742 - val_loss: 4.3869 - val_main_output_accuracy: 0.3135 - val_main_output_loss: 3.0935 - learning_rate: 0.0100
# Epoch 43/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2642 - auxiliary_output_loss: 4.0529 - loss: 5.6645 - main_output_accuracy: 0.2774 - main_output_loss: 4.0434
# Epoch 43: val_main_output_accuracy did not improve from 0.31350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2642 - auxiliary_output_loss: 4.0529 - loss: 5.6645 - main_output_accuracy: 0.2774 - main_output_loss: 4.0433 - val_auxiliary_output_accuracy: 0.2836 - val_auxiliary_output_loss: 3.2404 - val_loss: 4.3959 - val_main_output_accuracy: 0.3035 - val_main_output_loss: 3.1145 - learning_rate: 0.0100
# Epoch 44/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2653 - auxiliary_output_loss: 4.0465 - loss: 5.6435 - main_output_accuracy: 0.2830 - main_output_loss: 4.0249
# Epoch 44: val_main_output_accuracy did not improve from 0.31350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.2653 - auxiliary_output_loss: 4.0465 - loss: 5.6435 - main_output_accuracy: 0.2830 - main_output_loss: 4.0249 - val_auxiliary_output_accuracy: 0.2625 - val_auxiliary_output_loss: 3.3785 - val_loss: 4.5814 - val_main_output_accuracy: 0.2825 - val_main_output_loss: 3.2484 - learning_rate: 0.0100
# Epoch 45/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2697 - auxiliary_output_loss: 4.0371 - loss: 5.6294 - main_output_accuracy: 0.2861 - main_output_loss: 4.0146
# Epoch 45: val_main_output_accuracy did not improve from 0.31350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.2697 - auxiliary_output_loss: 4.0371 - loss: 5.6294 - main_output_accuracy: 0.2861 - main_output_loss: 4.0146 - val_auxiliary_output_accuracy: 0.2789 - val_auxiliary_output_loss: 3.2677 - val_loss: 4.4707 - val_main_output_accuracy: 0.2925 - val_main_output_loss: 3.1789 - learning_rate: 0.0100
# Epoch 46/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2733 - auxiliary_output_loss: 4.0215 - loss: 5.6151 - main_output_accuracy: 0.2894 - main_output_loss: 4.0065
# Epoch 46: val_main_output_accuracy improved from 0.31350 to 0.31640, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2733 - auxiliary_output_loss: 4.0215 - loss: 5.6151 - main_output_accuracy: 0.2894 - main_output_loss: 4.0065 - val_auxiliary_output_accuracy: 0.2821 - val_auxiliary_output_loss: 3.2454 - val_loss: 4.3737 - val_main_output_accuracy: 0.3164 - val_main_output_loss: 3.0864 - learning_rate: 0.0100
# Epoch 47/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2763 - auxiliary_output_loss: 4.0121 - loss: 5.5966 - main_output_accuracy: 0.2938 - main_output_loss: 3.9918
# Epoch 47: val_main_output_accuracy did not improve from 0.31640
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.2763 - auxiliary_output_loss: 4.0121 - loss: 5.5966 - main_output_accuracy: 0.2938 - main_output_loss: 3.9918 - val_auxiliary_output_accuracy: 0.2659 - val_auxiliary_output_loss: 3.3434 - val_loss: 4.5165 - val_main_output_accuracy: 0.2883 - val_main_output_loss: 3.1981 - learning_rate: 0.0100
# Epoch 48/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2769 - auxiliary_output_loss: 4.0107 - loss: 5.5927 - main_output_accuracy: 0.2946 - main_output_loss: 3.9884
# Epoch 48: val_main_output_accuracy did not improve from 0.31640
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.2769 - auxiliary_output_loss: 4.0107 - loss: 5.5927 - main_output_accuracy: 0.2947 - main_output_loss: 3.9884 - val_auxiliary_output_accuracy: 0.2689 - val_auxiliary_output_loss: 3.3425 - val_loss: 4.5809 - val_main_output_accuracy: 0.2831 - val_main_output_loss: 3.2555 - learning_rate: 0.0100
# Epoch 49/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2803 - auxiliary_output_loss: 3.9923 - loss: 5.5655 - main_output_accuracy: 0.2986 - main_output_loss: 3.9686
# Epoch 49: val_main_output_accuracy did not improve from 0.31640
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.2803 - auxiliary_output_loss: 3.9923 - loss: 5.5655 - main_output_accuracy: 0.2986 - main_output_loss: 3.9686 - val_auxiliary_output_accuracy: 0.2502 - val_auxiliary_output_loss: 3.4576 - val_loss: 4.7757 - val_main_output_accuracy: 0.2618 - val_main_output_loss: 3.4101 - learning_rate: 0.0100
# Epoch 50/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2815 - auxiliary_output_loss: 3.9903 - loss: 5.5577 - main_output_accuracy: 0.3017 - main_output_loss: 3.9616
# Epoch 50: val_main_output_accuracy improved from 0.31640 to 0.31790, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2815 - auxiliary_output_loss: 3.9903 - loss: 5.5577 - main_output_accuracy: 0.3017 - main_output_loss: 3.9616 - val_auxiliary_output_accuracy: 0.2806 - val_auxiliary_output_loss: 3.2748 - val_loss: 4.3639 - val_main_output_accuracy: 0.3179 - val_main_output_loss: 3.0716 - learning_rate: 0.0100
# Epoch 51/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2852 - auxiliary_output_loss: 3.9840 - loss: 5.5431 - main_output_accuracy: 0.3068 - main_output_loss: 3.9495
# Epoch 51: val_main_output_accuracy did not improve from 0.31790
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.2852 - auxiliary_output_loss: 3.9840 - loss: 5.5431 - main_output_accuracy: 0.3068 - main_output_loss: 3.9495 - val_auxiliary_output_accuracy: 0.2727 - val_auxiliary_output_loss: 3.2948 - val_loss: 4.4619 - val_main_output_accuracy: 0.2986 - val_main_output_loss: 3.1608 - learning_rate: 0.0100
# Epoch 52/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2884 - auxiliary_output_loss: 3.9740 - loss: 5.5373 - main_output_accuracy: 0.3060 - main_output_loss: 3.9476
# Epoch 52: val_main_output_accuracy improved from 0.31790 to 0.32610, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2884 - auxiliary_output_loss: 3.9740 - loss: 5.5372 - main_output_accuracy: 0.3060 - main_output_loss: 3.9476 - val_auxiliary_output_accuracy: 0.2870 - val_auxiliary_output_loss: 3.2452 - val_loss: 4.3144 - val_main_output_accuracy: 0.3261 - val_main_output_loss: 3.0298 - learning_rate: 0.0100
# Epoch 53/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2896 - auxiliary_output_loss: 3.9654 - loss: 5.5176 - main_output_accuracy: 0.3097 - main_output_loss: 3.9315
# Epoch 53: val_main_output_accuracy improved from 0.32610 to 0.34800, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2896 - auxiliary_output_loss: 3.9654 - loss: 5.5176 - main_output_accuracy: 0.3097 - main_output_loss: 3.9314 - val_auxiliary_output_accuracy: 0.3039 - val_auxiliary_output_loss: 3.1364 - val_loss: 4.1408 - val_main_output_accuracy: 0.3480 - val_main_output_loss: 2.8980 - learning_rate: 0.0100
# Epoch 54/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.2922 - auxiliary_output_loss: 3.9602 - loss: 5.5097 - main_output_accuracy: 0.3128 - main_output_loss: 3.9256
# Epoch 54: val_main_output_accuracy improved from 0.34800 to 0.35190, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.2922 - auxiliary_output_loss: 3.9602 - loss: 5.5097 - main_output_accuracy: 0.3128 - main_output_loss: 3.9256 - val_auxiliary_output_accuracy: 0.3042 - val_auxiliary_output_loss: 3.1489 - val_loss: 4.1366 - val_main_output_accuracy: 0.3519 - val_main_output_loss: 2.8971 - learning_rate: 0.0100
# Epoch 55/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2952 - auxiliary_output_loss: 3.9546 - loss: 5.5044 - main_output_accuracy: 0.3155 - main_output_loss: 3.9225
# Epoch 55: val_main_output_accuracy did not improve from 0.35190
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.2952 - auxiliary_output_loss: 3.9546 - loss: 5.5043 - main_output_accuracy: 0.3155 - main_output_loss: 3.9225 - val_auxiliary_output_accuracy: 0.2860 - val_auxiliary_output_loss: 3.2452 - val_loss: 4.3823 - val_main_output_accuracy: 0.3053 - val_main_output_loss: 3.1010 - learning_rate: 0.0100
# Epoch 56/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2961 - auxiliary_output_loss: 3.9458 - loss: 5.4827 - main_output_accuracy: 0.3213 - main_output_loss: 3.9043
# Epoch 56: val_main_output_accuracy did not improve from 0.35190
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.2961 - auxiliary_output_loss: 3.9458 - loss: 5.4827 - main_output_accuracy: 0.3213 - main_output_loss: 3.9043 - val_auxiliary_output_accuracy: 0.2942 - val_auxiliary_output_loss: 3.1823 - val_loss: 4.2737 - val_main_output_accuracy: 0.3348 - val_main_output_loss: 3.0094 - learning_rate: 0.0100
# Epoch 57/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.2989 - auxiliary_output_loss: 3.9379 - loss: 5.4735 - main_output_accuracy: 0.3255 - main_output_loss: 3.8983
# Epoch 57: val_main_output_accuracy did not improve from 0.35190
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.2989 - auxiliary_output_loss: 3.9379 - loss: 5.4735 - main_output_accuracy: 0.3255 - main_output_loss: 3.8983 - val_auxiliary_output_accuracy: 0.2994 - val_auxiliary_output_loss: 3.1473 - val_loss: 4.2185 - val_main_output_accuracy: 0.3433 - val_main_output_loss: 2.9706 - learning_rate: 0.0100
# Epoch 58/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3030 - auxiliary_output_loss: 3.9228 - loss: 5.4543 - main_output_accuracy: 0.3286 - main_output_loss: 3.8852
# Epoch 58: val_main_output_accuracy did not improve from 0.35190
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3030 - auxiliary_output_loss: 3.9228 - loss: 5.4543 - main_output_accuracy: 0.3286 - main_output_loss: 3.8852 - val_auxiliary_output_accuracy: 0.3006 - val_auxiliary_output_loss: 3.1527 - val_loss: 4.1720 - val_main_output_accuracy: 0.3395 - val_main_output_loss: 2.9260 - learning_rate: 0.0100
# Epoch 59/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3053 - auxiliary_output_loss: 3.9244 - loss: 5.4486 - main_output_accuracy: 0.3308 - main_output_loss: 3.8788
# Epoch 59: val_main_output_accuracy improved from 0.35190 to 0.35690, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3053 - auxiliary_output_loss: 3.9244 - loss: 5.4486 - main_output_accuracy: 0.3308 - main_output_loss: 3.8788 - val_auxiliary_output_accuracy: 0.3059 - val_auxiliary_output_loss: 3.1607 - val_loss: 4.1423 - val_main_output_accuracy: 0.3569 - val_main_output_loss: 2.8901 - learning_rate: 0.0100
# Epoch 60/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.3066 - auxiliary_output_loss: 3.9120 - loss: 5.4355 - main_output_accuracy: 0.3340 - main_output_loss: 3.8707
# Epoch 60: val_main_output_accuracy did not improve from 0.35690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3066 - auxiliary_output_loss: 3.9120 - loss: 5.4355 - main_output_accuracy: 0.3340 - main_output_loss: 3.8707 - val_auxiliary_output_accuracy: 0.2948 - val_auxiliary_output_loss: 3.1472 - val_loss: 4.1413 - val_main_output_accuracy: 0.3484 - val_main_output_loss: 2.8958 - learning_rate: 0.0100
# Epoch 61/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3089 - auxiliary_output_loss: 3.9059 - loss: 5.4245 - main_output_accuracy: 0.3380 - main_output_loss: 3.8622
# Epoch 61: val_main_output_accuracy did not improve from 0.35690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3089 - auxiliary_output_loss: 3.9059 - loss: 5.4245 - main_output_accuracy: 0.3380 - main_output_loss: 3.8622 - val_auxiliary_output_accuracy: 0.2977 - val_auxiliary_output_loss: 3.1974 - val_loss: 4.2509 - val_main_output_accuracy: 0.3276 - val_main_output_loss: 2.9900 - learning_rate: 0.0100
# Epoch 62/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3126 - auxiliary_output_loss: 3.9000 - loss: 5.4142 - main_output_accuracy: 0.3412 - main_output_loss: 3.8543
# Epoch 62: val_main_output_accuracy did not improve from 0.35690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3126 - auxiliary_output_loss: 3.8999 - loss: 5.4142 - main_output_accuracy: 0.3412 - main_output_loss: 3.8543 - val_auxiliary_output_accuracy: 0.3018 - val_auxiliary_output_loss: 3.1741 - val_loss: 4.2615 - val_main_output_accuracy: 0.3377 - val_main_output_loss: 3.0116 - learning_rate: 0.0100
# Epoch 63/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3128 - auxiliary_output_loss: 3.8952 - loss: 5.4047 - main_output_accuracy: 0.3413 - main_output_loss: 3.8467
# Epoch 63: val_main_output_accuracy did not improve from 0.35690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3128 - auxiliary_output_loss: 3.8952 - loss: 5.4047 - main_output_accuracy: 0.3413 - main_output_loss: 3.8466 - val_auxiliary_output_accuracy: 0.2906 - val_auxiliary_output_loss: 3.1882 - val_loss: 4.2166 - val_main_output_accuracy: 0.3373 - val_main_output_loss: 2.9602 - learning_rate: 0.0100
# Epoch 64/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3176 - auxiliary_output_loss: 3.8827 - loss: 5.3871 - main_output_accuracy: 0.3452 - main_output_loss: 3.8340
# Epoch 64: val_main_output_accuracy did not improve from 0.35690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3176 - auxiliary_output_loss: 3.8827 - loss: 5.3871 - main_output_accuracy: 0.3452 - main_output_loss: 3.8340 - val_auxiliary_output_accuracy: 0.2931 - val_auxiliary_output_loss: 3.2586 - val_loss: 4.4321 - val_main_output_accuracy: 0.3180 - val_main_output_loss: 3.1539 - learning_rate: 0.0100
# Epoch 65/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3185 - auxiliary_output_loss: 3.8823 - loss: 5.3831 - main_output_accuracy: 0.3490 - main_output_loss: 3.8301
# Epoch 65: val_main_output_accuracy did not improve from 0.35690
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3185 - auxiliary_output_loss: 3.8823 - loss: 5.3830 - main_output_accuracy: 0.3490 - main_output_loss: 3.8301 - val_auxiliary_output_accuracy: 0.3007 - val_auxiliary_output_loss: 3.2060 - val_loss: 4.3343 - val_main_output_accuracy: 0.3262 - val_main_output_loss: 3.0703 - learning_rate: 0.0100
# Epoch 66/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3188 - auxiliary_output_loss: 3.8731 - loss: 5.3699 - main_output_accuracy: 0.3521 - main_output_loss: 3.8206
# Epoch 66: val_main_output_accuracy improved from 0.35690 to 0.37680, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3188 - auxiliary_output_loss: 3.8731 - loss: 5.3698 - main_output_accuracy: 0.3521 - main_output_loss: 3.8206 - val_auxiliary_output_accuracy: 0.3196 - val_auxiliary_output_loss: 3.0984 - val_loss: 4.0208 - val_main_output_accuracy: 0.3768 - val_main_output_loss: 2.7965 - learning_rate: 0.0100
# Epoch 67/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.3201 - auxiliary_output_loss: 3.8643 - loss: 5.3550 - main_output_accuracy: 0.3537 - main_output_loss: 3.8093
# Epoch 67: val_main_output_accuracy did not improve from 0.37680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3201 - auxiliary_output_loss: 3.8643 - loss: 5.3550 - main_output_accuracy: 0.3537 - main_output_loss: 3.8093 - val_auxiliary_output_accuracy: 0.2991 - val_auxiliary_output_loss: 3.1691 - val_loss: 4.1840 - val_main_output_accuracy: 0.3476 - val_main_output_loss: 2.9294 - learning_rate: 0.0100
# Epoch 68/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - auxiliary_output_accuracy: 0.3211 - auxiliary_output_loss: 3.8614 - loss: 5.3445 - main_output_accuracy: 0.3593 - main_output_loss: 3.7999
# Epoch 68: val_main_output_accuracy did not improve from 0.37680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3211 - auxiliary_output_loss: 3.8614 - loss: 5.3445 - main_output_accuracy: 0.3593 - main_output_loss: 3.7999 - val_auxiliary_output_accuracy: 0.3272 - val_auxiliary_output_loss: 3.0613 - val_loss: 4.0289 - val_main_output_accuracy: 0.3699 - val_main_output_loss: 2.8211 - learning_rate: 0.0100
# Epoch 69/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3273 - auxiliary_output_loss: 3.8526 - loss: 5.3299 - main_output_accuracy: 0.3625 - main_output_loss: 3.7888
# Epoch 69: val_main_output_accuracy did not improve from 0.37680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3273 - auxiliary_output_loss: 3.8526 - loss: 5.3299 - main_output_accuracy: 0.3625 - main_output_loss: 3.7888 - val_auxiliary_output_accuracy: 0.3157 - val_auxiliary_output_loss: 3.1068 - val_loss: 4.0676 - val_main_output_accuracy: 0.3659 - val_main_output_loss: 2.8474 - learning_rate: 0.0100
# Epoch 70/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3278 - auxiliary_output_loss: 3.8562 - loss: 5.3309 - main_output_accuracy: 0.3631 - main_output_loss: 3.7884
# Epoch 70: val_main_output_accuracy did not improve from 0.37680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3278 - auxiliary_output_loss: 3.8562 - loss: 5.3309 - main_output_accuracy: 0.3631 - main_output_loss: 3.7884 - val_auxiliary_output_accuracy: 0.3284 - val_auxiliary_output_loss: 3.0482 - val_loss: 4.0368 - val_main_output_accuracy: 0.3642 - val_main_output_loss: 2.8296 - learning_rate: 0.0100
# Epoch 71/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3295 - auxiliary_output_loss: 3.8421 - loss: 5.3176 - main_output_accuracy: 0.3643 - main_output_loss: 3.7808
# Epoch 71: val_main_output_accuracy did not improve from 0.37680
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3296 - auxiliary_output_loss: 3.8421 - loss: 5.3176 - main_output_accuracy: 0.3643 - main_output_loss: 3.7808 - val_auxiliary_output_accuracy: 0.3176 - val_auxiliary_output_loss: 3.1321 - val_loss: 4.0888 - val_main_output_accuracy: 0.3697 - val_main_output_loss: 2.8564 - learning_rate: 0.0100
# Epoch 72/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3321 - auxiliary_output_loss: 3.8356 - loss: 5.3020 - main_output_accuracy: 0.3673 - main_output_loss: 3.7678
# Epoch 72: val_main_output_accuracy did not improve from 0.37680
# ...
# Epoch 96: val_main_output_accuracy did not improve from 0.41370
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3827 - auxiliary_output_loss: 3.6786 - loss: 5.0293 - main_output_accuracy: 0.4410 - main_output_loss: 3.5579 - val_auxiliary_output_accuracy: 0.3430 - val_auxiliary_output_loss: 2.9980 - val_loss: 3.9102 - val_main_output_accuracy: 0.3978 - val_main_output_loss: 2.7304 - learning_rate: 0.0050
# Epoch 97/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3838 - auxiliary_output_loss: 3.6738 - loss: 5.0208 - main_output_accuracy: 0.4428 - main_output_loss: 3.5513
# Epoch 97: val_main_output_accuracy improved from 0.41370 to 0.41930, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3838 - auxiliary_output_loss: 3.6738 - loss: 5.0208 - main_output_accuracy: 0.4428 - main_output_loss: 3.5513 - val_auxiliary_output_accuracy: 0.3576 - val_auxiliary_output_loss: 2.9210 - val_loss: 3.7898 - val_main_output_accuracy: 0.4193 - val_main_output_loss: 2.6403 - learning_rate: 0.0050
# Epoch 98/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3831 - auxiliary_output_loss: 3.6747 - loss: 5.0192 - main_output_accuracy: 0.4452 - main_output_loss: 3.5493
# Epoch 98: val_main_output_accuracy improved from 0.41930 to 0.43920, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3831 - auxiliary_output_loss: 3.6747 - loss: 5.0192 - main_output_accuracy: 0.4452 - main_output_loss: 3.5493 - val_auxiliary_output_accuracy: 0.3705 - val_auxiliary_output_loss: 2.8162 - val_loss: 3.6034 - val_main_output_accuracy: 0.4392 - val_main_output_loss: 2.4907 - learning_rate: 0.0050
# Epoch 99/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3823 - auxiliary_output_loss: 3.6751 - loss: 5.0116 - main_output_accuracy: 0.4491 - main_output_loss: 3.5416
# Epoch 99: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3823 - auxiliary_output_loss: 3.6751 - loss: 5.0116 - main_output_accuracy: 0.4491 - main_output_loss: 3.5416 - val_auxiliary_output_accuracy: 0.3458 - val_auxiliary_output_loss: 2.9645 - val_loss: 3.8385 - val_main_output_accuracy: 0.4010 - val_main_output_loss: 2.6687 - learning_rate: 0.0050
# Epoch 100/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3842 - auxiliary_output_loss: 3.6724 - loss: 5.0104 - main_output_accuracy: 0.4478 - main_output_loss: 3.5415
# Epoch 100: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3842 - auxiliary_output_loss: 3.6724 - loss: 5.0104 - main_output_accuracy: 0.4478 - main_output_loss: 3.5415 - val_auxiliary_output_accuracy: 0.3624 - val_auxiliary_output_loss: 2.9060 - val_loss: 3.7211 - val_main_output_accuracy: 0.4239 - val_main_output_loss: 2.5768 - learning_rate: 0.0050
# Epoch 101/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3884 - auxiliary_output_loss: 3.6580 - loss: 4.9953 - main_output_accuracy: 0.4506 - main_output_loss: 3.5321
# Epoch 101: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3884 - auxiliary_output_loss: 3.6580 - loss: 4.9953 - main_output_accuracy: 0.4506 - main_output_loss: 3.5321 - val_auxiliary_output_accuracy: 0.3481 - val_auxiliary_output_loss: 2.9797 - val_loss: 3.8321 - val_main_output_accuracy: 0.4076 - val_main_output_loss: 2.6573 - learning_rate: 0.0050
# Epoch 102/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3919 - auxiliary_output_loss: 3.6582 - loss: 4.9924 - main_output_accuracy: 0.4518 - main_output_loss: 3.5291
# Epoch 102: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3919 - auxiliary_output_loss: 3.6582 - loss: 4.9924 - main_output_accuracy: 0.4518 - main_output_loss: 3.5291 - val_auxiliary_output_accuracy: 0.3700 - val_auxiliary_output_loss: 2.8389 - val_loss: 3.6202 - val_main_output_accuracy: 0.4352 - val_main_output_loss: 2.4982 - learning_rate: 0.0050
# Epoch 103/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3902 - auxiliary_output_loss: 3.6578 - loss: 4.9925 - main_output_accuracy: 0.4525 - main_output_loss: 3.5294
# Epoch 103: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3902 - auxiliary_output_loss: 3.6578 - loss: 4.9925 - main_output_accuracy: 0.4525 - main_output_loss: 3.5293 - val_auxiliary_output_accuracy: 0.3632 - val_auxiliary_output_loss: 2.9037 - val_loss: 3.7456 - val_main_output_accuracy: 0.4269 - val_main_output_loss: 2.6004 - learning_rate: 0.0050
# Epoch 104/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3896 - auxiliary_output_loss: 3.6555 - loss: 4.9823 - main_output_accuracy: 0.4539 - main_output_loss: 3.5201
# Epoch 104: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3896 - auxiliary_output_loss: 3.6555 - loss: 4.9823 - main_output_accuracy: 0.4539 - main_output_loss: 3.5201 - val_auxiliary_output_accuracy: 0.3547 - val_auxiliary_output_loss: 2.9334 - val_loss: 3.7833 - val_main_output_accuracy: 0.4133 - val_main_output_loss: 2.6290 - learning_rate: 0.0050
# Epoch 105/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3924 - auxiliary_output_loss: 3.6533 - loss: 4.9805 - main_output_accuracy: 0.4558 - main_output_loss: 3.5192
# Epoch 105: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3924 - auxiliary_output_loss: 3.6533 - loss: 4.9805 - main_output_accuracy: 0.4558 - main_output_loss: 3.5192 - val_auxiliary_output_accuracy: 0.3565 - val_auxiliary_output_loss: 2.9447 - val_loss: 3.7389 - val_main_output_accuracy: 0.4278 - val_main_output_loss: 2.5761 - learning_rate: 0.0050
# Epoch 106/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3931 - auxiliary_output_loss: 3.6560 - loss: 4.9797 - main_output_accuracy: 0.4582 - main_output_loss: 3.5173
# Epoch 106: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 106: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3931 - auxiliary_output_loss: 3.6559 - loss: 4.9797 - main_output_accuracy: 0.4582 - main_output_loss: 3.5173 - val_auxiliary_output_accuracy: 0.3517 - val_auxiliary_output_loss: 2.9638 - val_loss: 3.7769 - val_main_output_accuracy: 0.4235 - val_main_output_loss: 2.6083 - learning_rate: 0.0050
# Epoch 107/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3990 - auxiliary_output_loss: 3.6306 - loss: 4.9382 - main_output_accuracy: 0.4690 - main_output_loss: 3.4859
# Epoch 107: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 234ms/step - auxiliary_output_accuracy: 0.3990 - auxiliary_output_loss: 3.6306 - loss: 4.9382 - main_output_accuracy: 0.4690 - main_output_loss: 3.4859 - val_auxiliary_output_accuracy: 0.3542 - val_auxiliary_output_loss: 2.9221 - val_loss: 3.7312 - val_main_output_accuracy: 0.4252 - val_main_output_loss: 2.5794 - learning_rate: 0.0025
# Epoch 108/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4002 - auxiliary_output_loss: 3.6253 - loss: 4.9264 - main_output_accuracy: 0.4717 - main_output_loss: 3.4763
# Epoch 108: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4002 - auxiliary_output_loss: 3.6253 - loss: 4.9264 - main_output_accuracy: 0.4717 - main_output_loss: 3.4763 - val_auxiliary_output_accuracy: 0.3603 - val_auxiliary_output_loss: 2.9066 - val_loss: 3.6978 - val_main_output_accuracy: 0.4327 - val_main_output_loss: 2.5503 - learning_rate: 0.0025
# Epoch 109/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4022 - auxiliary_output_loss: 3.6190 - loss: 4.9171 - main_output_accuracy: 0.4744 - main_output_loss: 3.4695
# Epoch 109: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4022 - auxiliary_output_loss: 3.6190 - loss: 4.9171 - main_output_accuracy: 0.4744 - main_output_loss: 3.4695 - val_auxiliary_output_accuracy: 0.3629 - val_auxiliary_output_loss: 2.8761 - val_loss: 3.6557 - val_main_output_accuracy: 0.4373 - val_main_output_loss: 2.5239 - learning_rate: 0.0025
# Epoch 110/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.3995 - auxiliary_output_loss: 3.6162 - loss: 4.9117 - main_output_accuracy: 0.4728 - main_output_loss: 3.4652
# Epoch 110: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.3995 - auxiliary_output_loss: 3.6162 - loss: 4.9117 - main_output_accuracy: 0.4728 - main_output_loss: 3.4652 - val_auxiliary_output_accuracy: 0.3683 - val_auxiliary_output_loss: 2.8635 - val_loss: 3.6756 - val_main_output_accuracy: 0.4295 - val_main_output_loss: 2.5480 - learning_rate: 0.0025
# Epoch 111/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4051 - auxiliary_output_loss: 3.6137 - loss: 4.9126 - main_output_accuracy: 0.4729 - main_output_loss: 3.4672
# Epoch 111: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4051 - auxiliary_output_loss: 3.6137 - loss: 4.9126 - main_output_accuracy: 0.4729 - main_output_loss: 3.4672 - val_auxiliary_output_accuracy: 0.3637 - val_auxiliary_output_loss: 2.8950 - val_loss: 3.7243 - val_main_output_accuracy: 0.4270 - val_main_output_loss: 2.5826 - learning_rate: 0.0025
# Epoch 112/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4036 - auxiliary_output_loss: 3.6148 - loss: 4.9091 - main_output_accuracy: 0.4769 - main_output_loss: 3.4632
# Epoch 112: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4036 - auxiliary_output_loss: 3.6147 - loss: 4.9091 - main_output_accuracy: 0.4769 - main_output_loss: 3.4632 - val_auxiliary_output_accuracy: 0.3650 - val_auxiliary_output_loss: 2.8678 - val_loss: 3.6451 - val_main_output_accuracy: 0.4382 - val_main_output_loss: 2.5130 - learning_rate: 0.0025
# Epoch 113/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4047 - auxiliary_output_loss: 3.6154 - loss: 4.9022 - main_output_accuracy: 0.4789 - main_output_loss: 3.4560
# Epoch 113: val_main_output_accuracy did not improve from 0.43920
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4047 - auxiliary_output_loss: 3.6154 - loss: 4.9022 - main_output_accuracy: 0.4789 - main_output_loss: 3.4560 - val_auxiliary_output_accuracy: 0.3625 - val_auxiliary_output_loss: 2.8877 - val_loss: 3.6862 - val_main_output_accuracy: 0.4352 - val_main_output_loss: 2.5505 - learning_rate: 0.0025
# Epoch 114/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4031 - auxiliary_output_loss: 3.6108 - loss: 4.8994 - main_output_accuracy: 0.4775 - main_output_loss: 3.4550
# Epoch 114: val_main_output_accuracy improved from 0.43920 to 0.44080, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.4031 - auxiliary_output_loss: 3.6108 - loss: 4.8994 - main_output_accuracy: 0.4775 - main_output_loss: 3.4550 - val_auxiliary_output_accuracy: 0.3708 - val_auxiliary_output_loss: 2.8330 - val_loss: 3.6356 - val_main_output_accuracy: 0.4408 - val_main_output_loss: 2.5172 - learning_rate: 0.0025
# Epoch 115/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4090 - auxiliary_output_loss: 3.6044 - loss: 4.8946 - main_output_accuracy: 0.4791 - main_output_loss: 3.4528
# Epoch 115: val_main_output_accuracy did not improve from 0.44080
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4090 - auxiliary_output_loss: 3.6044 - loss: 4.8946 - main_output_accuracy: 0.4791 - main_output_loss: 3.4528 - val_auxiliary_output_accuracy: 0.3687 - val_auxiliary_output_loss: 2.8558 - val_loss: 3.6462 - val_main_output_accuracy: 0.4394 - val_main_output_loss: 2.5236 - learning_rate: 0.0025
# Epoch 116/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4042 - auxiliary_output_loss: 3.6109 - loss: 4.8913 - main_output_accuracy: 0.4821 - main_output_loss: 3.4470
# Epoch 116: val_main_output_accuracy did not improve from 0.44080
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4042 - auxiliary_output_loss: 3.6109 - loss: 4.8913 - main_output_accuracy: 0.4821 - main_output_loss: 3.4469 - val_auxiliary_output_accuracy: 0.3645 - val_auxiliary_output_loss: 2.8800 - val_loss: 3.7052 - val_main_output_accuracy: 0.4325 - val_main_output_loss: 2.5723 - learning_rate: 0.0025
# Epoch 117/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4069 - auxiliary_output_loss: 3.6088 - loss: 4.8941 - main_output_accuracy: 0.4807 - main_output_loss: 3.4506
# Epoch 117: val_main_output_accuracy improved from 0.44080 to 0.44880, saving model to googlenet_exp006_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - auxiliary_output_accuracy: 0.4070 - auxiliary_output_loss: 3.6087 - loss: 4.8941 - main_output_accuracy: 0.4807 - main_output_loss: 3.4506 - val_auxiliary_output_accuracy: 0.3698 - val_auxiliary_output_loss: 2.8374 - val_loss: 3.5791 - val_main_output_accuracy: 0.4488 - val_main_output_loss: 2.4606 - learning_rate: 0.0025
# Epoch 118/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4084 - auxiliary_output_loss: 3.6046 - loss: 4.8855 - main_output_accuracy: 0.4857 - main_output_loss: 3.4437
# Epoch 118: val_main_output_accuracy did not improve from 0.44880
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4084 - auxiliary_output_loss: 3.6046 - loss: 4.8855 - main_output_accuracy: 0.4857 - main_output_loss: 3.4437 - val_auxiliary_output_accuracy: 0.3691 - val_auxiliary_output_loss: 2.8549 - val_loss: 3.6340 - val_main_output_accuracy: 0.4411 - val_main_output_loss: 2.5100 - learning_rate: 0.0025
# Epoch 119/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4098 - auxiliary_output_loss: 3.6063 - loss: 4.8884 - main_output_accuracy: 0.4809 - main_output_loss: 3.4458
# Epoch 119: val_main_output_accuracy did not improve from 0.44880
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4098 - auxiliary_output_loss: 3.6063 - loss: 4.8883 - main_output_accuracy: 0.4809 - main_output_loss: 3.4458 - val_auxiliary_output_accuracy: 0.3596 - val_auxiliary_output_loss: 2.9109 - val_loss: 3.7355 - val_main_output_accuracy: 0.4280 - val_main_output_loss: 2.5871 - learning_rate: 0.0025
# Epoch 120/120
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - auxiliary_output_accuracy: 0.4077 - auxiliary_output_loss: 3.6067 - loss: 4.8816 - main_output_accuracy: 0.4823 - main_output_loss: 3.4390
# Epoch 120: val_main_output_accuracy did not improve from 0.44880
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - auxiliary_output_accuracy: 0.4077 - auxiliary_output_loss: 3.6067 - loss: 4.8816 - main_output_accuracy: 0.4823 - main_output_loss: 3.4390 - val_auxiliary_output_accuracy: 0.3673 - val_auxiliary_output_loss: 2.8602 - val_loss: 3.6445 - val_main_output_accuracy: 0.4372 - val_main_output_loss: 2.5170 - learning_rate: 0.0025
# Restoring model weights from the end of the best epoch: 117.

# %%
best_model = tf.keras.models.load_model('googlenet_exp006_best.keras')
results    = best_model.evaluate(val_ds_dual, verbose=0)
print('\nresults[] completo (para debug de índices):')
for i, v in enumerate(results):
    print(f'  results[{i}] = {v:.4f}')
# Out:
# results[] completo (para debug de índices):
#   results[0] = 3.5791
#   results[1] = 2.4606
#   results[2] = 2.8374
#   results[3] = 0.3698
#   results[4] = 0.4488

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

axes[0].plot(history.history['loss'],     label='Train', color='steelblue')
axes[0].plot(history.history['val_loss'], label='Val',   color='tomato')
axes[0].set_title('Loss Total')
axes[0].set_xlabel('Épocas'); axes[0].legend(); axes[0].grid(alpha=0.4)
axes[0].annotate('Train loss mais alta\né normal com Mixup',
                 xy=(0.05, 0.95), xycoords='axes fraction',
                 fontsize=8, color='gray', va='top')

axes[1].plot(history.history['main_output_accuracy'],     label='Train', color='steelblue')
axes[1].plot(history.history['val_main_output_accuracy'], label='Val',   color='tomato')
axes[1].set_title('Acurácia — Saída Principal')
axes[1].set_xlabel('Épocas'); axes[1].legend(); axes[1].grid(alpha=0.4)

axes[2].plot(history.history['auxiliary_output_accuracy'],     label='Train (aux)', color='mediumpurple')
axes[2].plot(history.history['val_auxiliary_output_accuracy'], label='Val (aux)',   color='darkorange')
axes[2].plot(history.history['val_main_output_accuracy'],      label='Val (main)',  color='tomato', linestyle='--')
axes[2].set_title('Acurácia — Main vs. Auxiliar (gap)')
axes[2].set_xlabel('Épocas'); axes[2].legend(); axes[2].grid(alpha=0.4)

plt.suptitle('exp_006 — Curvas de Treinamento (com Mixup)', fontsize=13)
plt.tight_layout()
plt.savefig('training_curves_exp006.png', dpi=150)
plt.show()

# %%
id_to_name = {}
words_file = DATA_DIR / 'words.txt'
if words_file.exists():
    with open(words_file) as f:
        for line in f:
            parts = line.strip().split('\t', 1)
            if len(parts) == 2:
                id_to_name[parts[0]] = parts[1].split(',')[0]

idx_to_name = {i: id_to_name.get(cid, cid) for i, cid in enumerate(CLASS_NAMES)}
print('Mapeamento carregado.')
# Out:
# Mapeamento carregado.

# %%
# Coleta predições usando output[0] (main_output) diretamente — mais confiável
all_true, all_pred, all_probs = [], [], []
for imgs, (lbls, _) in val_ds_dual:
    lbl_idx = tf.argmax(lbls, axis=1).numpy()
    probs   = best_model(imgs, training=False)[0].numpy()  # [0] = main_output
    all_true.extend(lbl_idx)
    all_pred.extend(np.argmax(probs, axis=1))
    all_probs.append(probs)

all_true  = np.array(all_true)
all_pred  = np.array(all_pred)
all_probs = np.concatenate(all_probs, axis=0)

# Top-5
top5_metric = tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5)
top5_metric.update_state(all_true, all_probs)
top5_acc = top5_metric.result().numpy()

# Auxiliar — output[1]
all_probs_aux = []
for imgs, (_, _) in val_ds_dual:
    probs_aux = best_model(imgs, training=False)[1].numpy()  # [1] = auxiliary_output
    all_probs_aux.append(probs_aux)
all_probs_aux = np.concatenate(all_probs_aux, axis=0)
aux_acc = (np.argmax(all_probs_aux, axis=1) == all_true).mean()

per_class_acc = {
    c: (all_pred[all_true == c] == c).mean()
    for c in range(NUM_CLASSES) if (all_true == c).sum() > 0
}
sorted_acc = sorted(per_class_acc.items(), key=lambda x: x[1], reverse=True)
main_acc   = (all_true == all_pred).mean()

print(f"{'='*55}")
print(f"  Top-1 — Saída Principal  : {main_acc*100:.2f}%")
print(f"  Top-1 — Saída Auxiliar   : {aux_acc*100:.2f}%")
print(f"  Gap main/aux             : {abs(main_acc - aux_acc)*100:.2f}pp")
print(f"  Top-5 — Saída Principal  : {top5_acc*100:.2f}%")
print(f"  Média per-class (main)   : {np.mean(list(per_class_acc.values()))*100:.2f}%")
print(f"  Melhor classe            : {idx_to_name.get(sorted_acc[0][0])} ({sorted_acc[0][1]*100:.1f}%)")
print(f"  Pior classe              : {idx_to_name.get(sorted_acc[-1][0])} ({sorted_acc[-1][1]*100:.1f}%)")
print(f"{'='*55}")
# Out:
# =======================================================
#   Top-1 — Saída Principal  : 44.88%
#   Top-1 — Saída Auxiliar   : 36.98%
#   Gap main/aux             : 7.90pp
#   Top-5 — Saída Principal  : 70.75%
#   Média per-class (main)   : 44.88%
#   Melhor classe            : school bus (96.0%)
#   Pior classe              : plunger (2.0%)
# =======================================================

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
for ax, data, title, color in [
    (axes[0], sorted_acc[:20],  'Top-20 (melhor acurácia)', '#2ecc71'),
    (axes[1], sorted_acc[-20:], 'Bottom-20 (pior acurácia)', '#e74c3c'),
]:
    lbls = [idx_to_name.get(c, str(c)) for c, _ in data]
    vals = [v * 100 for _, v in data]
    bars = ax.barh(lbls[::-1], vals[::-1], color=color, alpha=0.8)
    ax.axvline(np.mean(list(per_class_acc.values())) * 100,
               color='gray', linestyle='--', lw=1, label='Média')
    ax.set_xlabel('Acurácia (%)'); ax.set_title(title)
    ax.set_xlim(0, 100); ax.legend(fontsize=8); ax.grid(axis='x', alpha=0.3)
    for bar, val in zip(bars, vals[::-1]):
        ax.text(val + 0.5, bar.get_y() + bar.get_height()/2,
                f'{val:.1f}%', va='center', fontsize=7)

plt.tight_layout()
plt.savefig('per_class_exp006.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
top20_idx = [c for c, _ in sorted(
    ((c, (all_true == c).sum()) for c in range(NUM_CLASSES)), key=lambda x: -x[1]
)[:20]]

mask = np.isin(all_true, top20_idx)
cm   = confusion_matrix(all_true[mask], all_pred[mask], labels=top20_idx)
cm_n = cm.astype(float) / cm.sum(axis=1, keepdims=True)

fig, ax = plt.subplots(figsize=(14, 12))
im = ax.imshow(cm_n, cmap='Blues', vmin=0, vmax=1)
plt.colorbar(im, ax=ax, fraction=0.03)
tick_lbl = [idx_to_name.get(c, str(c))[:12] for c in top20_idx]
ax.set_xticks(range(20)); ax.set_xticklabels(tick_lbl, rotation=45, ha='right', fontsize=7)
ax.set_yticks(range(20)); ax.set_yticklabels(tick_lbl, fontsize=7)
ax.set_title('Confusion Matrix — 20 classes mais frequentes (normalizada)')
ax.set_ylabel('Real'); ax.set_xlabel('Predito')
for i, j in itertools.product(range(20), range(20)):
    if cm_n[i, j] > 0.15:
        ax.text(j, i, f'{cm_n[i,j]:.2f}', ha='center', va='center',
                color='white' if cm_n[i,j] > 0.5 else 'black', fontsize=6)
plt.tight_layout()
plt.savefig('confusion_matrix_exp006.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
N, COLS = 20, 5
ROWS = math.ceil(N / COLS)

sample_imgs, (sample_lbls, _) = next(iter(val_ds_dual))
sample_imgs = sample_imgs[:N]
true_idx    = tf.argmax(sample_lbls[:N], axis=1).numpy()
probs_main  = best_model(sample_imgs, training=False)[0].numpy()
pred_idx    = np.argmax(probs_main, axis=1)
confs       = np.max(probs_main, axis=1)

fig, axes = plt.subplots(ROWS, COLS, figsize=(COLS*3, ROWS*3.4))
for i, ax in enumerate(axes.flat[:N]):
    correct = true_idx[i] == pred_idx[i]
    cor = '#2ecc71' if correct else '#e74c3c'
    ax.imshow(sample_imgs[i].numpy())
    for s in ax.spines.values():
        s.set_edgecolor(cor); s.set_linewidth(4)
    ax.set_title(
        f"Real: {idx_to_name.get(true_idx[i], '')}\n"
        f"Pred: {idx_to_name.get(pred_idx[i], '')}\n{confs[i]*100:.1f}%",
        fontsize=7.5, color=cor, pad=3
    )
    ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
for ax in axes.flat[N:]:
    ax.axis('off')

n_ok = (true_idx == pred_idx).sum()
fig.legend(handles=[
    mpatches.Patch(color='#2ecc71', label='Acerto'),
    mpatches.Patch(color='#e74c3c', label='Erro')
], loc='lower center', ncol=2, fontsize=10, bbox_to_anchor=(0.5, 0), frameon=False)
fig.suptitle(f'Real vs. Predito — {n_ok}/{N} corretos ({n_ok/N*100:.0f}%)', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('real_vs_predito_exp006.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
TEST_URLS = [
    ('goldfish',      'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Goldfish3.jpg/320px-Goldfish3.jpg'),
    ('tabby cat',     'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Cat_November_2010-1a.jpg/320px-Cat_November_2010-1a.jpg'),
    ('ant',           'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Camponotus_flavomarginatus_ant.jpg/320px-Camponotus_flavomarginatus_ant.jpg'),
    ('school bus',    'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Iconbus.jpg/320px-Iconbus.jpg'),
    ('Egyptian cat',  'https://upload.wikimedia.org/wikipedia/commons/thumb/9/94/Sobekhotep_IV_MET_44.4.21.jpg/320px-Sobekhotep_IV_MET_44.4.21.jpg'),
    ('monarch',       'https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Monarch_Butterfly_Danaus_plexippus_on_Echinacea_purpurea_1.jpg/320px-Monarch_Butterfly_Danaus_plexippus_on_Echinacea_purpurea_1.jpg'),
]

def predict_url(label, url, top_k=5):
    try:
        r   = requests.get(url, timeout=10, headers={'User-Agent': 'Mozilla/5.0'})
        img = Image.open(BytesIO(r.content)).convert('RGB')
        img_r = img.resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)
        arr   = np.array(img_r, dtype=np.float32)[None] / 255.0

        probs   = best_model(arr, training=False)[0][0].numpy()
        top_idx = np.argsort(probs)[::-1][:top_k]

        fig, axes = plt.subplots(1, 2, figsize=(8, 3.5),
                                 gridspec_kw={'width_ratios': [1, 2]})
        axes[0].imshow(img_r); axes[0].axis('off')
        axes[0].set_title(f'[esperado: {label}]', fontsize=8, color='gray')

        names  = [idx_to_name.get(i, str(i)) for i in top_idx]
        vals   = [probs[i]*100 for i in top_idx]
        colors = ['#2ecc71' if label.lower() in n.lower() else '#5b8dd9' for n in names]
        axes[1].barh(names[::-1], vals[::-1], color=colors[::-1])
        axes[1].set_xlabel('Confiança (%)')
        axes[1].set_title('Top-5 Predições')
        axes[1].set_xlim(0, 100)

        plt.suptitle(f'Predição externa — {label}', fontsize=10)
        plt.tight_layout()
        plt.show()
        print(f'  Top-1: {names[0]} ({vals[0]:.1f}%) | esperado: {label}')
    except Exception as e:
        print(f'  Erro ({label}): {e}')

for lbl, url in TEST_URLS:
    predict_url(lbl, url)
# Out:
#   Erro (goldfish): cannot identify image file <_io.BytesIO object at 0x7d8adf34a840>
#   Erro (tabby cat): cannot identify image file <_io.BytesIO object at 0x7d8ade464d60>
#   Erro (ant): cannot identify image file <_io.BytesIO object at 0x7d8adf0d75b0>
#   Erro (school bus): cannot identify image file <_io.BytesIO object at 0x7d8adf0d75b0>
#   Erro (Egyptian cat): cannot identify image file <_io.BytesIO object at 0x7d8adf0d75b0>
#   Erro (monarch): cannot identify image file <_io.BytesIO object at 0x7d8ade467ec0>

# %%
EXPERIMENTO['resultado_top1'] = round(float(main_acc) * 100, 2)
EXPERIMENTO['resultado_top5'] = round(float(top5_acc) * 100, 2)
EXPERIMENTO['epocas']         = len(history.history['loss'])

log_path   = 'experimentos_log.csv'
fieldnames = ['id', 'hipotese', 'mudancas', 'resultado_top1', 'resultado_top5', 'epocas', 'timestamp']
row = {
    **EXPERIMENTO,
    'mudancas':  ' | '.join(EXPERIMENTO['mudancas']),
    'timestamp': datetime.datetime.now().isoformat(),
}
file_exists = os.path.isfile(log_path)
with open(log_path, 'a', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    if not file_exists:
        writer.writeheader()
    writer.writerow(row)

print(f'✓ {EXPERIMENTO["id"]} salvo em {log_path}')
print(f'  Top-1 (main): {EXPERIMENTO["resultado_top1"]}% | Top-5: {EXPERIMENTO["resultado_top5"]}% | Épocas: {EXPERIMENTO["epocas"]}')
print(f'  Top-1 (aux):  {aux_acc*100:.2f}%')
print(f'  Gap main/aux: {abs(main_acc - aux_acc)*100:.2f}pp')
# Out:
# ✓ exp_006 salvo em experimentos_log.csv
#   Top-1 (main): 44.88% | Top-5: 70.75% | Épocas: 120
#   Top-1 (aux):  36.98%
#   Gap main/aux: 7.90pp
